# %% [markdown]
# # 先创建导入文件。根据不同task，创建不同文档。txt，json等等
# <img src="figures/cell_000_image.png" width="600" alt="image.png"><br>

# %% [markdown]
# # 导入coco检测框标签
# （该标签是label_no_overlap.json, 处理路线: labels.json -> coco_crops_ov20.json -> label_no_overlap.json， 原始->640图->去重）
# <img src="figures/cell_001_image.png" width="600" alt="image.png"><br>

# %% [markdown]
# # 检查标记
#
# <img src="figures/cell_002_image.png" width="600" alt="image.png"><br>

# %% [markdown]
# # 导出yolo水平框标签
# <img src="figures/cell_003_image.png" width="600" alt="image.png"><br>
#
# <img src="figures/cell_003_image-2.png" width="600" alt="image-2.png"><br>

# %% [markdown]
# # 最后文件夹里有以下文件
# <img src="figures/cell_004_image-2.png" width="600" alt="image-2.png"><br>

# %% [markdown]
# # labels文件夹里有图片和txt（annotation）。 分成yolo格式文件夹，就可以开始训练了
