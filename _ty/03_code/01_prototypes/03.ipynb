# %%
数据集集合根目录 = "root"
每个数据集的path列表 = 根据数据集集合根目录获取每个数据集的path列表(数据集集合根目录)
for 每个数据集的path in 每个数据集的path列表:
    raw_data文件夹的path = 获取raw_data文件夹的path(每个数据集的path)
    raw_image文件夹下每张图片的path的list = 获取当前数据集的所有图片的路径(raw_data文件夹的path)
    每张图片需要切割的窗口矩阵或者mask = 获取每张图片需要切割的窗口矩阵或者mask(raw_image文件夹下每张图片的path的list)
