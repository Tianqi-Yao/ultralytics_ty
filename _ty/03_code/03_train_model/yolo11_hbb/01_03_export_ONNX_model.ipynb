# %% [markdown]
# # 导出ONNX模型

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/workspace/models/runs_yolov11/output/good/yolo11n-seg.pt---data_split_0.6_0.2_0.2_4---0.913/weights/best.pt")  # load a custom trained model

# Export the model
model.export(format="onnx")
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Core(TM) Ultra 7 265KF)
# YOLO11n-seg summary (fused): 113 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
#
# PyTorch: starting from '/workspace/models/runs_yolov11/output/good/yolo11n-seg.pt---data_split_0.6_0.2_0.2_4---0.913/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 37, 8400), (1, 32, 160, 160)) (5.8 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 0.8s, saved as '/workspace/models/runs_yolov11/output/good/yolo11n-seg.pt---data_split_0.6_0.2_0.2_4---0.913/weights/best.onnx' (11.1 MB)
#
# Export complete (0.9s)
# Results saved to /workspace/models/runs_yolov11/output/good/yolo11n-seg.pt---data_split_0.6_0.2_0.2_4---0.913/weights
# ...
