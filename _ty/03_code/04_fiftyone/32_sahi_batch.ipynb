# %%
import fiftyone as fo  

# 加载已存在的数据集  
session = fo.launch_app()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=9644db93-c0f0-412c-8aed-62afbaf3dad3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from pathlib import Path

def fetch_subsequent_dir(data_root: Path, target_subdir_name: Path):
    data_paths = list(data_root.glob(f"*/{target_subdir_name}"))
    # display(data_paths)
    # get sub dir - no target_subdir_name
    subdir_path_list = [data_path.parent for data_path in data_paths]
    # display(subdir_path_list)
    subdir_name_list = [subdir.name for subdir in subdir_path_list]
    # display(subdir_name_list)
    return subdir_path_list, subdir_name_list


# data_root = Path("/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/00_test")
data_root = Path("/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset")
version = "sahi_v1"

target_subdir_name = Path("data")
subdir_path_list, subdir_name_list = fetch_subsequent_dir(data_root, target_subdir_name)
display(subdir_path_list)
display(subdir_name_list)
len(subdir_path_list), len(subdir_name_list)
# Out:
# [PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0726-0809_13_ok'),
#  PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/sw1_0605-0613_07_ok'),
#  PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0809-0823_34_ok'),
#  PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0710-0726_36_ok'),
#  PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0605-0621_40_ok'),
#  PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0809-0823_10_ok'),
#  PosixPath('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0726-0809_11_ok')]
# ['ms2_0726-0809_13_ok',
#  'sw1_0605-0613_07_ok',
#  'ms1_0809-0823_34_ok',
#  'ms1_0710-0726_36_ok',
#  'ms1_0605-0621_40_ok',
#  'ms2_0809-0823_10_ok',
#  'ms1_0726-0809_11_ok']
# (7, 7)

# %% [markdown]
# ### 使用模型推理---sahi小图

# %%
from sahi import AutoDetectionModel
from sahi.predict import get_prediction, get_sliced_prediction

ckpt_path = "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/02_models/best_models/04_swd_hbb/model_v2_4datasets_noAug_seed0_yolo11s_data_split_custom_8.pt"

detection_model = AutoDetectionModel.from_pretrained(
    model_type='yolov8',
    model_path=ckpt_path,
    confidence_threshold=0.1, ## same as the default value for our base model
    image_size=640,
    device="cuda", # or 'cuda'
)

# 定义一个函数来预测切片结果
def predict_with_slicing(sample, label_field, **kwargs):
    result = get_sliced_prediction(
        sample.filepath, detection_model, verbose=0, **kwargs
    )
    sample[label_field] = fo.Detections(detections=result.to_fiftyone_detections())

# %%
import fiftyone as fo  
import fiftyone.utils.coco as fouc
from pathlib import Path

count = 0
for subdir_path, subdir_name in zip(subdir_path_list, subdir_name_list):
    # 第二次退出
    # if count >= 2:
    #     break
    # count += 1
    print(f"Processing subdir: {subdir_name},{subdir_path}")
    if f"{subdir_name}_{version}" in fo.list_datasets():
        fo.delete_dataset(f"{subdir_name}_{version}") 
    dataset = fo.Dataset.from_images_dir(  
        str(subdir_path / "data"),
        name=f"{subdir_name}_{version}"  
    ) 

    # 添加COCO标签到现有数据集  
    fouc.add_coco_labels(  
        dataset,   
        label_field="ground_truth",  # 存储标签的字段名  
        labels_or_path=f"{subdir_path}/org_label_no_overlap.json",  # COCO JSON文件路径  
        categories={1: "swd"},  # 可选：类别信息，会自动从JSON中提取  
        label_type="detections"  # 标签类型：detections, segmentations, keypoints  
    )

    kwargs = {"overlap_height_ratio": 0.2, "overlap_width_ratio": 0.2}

    for sample in dataset.iter_samples(progress=True, autosave=True):
        predict_with_slicing(sample, label_field="small_slices", slice_height=640, slice_width=640, **kwargs)
    # break
# Out:
# Processing subdir: ms2_0726-0809_13_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0726-0809_13_ok
#  100% |█████████████████| 279/279 [29.8ms elapsed, 0s remaining, 9.4K samples/s]
# Computing metadata...
#  100% |█████████████████| 279/279 [41.4ms elapsed, 0s remaining, 6.7K samples/s]
#  100% |█████████████████| 279/279 [6.6m elapsed, 0s remaining, 0.7 samples/s]
# Processing subdir: sw1_0605-0613_07_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/sw1_0605-0613_07_ok
#  100% |█████████████████████| 6/6 [8.5ms elapsed, 0s remaining, 709.0 samples/s]
# Computing metadata...
#  100% |█████████████████████| 6/6 [4.4ms elapsed, 0s remaining, 1.4K samples/s]
#  100% |█████████████████████| 6/6 [8.4s elapsed, 0s remaining, 0.7 samples/s]
# Processing subdir: ms1_0809-0823_34_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0809-0823_34_ok
#  100% |█████████████████| 323/323 [30.4ms elapsed, 0s remaining, 10.6K samples/s]
# Computing metadata...
#  100% |█████████████████| 323/323 [50.2ms elapsed, 0s remaining, 6.4K samples/s]
#  100% |█████████████████| 323/323 [7.7m elapsed, 0s remaining, 0.7 samples/s]
# Processing subdir: ms1_0710-0726_36_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0710-0726_36_ok
#  100% |█████████████████| 471/471 [46.6ms elapsed, 0s remaining, 10.1K samples/s]
# Computing metadata...
#  100% |█████████████████| 471/471 [64.0ms elapsed, 0s remaining, 7.4K samples/s]
#  100% |█████████████████| 471/471 [11.2m elapsed, 0s remaining, 0.7 samples/s]
# Processing subdir: ms1_0605-0621_40_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0605-0621_40_ok
#  100% |█████████████████| 243/243 [26.7ms elapsed, 0s remaining, 9.1K samples/s]
# Computing metadata...
#  100% |█████████████████| 243/243 [40.3ms elapsed, 0s remaining, 6.0K samples/s]
#  100% |█████████████████| 243/243 [5.9m elapsed, 0s remaining, 0.7 samples/s]
# Processing subdir: ms2_0809-0823_10_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0809-0823_10_ok
#  100% |█████████████████| 578/578 [154.6ms elapsed, 0s remaining, 3.8K samples/s]
# Computing metadata...
#  100% |█████████████████| 578/578 [87.2ms elapsed, 0s remaining, 6.6K samples/s]
#  100% |█████████████████| 578/578 [13.8m elapsed, 0s remaining, 0.6 samples/s]
# Processing subdir: ms1_0726-0809_11_ok,/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0726-0809_11_ok
#  100% |█████████████████| 464/464 [52.2ms elapsed, 0s remaining, 8.9K samples/s]
# Computing metadata...
#  100% |█████████████████| 464/464 [73.7ms elapsed, 0s remaining, 6.3K samples/s]
#  100% |█████████████████| 464/464 [11.9m elapsed, 0s remaining, 0.6 samples/s]

# %%
for subdir_path in subdir_path_list:
    print(subdir_path) 
for subdir_name in subdir_name_list:
    print(subdir_name)
# Out:
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0726-0809_13_ok
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/sw1_0605-0613_07_ok
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0809-0823_34_ok
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0710-0726_36_ok
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0605-0621_40_ok
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0809-0823_10_ok
# /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0726-0809_11_ok
# ms2_0726-0809_13_ok
# sw1_0605-0613_07_ok
# ms1_0809-0823_34_ok
# ms1_0710-0726_36_ok
# ms1_0605-0621_40_ok
# ms2_0809-0823_10_ok
# ms1_0726-0809_11_ok

# %%
subdir_path_list2 = [
    "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms2_0726-0809_13_ok",
    "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/sw1_0605-0613_07_ok",
    # "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0809-0823_34_ok",
    # "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/03_16mp_fiftyone_dataset/ms1_0710-0726_36_ok",
]
subdir_name_list2 = [
    "ms2_0726-0809_13_ok_sahi_v1",
    "sw1_0605-0613_07_ok_sahi_v1",
    # "ms1_0809-0823_34_ok_sahi_v1",
    # "ms1_0710-0726_36_ok_sahi_v1",
]

# for subdir_path, subdir_name in zip(subdir_path_list2, subdir_name_list2):
#     small_slice_results = session.view.evaluate_detections("small_slices", gt_field="ground_truth", eval_key="eval_small_slices")
#     print(f"{subdir_name} Small slice results:")
#     small_slice_results.print_report()

# %%
import fiftyone as fo
from fiftyone import ViewField as F

# 定义不同的置信度阈值
confidence_thresholds = [
                            0.5, 0.6, 0.7, 0.8, 0.85,
                            0.9, 0.91, 0.92, 0.93
                        ]

# for subdir_path, subdir_name in zip(subdir_path_list2, subdir_name_list2):
for subdir_path, subdir_name in zip(subdir_path_list, subdir_name_list):
    subdir_name = f"{subdir_name}_{version}"
    print(f"\n=== {subdir_name} ===")

    dataset = fo.load_dataset(subdir_name)

    print("GT 框数量:", dataset.count("ground_truth.detections"))
    print("预测框数量:", dataset.count("small_slices.detections"))


    # 创建不同置信度的视图
    views = {}
    results = {}

    for threshold in confidence_thresholds:
        views[threshold] = dataset.filter_labels(
            "small_slices", F("confidence") > threshold, only_matches=False
        )

        eval_key = f"eval_conf_{int(threshold * 100)}"
        results[threshold] = views[threshold].evaluate_detections(
            "small_slices", gt_field="ground_truth", compute_mAP=True, 
            eval_key=eval_key
        )

    # 打印比较报告
    print(f"\n{subdir_name} 详细比较:")
    print("置信度 | mAP    | 精确度 | 召回率 | 预测数")
    print("-" * 50)

    for threshold in confidence_thresholds:
        res = results[threshold]
        
        pred_count = views[threshold].count("small_slices.detections")
        print(
            f"{threshold:6.2f} | {res.mAP():6.4f} | {res.metrics()['precision']:6.4f} | {res.metrics()['recall']:6.4f} | {pred_count:6d}"
        )
# Out:
# === ms2_0726-0809_13_ok_sahi_v1 ===
# GT 框数量: 531
# 预测框数量: 3125
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 227.4 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [1.0s elapsed, 0s remaining, 291.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 253.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 303.8 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 262.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [1.1s elapsed, 0s remaining, 306.0 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 247.2 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [1.0s elapsed, 0s remaining, 298.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.1s elapsed, 0s remaining, 273.6 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 314.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [900.2ms elapsed, 0s remaining, 309.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [850.1ms elapsed, 0s remaining, 328.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [952.7ms elapsed, 0s remaining, 292.8 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [785.7ms elapsed, 0s remaining, 355.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [649.2ms elapsed, 0s remaining, 429.8 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [679.1ms elapsed, 0s remaining, 410.8 samples/s]
# Evaluating detections...
#  100% |█████████████████| 279/279 [535.9ms elapsed, 0s remaining, 520.6 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 279/279 [561.9ms elapsed, 0s remaining, 496.5 samples/s]
#
# ms2_0726-0809_13_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.4712 | 0.2383 | 0.9171 |   2044
#   0.60 | 0.4700 | 0.2620 | 0.9077 |   1840
#   0.70 | 0.4663 | 0.2938 | 0.8908 |   1610
#   0.80 | 0.4593 | 0.3494 | 0.8625 |   1311
#   0.85 | 0.4511 | 0.4040 | 0.8362 |   1099
#   0.90 | 0.3918 | 0.5259 | 0.6874 |    694
#   0.91 | 0.3239 | 0.5641 | 0.5386 |    507
#   0.92 | 0.2258 | 0.6312 | 0.3352 |    282
#   0.93 | 0.0907 | 0.7568 | 0.1055 |     74
#
# === sw1_0605-0613_07_ok_sahi_v1 ===
# GT 框数量: 6
# 预测框数量: 37
# Evaluating detections...
#  100% |█████████████████████| 6/6 [14.1ms elapsed, 0s remaining, 426.6 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [16.2ms elapsed, 0s remaining, 371.0 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.3ms elapsed, 0s remaining, 391.2 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [17.5ms elapsed, 0s remaining, 342.5 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.1ms elapsed, 0s remaining, 396.2 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [17.5ms elapsed, 0s remaining, 342.4 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [14.4ms elapsed, 0s remaining, 417.6 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [17.0ms elapsed, 0s remaining, 352.0 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.6ms elapsed, 0s remaining, 385.3 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [18.4ms elapsed, 0s remaining, 326.6 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.9ms elapsed, 0s remaining, 463.7 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [15.4ms elapsed, 0s remaining, 388.8 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [11.1ms elapsed, 0s remaining, 539.6 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [14.0ms elapsed, 0s remaining, 427.5 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [11.1ms elapsed, 0s remaining, 541.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [11.9ms elapsed, 0s remaining, 505.1 samples/s]
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.0ms elapsed, 0s remaining, 500.4 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 6/6 [15.7ms elapsed, 0s remaining, 383.2 samples/s]
#
# sw1_0605-0613_07_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.8192 | 0.2222 | 1.0000 |     27
#   0.60 | 0.8192 | 0.2500 | 1.0000 |     24
#   0.70 | 0.8192 | 0.2727 | 1.0000 |     22
#   0.80 | 0.8192 | 0.3158 | 1.0000 |     19
#   0.85 | 0.8192 | 0.3529 | 1.0000 |     17
#   0.90 | 0.7519 | 0.5000 | 0.8333 |     10
#   0.91 | 0.7519 | 0.7143 | 0.8333 |      7
#   0.92 | 0.5050 | 1.0000 | 0.5000 |      3
#   0.93 | 0.1683 | 1.0000 | 0.1667 |      1
#
# === ms1_0809-0823_34_ok_sahi_v1 ===
# GT 框数量: 495
# 预测框数量: 4856
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.9s elapsed, 0s remaining, 200.2 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.4s elapsed, 0s remaining, 237.8 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.9s elapsed, 0s remaining, 195.7 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.4s elapsed, 0s remaining, 227.6 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.9s elapsed, 0s remaining, 204.6 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.6s elapsed, 0s remaining, 205.3 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.5s elapsed, 0s remaining, 212.4 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.4s elapsed, 0s remaining, 241.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.7s elapsed, 0s remaining, 217.8 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.4s elapsed, 0s remaining, 245.8 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.4s elapsed, 0s remaining, 255.1 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.2s elapsed, 0s remaining, 270.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [1.3s elapsed, 0s remaining, 234.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.2s elapsed, 0s remaining, 286.3 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [981.7ms elapsed, 0s remaining, 329.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [1.2s elapsed, 0s remaining, 270.4 samples/s]
# Evaluating detections...
#  100% |█████████████████| 323/323 [717.8ms elapsed, 0s remaining, 450.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 323/323 [769.5ms elapsed, 0s remaining, 419.7 samples/s]
#
# ms1_0809-0823_34_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.3314 | 0.1451 | 0.9535 |   3254
#   0.60 | 0.3308 | 0.1568 | 0.9455 |   2984
#   0.70 | 0.3294 | 0.1718 | 0.9374 |   2701
#   0.80 | 0.3290 | 0.2004 | 0.9313 |   2300
#   0.85 | 0.3278 | 0.2250 | 0.9232 |   2031
#   0.90 | 0.3208 | 0.2933 | 0.8869 |   1497
#   0.91 | 0.3059 | 0.3220 | 0.8242 |   1267
#   0.92 | 0.2596 | 0.3489 | 0.6505 |    923
#   0.93 | 0.1670 | 0.4009 | 0.3515 |    434
#
# === ms1_0710-0726_36_ok_sahi_v1 ===
# GT 框数量: 1232
# 预测框数量: 8579
# Evaluating detections...
#  100% |█████████████████| 471/471 [4.4s elapsed, 0s remaining, 78.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.6s elapsed, 0s remaining, 147.5 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [4.2s elapsed, 0s remaining, 79.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.7s elapsed, 0s remaining, 145.5 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [3.9s elapsed, 0s remaining, 99.7 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.9s elapsed, 0s remaining, 143.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [3.5s elapsed, 0s remaining, 108.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.7s elapsed, 0s remaining, 149.8 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [3.3s elapsed, 0s remaining, 105.8 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.6s elapsed, 0s remaining, 156.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [2.7s elapsed, 0s remaining, 164.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.5s elapsed, 0s remaining, 185.5 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [2.6s elapsed, 0s remaining, 157.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.3s elapsed, 0s remaining, 193.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [2.3s elapsed, 0s remaining, 210.3 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.1s elapsed, 0s remaining, 208.4 samples/s]
# Evaluating detections...
#  100% |█████████████████| 471/471 [1.9s elapsed, 0s remaining, 256.2 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 471/471 [2.1s elapsed, 0s remaining, 213.5 samples/s]
#
# ms1_0710-0726_36_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.7047 | 0.2075 | 0.9878 |   5864
#   0.60 | 0.7047 | 0.2272 | 0.9878 |   5356
#   0.70 | 0.7047 | 0.2536 | 0.9870 |   4795
#   0.80 | 0.7042 | 0.3006 | 0.9854 |   4039
#   0.85 | 0.7042 | 0.3486 | 0.9830 |   3474
#   0.90 | 0.6884 | 0.4595 | 0.9432 |   2529
#   0.91 | 0.6657 | 0.5121 | 0.8929 |   2148
#   0.92 | 0.6070 | 0.6135 | 0.7873 |   1581
#   0.93 | 0.4456 | 0.7341 | 0.5422 |    910
#
# === ms1_0605-0621_40_ok_sahi_v1 ===
# GT 框数量: 850
# 预测框数量: 4199
# Evaluating detections...
#  100% |█████████████████| 243/243 [2.2s elapsed, 0s remaining, 80.3 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.6s elapsed, 0s remaining, 102.6 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [2.0s elapsed, 0s remaining, 87.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.4s elapsed, 0s remaining, 129.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [2.1s elapsed, 0s remaining, 92.8 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.5s elapsed, 0s remaining, 123.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [1.9s elapsed, 0s remaining, 98.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.4s elapsed, 0s remaining, 129.2 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [1.8s elapsed, 0s remaining, 103.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.4s elapsed, 0s remaining, 133.0 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [1.5s elapsed, 0s remaining, 107.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.2s elapsed, 0s remaining, 139.3 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [1.5s elapsed, 0s remaining, 109.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.2s elapsed, 0s remaining, 141.7 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [1.0s elapsed, 0s remaining, 195.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [1.0s elapsed, 0s remaining, 219.0 samples/s]
# Evaluating detections...
#  100% |█████████████████| 243/243 [941.7ms elapsed, 0s remaining, 258.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 243/243 [808.1ms elapsed, 0s remaining, 300.7 samples/s]
#
# ms1_0605-0621_40_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.6104 | 0.2975 | 0.9576 |   2736
#   0.60 | 0.6071 | 0.3226 | 0.9435 |   2486
#   0.70 | 0.6007 | 0.3569 | 0.9282 |   2211
#   0.80 | 0.5912 | 0.4241 | 0.9000 |   1804
#   0.85 | 0.5748 | 0.4822 | 0.8624 |   1520
#   0.90 | 0.5040 | 0.6078 | 0.7365 |   1030
#   0.91 | 0.4359 | 0.6366 | 0.6224 |    831
#   0.92 | 0.2607 | 0.6552 | 0.3576 |    464
#   0.93 | 0.0799 | 0.7636 | 0.0988 |    110
#
# === ms2_0809-0823_10_ok_sahi_v1 ===
# GT 框数量: 682
# 预测框数量: 6396
# Evaluating detections...
#  100% |█████████████████| 578/578 [2.1s elapsed, 0s remaining, 258.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.7s elapsed, 0s remaining, 339.6 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [2.1s elapsed, 0s remaining, 307.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.8s elapsed, 0s remaining, 341.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.9s elapsed, 0s remaining, 330.7 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.7s elapsed, 0s remaining, 347.9 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.7s elapsed, 0s remaining, 387.3 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.6s elapsed, 0s remaining, 373.7 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.6s elapsed, 0s remaining, 427.1 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.5s elapsed, 0s remaining, 405.3 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.3s elapsed, 0s remaining, 443.7 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.3s elapsed, 0s remaining, 475.4 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.2s elapsed, 0s remaining, 502.1 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.4s elapsed, 0s remaining, 485.8 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.1s elapsed, 0s remaining, 548.1 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.2s elapsed, 0s remaining, 502.6 samples/s]
# Evaluating detections...
#  100% |█████████████████| 578/578 [1.1s elapsed, 0s remaining, 536.1 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 578/578 [1.0s elapsed, 0s remaining, 581.6 samples/s]
#
# ms2_0809-0823_10_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.7627 | 0.1779 | 0.9663 |   3704
#   0.60 | 0.7625 | 0.2037 | 0.9648 |   3230
#   0.70 | 0.7606 | 0.2433 | 0.9560 |   2680
#   0.80 | 0.7573 | 0.3144 | 0.9428 |   2045
#   0.85 | 0.7546 | 0.3900 | 0.9384 |   1641
#   0.90 | 0.7347 | 0.5553 | 0.8988 |   1104
#   0.91 | 0.6992 | 0.6217 | 0.8387 |    920
#   0.92 | 0.6187 | 0.7341 | 0.7126 |    662
#   0.93 | 0.4007 | 0.8841 | 0.4472 |    345
#
# === ms1_0726-0809_11_ok_sahi_v1 ===
# GT 框数量: 1037
# 预测框数量: 6124
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.6s elapsed, 0s remaining, 168.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [2.0s elapsed, 0s remaining, 217.9 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.6s elapsed, 0s remaining, 171.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [2.2s elapsed, 0s remaining, 211.1 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.6s elapsed, 0s remaining, 155.0 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [2.1s elapsed, 0s remaining, 207.3 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.3s elapsed, 0s remaining, 204.3 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [2.0s elapsed, 0s remaining, 217.4 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.2s elapsed, 0s remaining, 220.4 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [2.0s elapsed, 0s remaining, 217.5 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [1.9s elapsed, 0s remaining, 252.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [1.8s elapsed, 0s remaining, 240.5 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [1.9s elapsed, 0s remaining, 258.5 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [2.0s elapsed, 0s remaining, 239.0 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [1.5s elapsed, 0s remaining, 299.9 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [1.6s elapsed, 0s remaining, 282.0 samples/s]
# Evaluating detections...
#  100% |█████████████████| 464/464 [1.3s elapsed, 0s remaining, 404.7 samples/s]
# Performing IoU sweep...
#  100% |█████████████████| 464/464 [1.2s elapsed, 0s remaining, 372.3 samples/s]
#
# ms1_0726-0809_11_ok_sahi_v1 详细比较:
# 置信度 | mAP    | 精确度 | 召回率 | 预测数
# --------------------------------------------------
#   0.50 | 0.6669 | 0.2504 | 0.9952 |   4121
#   0.60 | 0.6669 | 0.2757 | 0.9932 |   3736
#   0.70 | 0.6648 | 0.3105 | 0.9894 |   3304
#   0.80 | 0.6639 | 0.3732 | 0.9836 |   2733
#   0.85 | 0.6635 | 0.4307 | 0.9826 |   2366
#   0.90 | 0.6437 | 0.5712 | 0.9441 |   1714
#   0.91 | 0.5873 | 0.6090 | 0.8486 |   1445
#   0.92 | 0.4487 | 0.6551 | 0.6210 |    983
#   0.93 | 0.1963 | 0.6935 | 0.2488 |    372
