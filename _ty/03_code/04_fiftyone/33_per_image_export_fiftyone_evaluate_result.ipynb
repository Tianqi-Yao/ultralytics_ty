# %% [markdown]
# ### Per-image 评估导出

# %%
# %%
from __future__ import annotations

from pathlib import Path
from collections import Counter
from typing import Dict, Any, List, Optional, Tuple

import pandas as pd
import fiftyone as fo
from fiftyone import ViewField as F

# %% [markdown]
# ### User Config (reuse yours)

# %%
# =========================
# User Config (reuse yours)
# =========================
version = "sahi_null_v2"  # 你已有
confidence_thresholds = [0.5, 0.6, 0.7, 0.8, 0.85, 0.9, 0.91, 0.92, 0.93]  # 你已有
# ckpt_paths = ckpt_paths  # 直接复用你前面定义好的
# 多模型：直接在这里放 .pt
model_root = Path("/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/02_models/best_models/04_swd_hbb") 
model_names = [
    # "a02_yolo11s_custom7_v2-13_7_34_36-40_10-11_8.pt",
    # "a02_yolo11s_custom7_v2-13_7_34_36-40_10-11_4.pt",
    # "a02_yolo11s_custom7_v1-34_36_40_11_-13-10_16.pt",
    # "a02_yolo11s_custom7_v4-36_40_10_11-7_34-13_16.pt",
    # "a02_yolo11s_custom7_v4-36_40_10_11-7_34-13_8.pt",
    "a03_yolo11s_custom7null_cv1_ms2_0809-0823_10_ok_16.pt",
    "a03_yolo11n_custom7null_cv1_ms2_0809-0823_10_ok_8.pt",
    "a03_yolo11s_custom7null_cv1_ms2_0809-0823_10_ok_8.pt",
    "a03_yolo11s_custom7null_cv1_ms2_0809-0823_10_ok_4.pt",
    "a04_yolo11s_custom7null_cv1_ms2_0809-0823_10_ok_16.pt",
    "a04_yolo11n_custom7null_cv1_ms2_0809-0823_10_ok_4.pt",
    "a04_yolo11n_custom7null_cv1_ms2_0809-0823_10_ok_8.pt",
    "a04_yolo11s_custom7null_cv1_ms2_0809-0823_10_ok_8.pt",
]

ckpt_paths = [str(model_root / name) for name in model_names]
out_dir = Path("./_eval_exports_per_images") / version
out_dir.mkdir(parents=True, exist_ok=True)

GT_FIELD = "ground_truth"

# 你想更“hit-based”的话，把 IoU 放低一些
IOU_THR = 0.50  # 可改 0.05 / 0.01

# %% [markdown]
# ### Helpers

# %%
# =========================
# Helpers
# =========================
import re
import pandas as pd
from pathlib import Path
import numpy as np
from pydash import min_

def parse_dt_focus(fp: str, year=2024):
    m = re.search(r"(\d{4})_(\d{4})_(\d+)\.(jpg|png)$", Path(fp).name)
    if not m:
        return pd.NaT, None

    mmdd, hhmm, focus = m.group(1), m.group(2), int(m.group(3))
    return (
        pd.Timestamp(
            year,
            int(mmdd[:2]),
            int(mmdd[2:]),
            int(hhmm[:2]),
            int(hhmm[2:]),
        ),
        focus,
    )

def model_tag_from_path(p: str) -> str:
    return Path(p).stem

def safe_slug(s: str) -> str:
    # 文件名安全：避免奇怪字符
    return s.replace("/", "_").replace(" ", "_").replace("-", "__")

def _safe_dets(sample: fo.Sample, field: str):
    obj = sample.get_field(field)
    if obj is None:
        return []
    dets = getattr(obj, "detections", None)
    return dets if dets else []

def _get_eval_type(det: fo.Detection, eval_key: str) -> Optional[str]:
    """
    读取 detection 上由 evaluate_detections 写入的 tp/fp/fn 类型。
    不同 FO 版本可能写入结构略不同，这里做兜底。
    """
    try:
        v = det.get(eval_key, None)
    except Exception:
        v = None

    if isinstance(v, dict) and "type" in v:
        return v["type"]
    if isinstance(v, str):
        return v

    try:
        ev = det.get("eval", None)
    except Exception:
        ev = None
    if isinstance(ev, dict):
        vv = ev.get(eval_key, None)
        if isinstance(vv, dict) and "type" in vv:
            return vv["type"]

    return None



def export_image_level_rows(
    view: fo.DatasetView,
    dataset_name: str,
    subdir_name: str,
    subdir_path: str,
    model_tag: str,
    ckpt_path: str,
    pred_field: str,
    conf_thr: float,
    eval_key: str,
) -> pd.DataFrame:
    rows: List[Dict[str, Any]] = []

    for s in view.iter_samples(progress=True):
        gt_dets = _safe_dets(s, GT_FIELD)
        

        # 获取每个检测的概率信息  
        pred_dets = _safe_dets(s, pred_field)  
        confidences = [d.confidence for d in pred_dets if d.confidence is not None]  
        ious = [getattr(d, f"{eval_key}_iou") for d in pred_dets   
                if hasattr(d, f"{eval_key}_iou") and getattr(d, f"{eval_key}_iou") is not None]

        tp_img = getattr(s, f"{eval_key}_tp", 0)  
        fp_img = getattr(s, f"{eval_key}_fp", 0)   
        fn_img = getattr(s, f"{eval_key}_fn", 0)
        gt_count_img = len(gt_dets)
        pred_count_img = len(pred_dets)

        # 计算统计值
        q1_confidence = np.percentile(confidences, 25) if confidences else 0.0
        q3_confidence = np.percentile(confidences, 75) if confidences else 0.0
        iqr_confidence = q3_confidence - q1_confidence
        std_confidence = np.std(confidences) if confidences else 0.0
        median_confidence = np.median(confidences) if confidences else 0.0
        avg_confidence = np.mean(confidences) if confidences else 0.0  
        max_confidence = np.max(confidences) if confidences else 0.0
        min_confidence = np.min(confidences) if confidences else 0.0

        q1_iou = np.percentile(ious, 25) if ious else 0.0
        q3_iou = np.percentile(ious, 75) if ious else 0.0
        iqr_iou = q3_iou - q1_iou
        std_iou = np.std(ious) if ious else 0.0
        median_iou = np.median(ious) if ious else 0.0
        avg_iou = np.mean(ious) if ious else 0.0  
        max_iou = np.max(ious) if ious else 0.0
        min_iou = np.min(ious) if ious else 0.0

        pred_gt_ratio = (
            pred_count_img / gt_count_img
            if gt_count_img > 0 else np.nan
        )
        tp_ratio = (
            tp_img / gt_count_img
            if gt_count_img > 0 else np.nan
        )
        fp_ratio = (
            fp_img / pred_count_img
            if pred_count_img > 0 else np.nan
        )
        fn_ratio = (
            fn_img / gt_count_img
            if gt_count_img > 0 else np.nan
        )


        # 基于 IoU 匹配的指标  
        gt_present = gt_count_img > 0
        pred_present = pred_count_img > 0

        hit_img = int(gt_present and pred_present)
        miss_img = int(gt_present and not pred_present)
        false_alarm_img = int(not gt_present and pred_present)
        correct_reject_img = int(not gt_present and not pred_present)

        # hit_img = int(tp_img > 0)  # 至少有一个真正的 IoU 匹配，boolean 转 int
        # miss_img = int(fn_img > 0)  # 有 GT 但没有匹配的预测, boolean 转 int
        # false_alarm_img = int(fp_img > 0)  # 有预测但没有匹配的 GT , boolean 转 int
        # correct_reject_img = int(gt_count_img == 0 and pred_count_img == 0)  # 没有 GT 也没有预测 , boolean 转 int

        # 解析时间和焦点（如果需要）
        capture_dt, focus = parse_dt_focus(s.filepath)
        if pd.isna(capture_dt):
            capture_date = None
            capture_time = None
        else:
            capture_date = capture_dt.date()     # datetime.date
            capture_time = capture_dt.time()     # datetime.time


        rows.append({
            # --- identity ---
            "dataset_name": dataset_name,
            "subdir_name": subdir_name,
            "subdir_path": subdir_path,
            "version": version,
            "model_tag": model_tag,
            "ckpt_path": ckpt_path,
            "pred_field": pred_field,
            "confidence_threshold": conf_thr,
            "iou_threshold": IOU_THR,

            # --- sample ---
            "sample_id": str(s.id),
            "filepath": s.filepath,
            "capture_datetime": capture_dt,
            "capture_date": capture_date,
            "capture_time": capture_time,
            "focus": focus,

            # --- counts ---
            "gt_count_img": gt_count_img,
            "pred_count_img": pred_count_img,
            "tp_img": tp_img,
            "fp_img": fp_img,
            "fn_img": fn_img,
            "tp_ratio": tp_ratio,
            "fp_ratio": fp_ratio,
            "fn_ratio": fn_ratio,
            "pred_gt_ratio": pred_gt_ratio,
            "hit_img": hit_img,  
            "miss_img": miss_img,  
            "false_alarm_img": false_alarm_img,  
            "correct_reject_img": correct_reject_img, 
            
            # --- stats ---
            "avg_confidence": avg_confidence,  
            "max_confidence": max_confidence,  
            "min_confidence": min_confidence,
            "std_confidence": std_confidence,
            "median_confidence": median_confidence,
            "q1_confidence": q1_confidence,
            "q3_confidence": q3_confidence,
            "iqr_confidence": iqr_confidence,
            "avg_iou": avg_iou,  
            "max_iou": max_iou,  
            "min_iou": min_iou,
            "std_iou": std_iou,
            "median_iou": median_iou,
            "q1_iou": q1_iou,
            "q3_iou": q3_iou,
            "iqr_iou": iqr_iou,

            # full data
            "confidences": confidences,
            "ious": ious,
        })

    return pd.DataFrame(rows)

def summarize_from_image_df(img_df: pd.DataFrame) -> Dict[str, Any]:  
    # 全局汇总（IoU-based）  
    tp = int(img_df["tp_img"].sum())  
    fp = int(img_df["fp_img"].sum())  
    fn = int(img_df["fn_img"].sum())  

    gt_total = int(img_df["gt_count_img"].sum())  
    pred_total = int(img_df["pred_count_img"].sum())  

    # IoU-match based precision/recall  
    precision = tp / (tp + fp) if (tp + fp) > 0 else float("nan")  
    recall = tp / (tp + fn) if (tp + fn) > 0 else float("nan")  
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else float("nan")  

    # 使用 IoU-based 图像级别指标  
    hit_img = int(img_df["hit_img"].sum())  
    miss_img = int(img_df["miss_img"].sum())  
    false_alarm_img = int(img_df["false_alarm_img"].sum())  
    correct_reject_img = int(img_df["correct_reject_img"].sum())  

    # 图像级别的 recall/precision  
    denom_pos = hit_img + miss_img  
    img_recall = hit_img / denom_pos if denom_pos > 0 else float("nan")  

    denom_predpos = hit_img + false_alarm_img  
    img_precision = hit_img / denom_predpos if denom_predpos > 0 else float("nan")  

    img_f1 = (2 * img_precision * img_recall / (img_precision + img_recall)) if (img_precision + img_recall) > 0 else float("nan")  

    return {  
        "gt_total": gt_total,  
        "pred_total": pred_total,  
        "tp_total": tp,  
        "fp_total": fp,  
        "fn_total": fn,  
        "precision_iou": precision,  
        "recall_iou": recall,  
        "f1_iou": f1,  

        # 更新为 IoU-based 图像级别指标  
        "hit_images": hit_img,  
        "miss_images": miss_img,  
        "false_alarm_images": false_alarm_img,  
        "correct_reject_images": correct_reject_img,  
        "img_precision": img_precision,  
        "img_recall": img_recall,  
        "img_f1": img_f1,  
        "hit_rate_img": float(img_df["hit_img"].mean()) if len(img_df) else float("nan"),  
    }

def fetch_subsequent_dir(data_root: Path, target_subdir_name: Path) -> Tuple[List[Path], List[str]]:
    data_paths = list(data_root.glob(f"*/{target_subdir_name}"))
    subdir_path_list = [data_path.parent for data_path in data_paths]
    subdir_name_list = [subdir.name for subdir in subdir_path_list]
    return subdir_path_list, subdir_name_list

# %%
# %% =========================
# 3) Discover subdirs
# =========================
data_root = Path("/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone")
target_subdir_name = Path("data")

subdir_path_list, subdir_name_list = fetch_subsequent_dir(data_root, target_subdir_name)
print("Found subdirs:", len(subdir_name_list))
for n, p in zip(subdir_name_list, subdir_path_list):
    print(n, p)
# Out:
# Found subdirs: 7
# ms2_0726-0809_13_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/ms2_0726-0809_13_ok
# sw1_0605-0613_07_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/sw1_0605-0613_07_ok
# ms1_0809-0823_34_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/ms1_0809-0823_34_ok
# ms1_0710-0726_36_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/ms1_0710-0726_36_ok
# ms1_0605-0621_40_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/ms1_0605-0621_40_ok
# ms2_0809-0823_10_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/ms2_0809-0823_10_ok
# ms1_0726-0809_11_ok /home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a02_16mp_2024_datasets_fiftyone/ms1_0726-0809_11_ok

# %% [markdown]
# ### Batch Run

# %%
# =========================
# Batch Run
# =========================
summary_rows: List[Dict[str, Any]] = []

# 复用你前面 fetch_subsequent_dir 得到的 subdir_name_list / subdir_path_list
for subdir_path, subdir_name in zip(subdir_path_list, subdir_name_list):
    dataset_name = f"{version}_{subdir_name}"
    ds = fo.load_dataset(dataset_name)
    print(f"processing: {dataset_name}")
    ds.delete_evaluations()  


    for ckpt_path in ckpt_paths:
        model_tag = model_tag_from_path(ckpt_path)
        pred_field = f"small_slices_{model_tag}"

        if pred_field not in ds.get_field_schema():
            print(f"[WARN] Missing pred_field={pred_field} in dataset={dataset_name}, skip.")
            continue

        for thr in confidence_thresholds:
            # --- make view (thresholded) ---
            view = ds.filter_labels(pred_field, F("confidence") > thr, only_matches=False)

            # --- run eval (writes tp/fp/fn info onto detections) ---
            eval_key = f"eval_img__{safe_slug(model_tag)}__c{int(thr*100)}__iou{int(IOU_THR*100)}"
            view.evaluate_detections(
                pred_field,
                gt_field=GT_FIELD,
                eval_key=eval_key,
                iou=IOU_THR,
                compute_mAP=False,
            )

            # --- export per-image table ---
            img_df = export_image_level_rows(
                view=view,
                dataset_name=dataset_name,
                subdir_name=subdir_name,
                subdir_path=str(subdir_path),
                model_tag=model_tag,
                ckpt_path=ckpt_path,
                pred_field=pred_field,
                conf_thr=thr,
                eval_key=eval_key,
            )

            out_img = out_dir / safe_slug(dataset_name) / f"image_level_{safe_slug(model_tag)}__c{int(thr*100)}__iou{int(IOU_THR*100)}.csv"
            out_img.parent.mkdir(parents=True, exist_ok=True)
            img_df.to_csv(out_img, index=False)
            print("[SAVE]", out_img)

            # --- append summary row from per-image ---
            srow = {
                "dataset_name": dataset_name,
                "subdir_name": subdir_name,
                "subdir_path": str(subdir_path),
                "version": version,
                "model_tag": model_tag,
                "ckpt_path": ckpt_path,
                "pred_field": pred_field,
                "confidence_threshold": thr,
                "iou_threshold": IOU_THR,
            }
            srow.update(summarize_from_image_df(img_df))
            summary_rows.append(srow)
    #         break
    #     break
    # break

# export global summary
summary_df = pd.DataFrame(summary_rows)
out_sum = out_dir / f"per_image_summary__{version}__iou{int(IOU_THR*100)}.csv"
summary_df.to_csv(out_sum, index=False)
print("Saved summary:", out_sum)
print("Summary shape:", summary_df.shape)
# Out:
# processing: sahi_null_v2_ms2_0726-0809_13_ok
# Evaluating detections...
#  100% |█████████████████| 279/279 [894.9ms elapsed, 0s remaining, 311.8 samples/s]
#  100% |█████████████████| 279/279 [1.6s elapsed, 0s remaining, 235.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [928.9ms elapsed, 0s remaining, 300.4 samples/s]
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 231.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [930.4ms elapsed, 0s remaining, 299.9 samples/s]
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 192.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [954.7ms elapsed, 0s remaining, 292.2 samples/s]
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 188.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [934.7ms elapsed, 0s remaining, 298.5 samples/s]
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 231.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [772.7ms elapsed, 0s remaining, 361.1 samples/s]
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 230.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [876.3ms elapsed, 0s remaining, 318.4 samples/s]
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 235.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [569.4ms elapsed, 0s remaining, 490.0 samples/s]
#  100% |█████████████████| 279/279 [1.6s elapsed, 0s remaining, 250.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [490.5ms elapsed, 0s remaining, 568.8 samples/s]
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 213.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 254.6 samples/s]
#  100% |█████████████████| 279/279 [1.9s elapsed, 0s remaining, 209.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 252.2 samples/s]
#  100% |█████████████████| 279/279 [1.9s elapsed, 0s remaining, 205.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 246.5 samples/s]
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 202.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 256.1 samples/s]
#  100% |█████████████████| 279/279 [1.9s elapsed, 0s remaining, 206.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 259.0 samples/s]
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 201.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [987.1ms elapsed, 0s remaining, 282.6 samples/s]
#  100% |█████████████████| 279/279 [1.9s elapsed, 0s remaining, 202.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [889.3ms elapsed, 0s remaining, 313.7 samples/s]
#  100% |█████████████████| 279/279 [1.9s elapsed, 0s remaining, 200.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [761.8ms elapsed, 0s remaining, 366.2 samples/s]
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 216.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [701.4ms elapsed, 0s remaining, 397.8 samples/s]
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 223.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 248.7 samples/s]
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 184.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 247.4 samples/s]
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 182.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 260.3 samples/s]
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 179.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 253.8 samples/s]
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 176.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 258.2 samples/s]
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 180.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 300.2 samples/s]
#  100% |█████████████████| 279/279 [1.9s elapsed, 0s remaining, 186.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [921.5ms elapsed, 0s remaining, 302.8 samples/s]
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 197.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [872.0ms elapsed, 0s remaining, 320.0 samples/s]
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 196.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [874.3ms elapsed, 0s remaining, 319.1 samples/s]
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 197.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 203.9 samples/s]
#  100% |█████████████████| 279/279 [2.4s elapsed, 0s remaining, 160.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.6s elapsed, 0s remaining, 229.6 samples/s]
#  100% |█████████████████| 279/279 [2.4s elapsed, 0s remaining, 160.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.6s elapsed, 0s remaining, 239.5 samples/s]
#  100% |█████████████████| 279/279 [2.5s elapsed, 0s remaining, 156.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 212.0 samples/s]
#  100% |█████████████████| 279/279 [2.5s elapsed, 0s remaining, 124.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.6s elapsed, 0s remaining, 253.9 samples/s]
#  100% |█████████████████| 279/279 [2.5s elapsed, 0s remaining, 158.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 265.3 samples/s]
#  100% |█████████████████| 279/279 [2.5s elapsed, 0s remaining, 157.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 279.8 samples/s]
#  100% |█████████████████| 279/279 [2.4s elapsed, 0s remaining, 157.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.2s elapsed, 0s remaining, 284.6 samples/s]
#  100% |█████████████████| 279/279 [2.4s elapsed, 0s remaining, 175.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.1s elapsed, 0s remaining, 285.9 samples/s]
#  100% |█████████████████| 279/279 [2.3s elapsed, 0s remaining, 177.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 235.9 samples/s]
#  100% |█████████████████| 279/279 [2.7s elapsed, 0s remaining, 136.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 237.1 samples/s]
#  100% |█████████████████| 279/279 [2.7s elapsed, 0s remaining, 134.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 233.5 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 133.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 244.9 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 135.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 208.2 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 133.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 218.9 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 113.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 224.5 samples/s]
#  100% |█████████████████| 279/279 [2.6s elapsed, 0s remaining, 136.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.4s elapsed, 0s remaining, 266.1 samples/s]
#  100% |█████████████████| 279/279 [2.6s elapsed, 0s remaining, 142.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.3s elapsed, 0s remaining, 293.4 samples/s]
#  100% |█████████████████| 279/279 [2.6s elapsed, 0s remaining, 150.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 216.7 samples/s]
#  100% |█████████████████| 279/279 [3.0s elapsed, 0s remaining, 123.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 216.9 samples/s]
#  100% |█████████████████| 279/279 [3.0s elapsed, 0s remaining, 127.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 223.3 samples/s]
#  100% |█████████████████| 279/279 [3.0s elapsed, 0s remaining, 126.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 192.1 samples/s]
#  100% |█████████████████| 279/279 [3.0s elapsed, 0s remaining, 105.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 198.6 samples/s]
#  100% |█████████████████| 279/279 [3.0s elapsed, 0s remaining, 125.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 258.5 samples/s]
#  100% |█████████████████| 279/279 [2.9s elapsed, 0s remaining, 130.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.5s elapsed, 0s remaining, 263.2 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 135.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 272.1 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 135.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.7s elapsed, 0s remaining, 272.3 samples/s]
#  100% |█████████████████| 279/279 [2.8s elapsed, 0s remaining, 133.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.4s elapsed, 0s remaining, 199.8 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 117.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.6s elapsed, 0s remaining, 167.4 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 118.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.4s elapsed, 0s remaining, 201.0 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 118.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.5s elapsed, 0s remaining, 172.4 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 117.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.3s elapsed, 0s remaining, 208.7 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 117.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.3s elapsed, 0s remaining, 177.5 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 117.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 211.4 samples/s]
#  100% |█████████████████| 279/279 [3.3s elapsed, 0s remaining, 118.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.1s elapsed, 0s remaining, 191.0 samples/s]
#  100% |█████████████████| 279/279 [3.2s elapsed, 0s remaining, 118.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [1.8s elapsed, 0s remaining, 247.7 samples/s]
#  100% |█████████████████| 279/279 [3.1s elapsed, 0s remaining, 122.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.7s elapsed, 0s remaining, 156.1 samples/s]
#  100% |█████████████████| 279/279 [3.5s elapsed, 0s remaining, 109.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.7s elapsed, 0s remaining, 187.4 samples/s]
#  100% |█████████████████| 279/279 [3.5s elapsed, 0s remaining, 108.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.7s elapsed, 0s remaining, 189.6 samples/s]
#  100% |█████████████████| 279/279 [3.6s elapsed, 0s remaining, 108.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.7s elapsed, 0s remaining, 158.0 samples/s]
#  100% |█████████████████| 279/279 [3.6s elapsed, 0s remaining, 108.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.5s elapsed, 0s remaining, 192.2 samples/s]
#  100% |█████████████████| 279/279 [3.8s elapsed, 0s remaining, 105.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 208.0 samples/s]
#  100% |█████████████████| 279/279 [3.5s elapsed, 0s remaining, 110.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 183.4 samples/s]
#  100% |█████████████████| 279/279 [3.5s elapsed, 0s remaining, 111.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.0s elapsed, 0s remaining, 225.2 samples/s]
#  100% |█████████████████| 279/279 [3.6s elapsed, 0s remaining, 94.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 279/279 [2.2s elapsed, 0s remaining, 226.4 samples/s]
#  100% |█████████████████| 279/279 [3.4s elapsed, 0s remaining, 115.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms2_0726__0809_13_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# processing: sahi_null_v2_sw1_0605-0613_07_ok
# Evaluating detections...
#  100% |█████████████████████| 6/6 [11.4ms elapsed, 0s remaining, 527.1 samples/s]
#  100% |█████████████████████| 6/6 [19.3ms elapsed, 0s remaining, 311.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [11.2ms elapsed, 0s remaining, 534.6 samples/s]
#  100% |█████████████████████| 6/6 [19.8ms elapsed, 0s remaining, 303.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.5ms elapsed, 0s remaining, 478.9 samples/s]
#  100% |█████████████████████| 6/6 [20.5ms elapsed, 0s remaining, 292.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.0ms elapsed, 0s remaining, 500.1 samples/s]
#  100% |█████████████████████| 6/6 [20.5ms elapsed, 0s remaining, 293.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.1ms elapsed, 0s remaining, 494.4 samples/s]
#  100% |█████████████████████| 6/6 [20.5ms elapsed, 0s remaining, 293.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [10.9ms elapsed, 0s remaining, 548.2 samples/s]
#  100% |█████████████████████| 6/6 [21.0ms elapsed, 0s remaining, 286.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [13.1ms elapsed, 0s remaining, 456.7 samples/s]
#  100% |█████████████████████| 6/6 [22.1ms elapsed, 0s remaining, 272.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [8.6ms elapsed, 0s remaining, 698.7 samples/s]
#  100% |█████████████████████| 6/6 [16.9ms elapsed, 0s remaining, 354.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [8.4ms elapsed, 0s remaining, 717.4 samples/s]
#  100% |█████████████████████| 6/6 [17.6ms elapsed, 0s remaining, 340.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.6ms elapsed, 0s remaining, 385.3 samples/s]
#  100% |█████████████████████| 6/6 [22.2ms elapsed, 0s remaining, 269.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.8ms elapsed, 0s remaining, 467.7 samples/s]
#  100% |█████████████████████| 6/6 [22.6ms elapsed, 0s remaining, 265.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [11.9ms elapsed, 0s remaining, 505.1 samples/s]
#  100% |█████████████████████| 6/6 [22.5ms elapsed, 0s remaining, 266.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.6ms elapsed, 0s remaining, 475.9 samples/s]
#  100% |█████████████████████| 6/6 [23.5ms elapsed, 0s remaining, 254.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.9ms elapsed, 0s remaining, 466.6 samples/s]
#  100% |█████████████████████| 6/6 [23.7ms elapsed, 0s remaining, 253.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.8ms elapsed, 0s remaining, 470.3 samples/s]
#  100% |█████████████████████| 6/6 [24.0ms elapsed, 0s remaining, 250.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [11.3ms elapsed, 0s remaining, 531.7 samples/s]
#  100% |█████████████████████| 6/6 [21.5ms elapsed, 0s remaining, 279.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [10.9ms elapsed, 0s remaining, 550.0 samples/s]
#  100% |█████████████████████| 6/6 [21.0ms elapsed, 0s remaining, 285.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [10.2ms elapsed, 0s remaining, 590.6 samples/s]
#  100% |█████████████████████| 6/6 [20.3ms elapsed, 0s remaining, 294.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.7ms elapsed, 0s remaining, 381.4 samples/s]
#  100% |█████████████████████| 6/6 [29.2ms elapsed, 0s remaining, 205.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.3ms elapsed, 0s remaining, 294.9 samples/s]
#  100% |█████████████████████| 6/6 [26.2ms elapsed, 0s remaining, 228.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [19.6ms elapsed, 0s remaining, 305.9 samples/s]
#  100% |█████████████████████| 6/6 [28.1ms elapsed, 0s remaining, 213.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [14.4ms elapsed, 0s remaining, 417.5 samples/s]
#  100% |█████████████████████| 6/6 [25.8ms elapsed, 0s remaining, 232.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [14.5ms elapsed, 0s remaining, 415.0 samples/s]
#  100% |█████████████████████| 6/6 [24.6ms elapsed, 0s remaining, 243.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [16.2ms elapsed, 0s remaining, 371.4 samples/s]
#  100% |█████████████████████| 6/6 [24.7ms elapsed, 0s remaining, 243.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [12.8ms elapsed, 0s remaining, 469.3 samples/s]
#  100% |█████████████████████| 6/6 [23.0ms elapsed, 0s remaining, 261.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [13.5ms elapsed, 0s remaining, 443.4 samples/s]
#  100% |█████████████████████| 6/6 [23.4ms elapsed, 0s remaining, 256.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [13.5ms elapsed, 0s remaining, 444.7 samples/s]
#  100% |█████████████████████| 6/6 [24.1ms elapsed, 0s remaining, 248.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [19.3ms elapsed, 0s remaining, 311.3 samples/s]
#  100% |█████████████████████| 6/6 [28.2ms elapsed, 0s remaining, 213.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [23.7ms elapsed, 0s remaining, 252.6 samples/s]
#  100% |█████████████████████| 6/6 [28.5ms elapsed, 0s remaining, 210.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [18.1ms elapsed, 0s remaining, 331.1 samples/s]
#  100% |█████████████████████| 6/6 [29.3ms elapsed, 0s remaining, 204.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [18.3ms elapsed, 0s remaining, 327.2 samples/s]
#  100% |█████████████████████| 6/6 [29.4ms elapsed, 0s remaining, 203.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [17.3ms elapsed, 0s remaining, 346.2 samples/s]
#  100% |█████████████████████| 6/6 [28.1ms elapsed, 0s remaining, 213.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.9ms elapsed, 0s remaining, 376.7 samples/s]
#  100% |█████████████████████| 6/6 [27.4ms elapsed, 0s remaining, 218.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [14.8ms elapsed, 0s remaining, 404.4 samples/s]
#  100% |█████████████████████| 6/6 [25.6ms elapsed, 0s remaining, 234.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.6ms elapsed, 0s remaining, 383.5 samples/s]
#  100% |█████████████████████| 6/6 [25.4ms elapsed, 0s remaining, 236.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [15.2ms elapsed, 0s remaining, 396.0 samples/s]
#  100% |█████████████████████| 6/6 [25.9ms elapsed, 0s remaining, 231.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.9ms elapsed, 0s remaining, 286.5 samples/s]
#  100% |█████████████████████| 6/6 [31.1ms elapsed, 0s remaining, 193.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [19.3ms elapsed, 0s remaining, 311.4 samples/s]
#  100% |█████████████████████| 6/6 [31.4ms elapsed, 0s remaining, 191.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.3ms elapsed, 0s remaining, 295.9 samples/s]
#  100% |█████████████████████| 6/6 [201.4ms elapsed, 0s remaining, 29.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [24.4ms elapsed, 0s remaining, 245.9 samples/s]
#  100% |█████████████████████| 6/6 [33.0ms elapsed, 0s remaining, 182.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.6ms elapsed, 0s remaining, 291.9 samples/s]
#  100% |█████████████████████| 6/6 [33.3ms elapsed, 0s remaining, 180.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.1ms elapsed, 0s remaining, 298.8 samples/s]
#  100% |█████████████████████| 6/6 [32.1ms elapsed, 0s remaining, 186.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [19.4ms elapsed, 0s remaining, 308.8 samples/s]
#  100% |█████████████████████| 6/6 [30.7ms elapsed, 0s remaining, 195.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [17.7ms elapsed, 0s remaining, 339.2 samples/s]
#  100% |█████████████████████| 6/6 [29.6ms elapsed, 0s remaining, 203.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [18.0ms elapsed, 0s remaining, 334.2 samples/s]
#  100% |█████████████████████| 6/6 [31.4ms elapsed, 0s remaining, 191.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [21.6ms elapsed, 0s remaining, 277.7 samples/s]
#  100% |█████████████████████| 6/6 [33.1ms elapsed, 0s remaining, 181.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [24.1ms elapsed, 0s remaining, 248.9 samples/s]
#  100% |█████████████████████| 6/6 [35.5ms elapsed, 0s remaining, 169.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [22.0ms elapsed, 0s remaining, 272.4 samples/s]
#  100% |█████████████████████| 6/6 [36.7ms elapsed, 0s remaining, 163.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [23.0ms elapsed, 0s remaining, 260.4 samples/s]
#  100% |█████████████████████| 6/6 [35.9ms elapsed, 0s remaining, 167.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [22.1ms elapsed, 0s remaining, 272.1 samples/s]
#  100% |█████████████████████| 6/6 [34.5ms elapsed, 0s remaining, 174.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [19.2ms elapsed, 0s remaining, 312.3 samples/s]
#  100% |█████████████████████| 6/6 [33.3ms elapsed, 0s remaining, 180.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.9ms elapsed, 0s remaining, 287.4 samples/s]
#  100% |█████████████████████| 6/6 [32.9ms elapsed, 0s remaining, 182.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [19.5ms elapsed, 0s remaining, 307.9 samples/s]
#  100% |█████████████████████| 6/6 [32.0ms elapsed, 0s remaining, 187.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [20.2ms elapsed, 0s remaining, 296.7 samples/s]
#  100% |█████████████████████| 6/6 [33.0ms elapsed, 0s remaining, 181.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [24.2ms elapsed, 0s remaining, 247.5 samples/s]
#  100% |█████████████████████| 6/6 [37.9ms elapsed, 0s remaining, 158.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [24.3ms elapsed, 0s remaining, 246.7 samples/s]
#  100% |█████████████████████| 6/6 [37.2ms elapsed, 0s remaining, 161.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [24.4ms elapsed, 0s remaining, 245.9 samples/s]
#  100% |█████████████████████| 6/6 [37.8ms elapsed, 0s remaining, 158.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [32.0ms elapsed, 0s remaining, 187.5 samples/s]
#  100% |█████████████████████| 6/6 [39.5ms elapsed, 0s remaining, 151.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [24.8ms elapsed, 0s remaining, 241.9 samples/s]
#  100% |█████████████████████| 6/6 [39.7ms elapsed, 0s remaining, 151.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [25.0ms elapsed, 0s remaining, 240.4 samples/s]
#  100% |█████████████████████| 6/6 [42.8ms elapsed, 0s remaining, 140.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [22.1ms elapsed, 0s remaining, 271.9 samples/s]
#  100% |█████████████████████| 6/6 [36.4ms elapsed, 0s remaining, 164.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [22.3ms elapsed, 0s remaining, 269.2 samples/s]
#  100% |█████████████████████| 6/6 [35.3ms elapsed, 0s remaining, 170.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [25.7ms elapsed, 0s remaining, 233.8 samples/s]
#  100% |█████████████████████| 6/6 [35.0ms elapsed, 0s remaining, 171.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_sw1_0605__0613_07_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████████| 6/6 [28.9ms elapsed, 0s remaining, 207.6 samples/s]
#  100% |█████████████████████| 6/6 [40.8ms elapsed, 0s remaining, 147.1 samples/s]
# ...
#  100% |█████████████████| 464/464 [3.6s elapsed, 0s remaining, 117.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.7s elapsed, 0s remaining, 154.1 samples/s]
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 114.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.8s elapsed, 0s remaining, 148.0 samples/s]
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 113.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.8s elapsed, 0s remaining, 153.3 samples/s]
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 111.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.8s elapsed, 0s remaining, 154.6 samples/s]
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 112.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.5s elapsed, 0s remaining, 162.6 samples/s]
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 112.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.4s elapsed, 0s remaining, 171.5 samples/s]
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 114.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.1s elapsed, 0s remaining, 187.5 samples/s]
#  100% |█████████████████| 464/464 [3.5s elapsed, 0s remaining, 116.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.0s elapsed, 0s remaining, 203.1 samples/s]
#  100% |█████████████████| 464/464 [3.4s elapsed, 0s remaining, 121.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a03_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_4__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.1s elapsed, 0s remaining, 116.3 samples/s]
#  100% |█████████████████| 464/464 [4.1s elapsed, 0s remaining, 102.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.2s elapsed, 0s remaining, 131.1 samples/s]
#  100% |█████████████████| 464/464 [4.1s elapsed, 0s remaining, 101.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.2s elapsed, 0s remaining, 111.2 samples/s]
#  100% |█████████████████| 464/464 [4.2s elapsed, 0s remaining, 82.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.3s elapsed, 0s remaining, 130.7 samples/s]
#  100% |█████████████████| 464/464 [4.2s elapsed, 0s remaining, 99.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.2s elapsed, 0s remaining, 106.6 samples/s]
#  100% |█████████████████| 464/464 [4.3s elapsed, 0s remaining, 97.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.1s elapsed, 0s remaining, 138.4 samples/s]
#  100% |█████████████████| 464/464 [4.2s elapsed, 0s remaining, 100.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.1s elapsed, 0s remaining, 117.5 samples/s]
#  100% |█████████████████| 464/464 [4.3s elapsed, 0s remaining, 95.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.9s elapsed, 0s remaining, 149.1 samples/s]
#  100% |█████████████████| 464/464 [4.1s elapsed, 0s remaining, 100.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.6s elapsed, 0s remaining, 137.9 samples/s]
#  100% |█████████████████| 464/464 [4.0s elapsed, 0s remaining, 84.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_16__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.6s elapsed, 0s remaining, 114.4 samples/s]
#  100% |█████████████████| 464/464 [4.7s elapsed, 0s remaining, 76.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.7s elapsed, 0s remaining, 116.8 samples/s]
#  100% |█████████████████| 464/464 [4.6s elapsed, 0s remaining, 90.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.6s elapsed, 0s remaining, 118.8 samples/s]
#  100% |█████████████████| 464/464 [4.6s elapsed, 0s remaining, 90.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.6s elapsed, 0s remaining, 120.8 samples/s]
#  100% |█████████████████| 464/464 [4.6s elapsed, 0s remaining, 91.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.5s elapsed, 0s remaining, 101.2 samples/s]
#  100% |█████████████████| 464/464 [4.6s elapsed, 0s remaining, 89.6 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.9s elapsed, 0s remaining, 136.7 samples/s]
#  100% |█████████████████| 464/464 [4.6s elapsed, 0s remaining, 70.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.0s elapsed, 0s remaining, 140.0 samples/s]
#  100% |█████████████████| 464/464 [4.4s elapsed, 0s remaining, 93.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.9s elapsed, 0s remaining, 149.6 samples/s]
#  100% |█████████████████| 464/464 [4.4s elapsed, 0s remaining, 95.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [2.8s elapsed, 0s remaining, 143.1 samples/s]
#  100% |█████████████████| 464/464 [4.6s elapsed, 0s remaining, 80.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_4__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.9s elapsed, 0s remaining, 105.1 samples/s]
#  100% |█████████████████| 464/464 [5.2s elapsed, 0s remaining, 86.0 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.2s elapsed, 0s remaining, 92.6 samples/s]
#  100% |█████████████████| 464/464 [5.0s elapsed, 0s remaining, 84.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.1s elapsed, 0s remaining, 106.0 samples/s]
#  100% |█████████████████| 464/464 [5.1s elapsed, 0s remaining, 84.8 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.0s elapsed, 0s remaining, 109.5 samples/s]
#  100% |█████████████████| 464/464 [5.3s elapsed, 0s remaining, 65.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.0s elapsed, 0s remaining, 108.3 samples/s]
#  100% |█████████████████| 464/464 [5.3s elapsed, 0s remaining, 83.3 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.9s elapsed, 0s remaining, 92.4 samples/s]
#  100% |█████████████████| 464/464 [5.1s elapsed, 0s remaining, 83.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.8s elapsed, 0s remaining, 117.4 samples/s]
#  100% |█████████████████| 464/464 [5.1s elapsed, 0s remaining, 78.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.6s elapsed, 0s remaining, 118.2 samples/s]
#  100% |█████████████████| 464/464 [5.2s elapsed, 0s remaining, 68.5 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.4s elapsed, 0s remaining, 126.6 samples/s]
#  100% |█████████████████| 464/464 [5.1s elapsed, 0s remaining, 87.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11n_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.5s elapsed, 0s remaining, 92.8 samples/s]
#  100% |█████████████████| 464/464 [5.5s elapsed, 0s remaining, 74.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c50__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.5s elapsed, 0s remaining, 92.5 samples/s]
#  100% |█████████████████| 464/464 [5.8s elapsed, 0s remaining, 74.4 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c60__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.5s elapsed, 0s remaining, 93.7 samples/s]
#  100% |█████████████████| 464/464 [5.7s elapsed, 0s remaining, 62.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c70__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.7s elapsed, 0s remaining, 80.4 samples/s]
#  100% |█████████████████| 464/464 [5.6s elapsed, 0s remaining, 73.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c80__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.4s elapsed, 0s remaining, 99.8 samples/s]
#  100% |█████████████████| 464/464 [5.8s elapsed, 0s remaining, 72.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c85__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [4.1s elapsed, 0s remaining, 107.4 samples/s]
#  100% |█████████████████| 464/464 [5.5s elapsed, 0s remaining, 74.1 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c90__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.9s elapsed, 0s remaining, 110.0 samples/s]
#  100% |█████████████████| 464/464 [5.6s elapsed, 0s remaining, 74.9 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c91__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.8s elapsed, 0s remaining, 111.6 samples/s]
#  100% |█████████████████| 464/464 [5.4s elapsed, 0s remaining, 77.7 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c92__iou50.csv
# Evaluating detections...
#  100% |█████████████████| 464/464 [3.8s elapsed, 0s remaining, 114.6 samples/s]
#  100% |█████████████████| 464/464 [5.6s elapsed, 0s remaining, 77.2 samples/s]
# [SAVE] _eval_exports_per_images/sahi_null_v2/sahi_null_v2_ms1_0726__0809_11_ok/image_level_a04_yolo11s_custom7null_cv1_ms2_0809__0823_10_ok_8__c93__iou50.csv
# Saved summary: _eval_exports_per_images/sahi_null_v2/per_image_summary__sahi_null_v2__iou50.csv
# Summary shape: (504, 25)
