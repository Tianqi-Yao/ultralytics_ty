# %%
import fiftyone as fo
import fiftyone.types as fot

# %% [markdown]
# # 备份dataset

# %%
dataset.export(
    export_dir="/path/to/backup_dir",
    dataset_type=fot.FiftyOneDataset,
)

# %% [markdown]
# # 恢复dataset

# %%
new_ds = fo.Dataset.from_dir(
    "/path/to/backup_dir",
    dataset_type=fot.FiftyOneDataset,
    name="recovered_swd_v1",
)
