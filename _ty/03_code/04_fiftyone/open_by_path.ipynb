# %%
dataset_name = "ms1_0726-0809_11_ok"
image_file_name = "0803_1943_760.jpg"

# %%
import fiftyone as fo  

# 假设您已经有一个运行中的session  
dataset = fo.load_dataset(dataset_name)  
session = fo.launch_app(dataset)

# %%
# 通过filepath获取样本ID  

image_path = f"/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/01_16mp_2024_pipeline_data/{dataset_name}/raw_data/{image_file_name}"  
sample = dataset[image_path]  

# 在现有session中打开该样本  
session.sample_id = sample.id

# %% [markdown]
# # test

# %%
import fiftyone as fo  

dataset_name = "ms2_0726-0809_13_ok"

# 假设您已经有一个运行中的session  
dataset = fo.load_dataset(dataset_name)  
# session = fo.launch_app(dataset)

# %%
ann_view = dataset.match_tags("ann")
ann_view

# %%
# !export FIFTYONE_CVAT_USERNAME="yaotianqi6666@gmail.com"
# !export FIFTYONE_CVAT_PASSWORD="YYY1995yyy"

# %%
anno_key = "swd_anno"
anno_result = ann_view.annotate(anno_key=anno_key, label_field="swd_label_test", label_type="keypoints", classes=["swd"], launch_editor=True)

# %%
anno_key = "swd_anno"
if anno_key in dataset.list_annotation_runs():
    results = dataset.load_annotation_results(anno_key)  
    dataset.delete_annotation_run(anno_key)  # 删除本地记录
anno_result = ann_view.annotate(  
    anno_key,  
    label_field="swd_label_test",
    label_type="detections",
    classes=["swd"],
    backend="labelbox",  
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..iJePiLSZbjokQne_Wz44ymzku0kZS-TrSZRGMY_dEi4",
    launch_editor=True,
)

# %%
anno_result.get_status()

# %%
results = dataset.load_annotation_results(anno_key)  
results.get_status()

# %%
ann_view.to_dict()

# %%
ann_view.load_annotations(anno_key, cleanup=True)  # 删除已有标注

# %%
anno_keys = dataset.list_annotation_runs()  
anno_keys

# %%
for key in anno_keys:
    print(key)
    # 完整清理流程  
    results = dataset.load_annotation_results(key)  
    # results.cleanup()  # 删除后端任务  
    dataset.delete_annotation_run(key)  # 删除本地记录
