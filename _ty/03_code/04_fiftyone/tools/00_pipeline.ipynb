# %% [markdown]
# ## GUI窗口

# %%
import fiftyone as fo  

# 加载已存在的数据集  
dataset = fo.load_dataset("my-dataset")
session = fo.launch_app(dataset)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-7856fef2-8fa3-4092-ab08-7c9cca7250e0 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-7856fef2-8fa3-4092-ab08-7c9cca7250e0 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-7856fef2-8fa3-4092-ab08-7c9cca7250e0:focus {
#   outline: none;
# }
# #fooverlay-7856fef2-8fa3-4092-ab08-7c9cca7250e0 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-7856fef2-8fa3-4092-ab08-7c9cca7250e0">
#    <div id="fooverlay-7856fef2-8fa3-4092-ab08-7c9cca7250e0" style="display: none;">
#       <button id="foactivate-7856fef2-8fa3-4092-ab08-7c9cca7250e0" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 1628px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-7856fef2-8fa3-4092-ab08-7c9cca7250e0");
#      var overlay = document.getElementById("fooverlay-7856fef2-8fa3-4092-ab08-7c9cca7250e0");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "7856fef2-8fa3-4092-ab08-7c9cca7250e0" },
#               subscription: "7856fef2-8fa3-4092-ab08-7c9cca7250e0"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %% [markdown]
# ## 遍历文件夹

# %%
from pathlib import Path

raw_data_dir = "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset"

sub_dir_path = ""

all_file_path_list = sorted(Path(raw_data_dir).glob(f"*/{sub_dir_path}"))

# 打印供主人确认，格式可直接粘贴进 list
for file_path in all_file_path_list:
    print(f'    "{file_path}",')

print(f"\n共 {len(all_file_path_list)} 个文件夹")
# Out:
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/air2_0729-0813_04",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/jeff_0613-0624_04_ok",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/jeff_0624-0702_01_ok",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/lloyd_0715-0729_04",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms1_0605-0621_40",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms1_0710-0726_36",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms1_0726-0809_11",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms1_0809-0823_34",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms2_0605-0621_30",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms2_0621-0710_01",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms2_0710-0726_41",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms2_0726-0809_13",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms2_0809-0823_10",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/ms2_0823-0906_07",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/sw1_0605-0613_07_ok",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/sw1_0627-0711_02",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/sw1_0711-0725_03",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/sw1_0808-0823_01",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/sw2_0725-0808_02",
#     "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/01_data/a01_20dataset/sw2_0808-0823_04",
#
# 共 20 个文件夹
