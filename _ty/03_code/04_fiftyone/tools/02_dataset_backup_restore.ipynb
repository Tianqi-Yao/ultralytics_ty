# %%
import fiftyone as fo
import fiftyone.types as fot

# %% [markdown]
# # 备份dataset

# %%
import fiftyone as fo
import os

root = "/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3"
os.makedirs(root, exist_ok=True)

datasets = fo.list_datasets()
# datasets = ["00_try"]

for dataset_name in datasets:
    ds = fo.load_dataset(dataset_name)

    out = os.path.join(root, dataset_name)
    print("Backing up:", dataset_name)
    os.makedirs(out, exist_ok=True)

    ds.export(
        export_dir=out,
        dataset_type=fo.types.FiftyOneDataset,
        export_media=True,
    )
# Out:
# Backing up: TEST2_air2_0701_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/TEST2_air2_0701_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 6626/6626 [2.0m elapsed, 0s remaining, 38.6 docs/s]
# Backing up: TEST2_ms2_0605_0923
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/TEST2_ms2_0605_0923' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████| 12254/12254 [5.5m elapsed, 0s remaining, 27.3 docs/s]
# Backing up: TEST2_southfarm2_0712_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/TEST2_southfarm2_0712_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 3125/3125 [1.4m elapsed, 0s remaining, 34.8 docs/s]
# Backing up: TESTair2_0701_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/TESTair2_0701_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 6626/6626 [2.7m elapsed, 0s remaining, 67.9 docs/s]
# Backing up: TESTms2_0605_0923
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/TESTms2_0605_0923' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████| 12254/12254 [5.6m elapsed, 0s remaining, 38.6 docs/s]
# Backing up: TESTsouthfarm2_0712_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/TESTsouthfarm2_0712_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 3125/3125 [1.4m elapsed, 0s remaining, 31.5 docs/s]
# Backing up: air2_0701_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/air2_0701_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 6626/6626 [2.8m elapsed, 0s remaining, 31.1 docs/s]
# Backing up: ms2_0605_0923
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/ms2_0605_0923' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████| 12254/12254 [5.8m elapsed, 0s remaining, 50.0 docs/s]
# Backing up: sahi_null_run_whole_rawData_good3_v1_air2_0701_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_run_whole_rawData_good3_v1_air2_0701_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 6626/6626 [2.8m elapsed, 0s remaining, 39.3 docs/s]
# Backing up: sahi_null_run_whole_rawData_good3_v1_ms2_0605_0923
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_run_whole_rawData_good3_v1_ms2_0605_0923' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████| 12254/12254 [5.9m elapsed, 0s remaining, 37.8 docs/s]
# Backing up: sahi_null_run_whole_rawData_good3_v1_southfarm2_0712_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_run_whole_rawData_good3_v1_southfarm2_0712_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 3125/3125 [1.5m elapsed, 0s remaining, 32.8 docs/s]
# Backing up: sahi_null_v2_ms2_0726-0809_13_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_v2_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [8.8s elapsed, 0s remaining, 34.5 docs/s]
# Backing up: sahi_null_v2_ms2_0809-0823_10_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_v2_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [15.3s elapsed, 0s remaining, 33.1 docs/s]
# Backing up: sahi_null_v3_ms2_0726-0809_13_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_v3_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [9.2s elapsed, 0s remaining, 30.5 docs/s]
# Backing up: sahi_null_v3_ms2_0809-0823_10_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_null_v3_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [15.2s elapsed, 0s remaining, 32.3 docs/s]
# Backing up: sahi_v1_ms2_0726-0809_13_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_v1_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [8.0s elapsed, 0s remaining, 28.6 docs/s]
# Backing up: sahi_v1_ms2_0809-0823_10_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/sahi_v1_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [15.2s elapsed, 0s remaining, 34.3 docs/s]
# Backing up: southfarm2_0712_0823
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/southfarm2_0712_0823' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 3125/3125 [1.5m elapsed, 0s remaining, 35.1 docs/s]
# Backing up: test
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/test' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████████| 9/9 [245.3ms elapsed, 0s remaining, 36.7 docs/s]
# Backing up: v1_ms2_0726-0809_13_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/v1_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 1713/1713 [54.2s elapsed, 0s remaining, 32.4 docs/s]
# Backing up: v2_ms2_0809-0823_10_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/v2_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 2245/2245 [1.1m elapsed, 0s remaining, 36.2 docs/s]
# Backing up: v3_sahi_ms2_0726-0809_13_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/v3_sahi_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [8.5s elapsed, 0s remaining, 31.7 docs/s]
# Backing up: v3_sahi_ms2_0809-0823_10_ok
# Directory '/media/tianqi/16tb/SWD/02_Middle_results/fiftyone_backup_v3/v3_sahi_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [15.6s elapsed, 0s remaining, 32.8 docs/s]

# %% [markdown]
# # 恢复dataset

# %%
import fiftyone as fo
import os

# get name list
root = "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2"
name_list = os.listdir(root)
# name_list = ["00_try"]

skip_list = [
    'my-dataset',
    'sahi_null_v2_ms1_0605-0621_40_ok',
    'sahi_null_v2_ms1_0710-0726_36_ok',
    'sahi_null_v2_ms1_0726-0809_11_ok',
    'sahi_null_v2_ms1_0809-0823_34_ok',
    'sahi_null_v2_ms2_0726-0809_13_ok',
    'sahi_null_v2_ms2_0809-0823_10_ok',
]

# sort name list
name_list.sort()

for dataset_name in name_list:
    if not (dataset_name.endswith("07_ok") and dataset_name.startswith("sahi_null_v2")):
        continue
    # if dataset_name in skip_list:
    #     continue
    print(dataset_name)

    ds = fo.Dataset.from_dir(
        f"{root}/{dataset_name}",
        fo.types.FiftyOneDataset,
        name=dataset_name,
    )
# Out:
# sahi_null_v2_sw1_0605-0613_07_ok
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1943220/1027455614.py in ?()
#      25 # get name list
#      26 root = "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2"
#      27 name_list = os.listdir(root)
#      28 # name_list = ["00_try"]
# ---> 29
#      30 skip_list = [
#      31     'my-dataset',
#      32     'sahi_null_v2_ms1_0605-0621_40_ok',
#
# ~/miniconda3/envs/fif/lib/python3.9/site-packages/fiftyone/core/dataset.py in ?(cls, dataset_dir, dataset_type, data_path, labels_path, name, persistent, overwrite, label_field, tags, dynamic, progress, **kwargs)
#    7855
#    7856         Returns:
#    7857             a :class:`Dataset`
#    7858         """
# -> 7859         dataset = cls(name, persistent=persistent, overwrite=overwrite)
#    7860         dataset.add_dir(
#    7861             dataset_dir=dataset_dir,
#    7862             dataset_type=dataset_type,
#
# ~/miniconda3/envs/fif/lib/python3.9/site-packages/fiftyone/core/singletons.py in ?(cls, name, _create, _reload, *args, **kwargs)
#      47             or instance is None
#      48             or instance.deleted
#      49             or instance.name is None
#      50         ):
# ---> 51             instance = cls._make_instance(
#      52                 name=name, _create=_create, *args, **kwargs
#      53             )
#      54             name = instance.name  # `__init__` may have changed `name`
#
# ~/miniconda3/envs/fif/lib/python3.9/site-packages/fiftyone/core/singletons.py in ?(cls, name, _create, *args, **kwargs)
#      33     def _make_instance(cls, name, _create, *args, **kwargs):
#      34         instance = cls.__new__(cls)
# ---> 35         instance.__init__(name=name, _create=_create, *args, **kwargs)
#      36         return instance
#
# ~/miniconda3/envs/fif/lib/python3.9/site-packages/fiftyone/core/dataset.py in ?(self, name, persistent, overwrite, _create, _virtual, _reload, **kwargs)
#     319         if overwrite and dataset_exists(name):
#     320             delete_dataset(name)
#     321
#     322         if _create:
# --> 323             doc, sample_doc_cls, frame_doc_cls = _create_dataset(
#     324                 self, name, persistent=persistent, **kwargs
#     325             )
#     326         else:
#
# ~/miniconda3/envs/fif/lib/python3.9/site-packages/fiftyone/core/dataset.py in ?(obj, name, persistent, _patches, _frames, _clips, _src_collection)
#    9280     _frames=False,
#    9281     _clips=False,
#    9282     _src_collection=None,
#    9283 ):
# -> 9284     slug = _validate_dataset_name(name)
#    9285
#    9286     _id = ObjectId()
#    9287     now = datetime.utcnow()
#
# ~/miniconda3/envs/fif/lib/python3.9/site-packages/fiftyone/core/dataset.py in ?(name, skip)
#     126     )
#     127     if clashing_name_doc is not None:
#     128         clashing_name = clashing_name_doc["name"]
#     129         if clashing_name == name:
# --> 130             raise ValueError(f"Dataset name '{name}' is not available")
#     131         else:
#     132             raise ValueError(
#     133                 f"Dataset name '{name}' is not available: slug '{slug}' "
#
# ValueError: Dataset name 'sahi_null_v2_sw1_0605-0613_07_ok' is not available

# %%
# delete all datasets
for ds_name in fo.list_datasets():
    print(f"{ds_name}")
    fo.delete_dataset(ds_name) 

# # # fo.delete_dataset("ms1_0605-0621_40_ok_v3")
