# %%
import fiftyone as fo
import fiftyone.types as fot

# %% [markdown]
# # 备份dataset

# %%
import fiftyone as fo
import os

root = "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2"
os.makedirs(root, exist_ok=True)

datasets = fo.list_datasets()
# datasets = ["00_try"]

for dataset_name in datasets:
    ds = fo.load_dataset(dataset_name)

    out = os.path.join(root, dataset_name)
    print("Backing up:", dataset_name)
    os.makedirs(out, exist_ok=True)

    ds.export(
        export_dir=out,
        dataset_type=fo.types.FiftyOneDataset,
        export_media=True,
    )
# Out:
# Backing up: my-dataset
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/my-dataset' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████████| 0/0 [151.8us elapsed, ? remaining, ? docs/s]
# Backing up: sahi_null_v2_ms1_0605-0621_40_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_ms1_0605-0621_40_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 243/243 [942.9ms elapsed, 0s remaining, 257.7 docs/s]
# Backing up: sahi_null_v2_ms1_0710-0726_36_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_ms1_0710-0726_36_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 471/471 [1.4s elapsed, 0s remaining, 355.8 docs/s]
# Backing up: sahi_null_v2_ms1_0726-0809_11_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_ms1_0726-0809_11_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 464/464 [1.3s elapsed, 0s remaining, 400.4 docs/s]
# Backing up: sahi_null_v2_ms1_0809-0823_34_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_ms1_0809-0823_34_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 323/323 [907.5ms elapsed, 0s remaining, 355.9 docs/s]
# Backing up: sahi_null_v2_ms2_0726-0809_13_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [825.1ms elapsed, 0s remaining, 338.1 docs/s]
# Backing up: sahi_null_v2_ms2_0809-0823_10_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [1.6s elapsed, 0s remaining, 368.5 docs/s]
# Backing up: sahi_null_v2_sw1_0605-0613_07_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v2_sw1_0605-0613_07_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████████| 6/6 [15.4ms elapsed, 0s remaining, 389.0 docs/s]
# Backing up: sahi_null_v3_ms1_0605-0621_40_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_ms1_0605-0621_40_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 243/243 [1.4s elapsed, 0s remaining, 122.8 docs/s]
# Backing up: sahi_null_v3_ms1_0710-0726_36_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_ms1_0710-0726_36_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 471/471 [2.3s elapsed, 0s remaining, 202.2 docs/s]
# Backing up: sahi_null_v3_ms1_0726-0809_11_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_ms1_0726-0809_11_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 464/464 [1.6s elapsed, 0s remaining, 257.7 docs/s]
# Backing up: sahi_null_v3_ms1_0809-0823_34_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_ms1_0809-0823_34_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 323/323 [1.2s elapsed, 0s remaining, 262.3 docs/s]
# Backing up: sahi_null_v3_ms2_0726-0809_13_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [1.1s elapsed, 0s remaining, 261.5 docs/s]
# Backing up: sahi_null_v3_ms2_0809-0823_10_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [1.7s elapsed, 0s remaining, 301.0 docs/s]
# Backing up: sahi_null_v3_sw1_0605-0613_07_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_null_v3_sw1_0605-0613_07_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████████| 6/6 [17.9ms elapsed, 0s remaining, 335.5 docs/s]
# Backing up: sahi_v1_ms1_0605-0621_40_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_ms1_0605-0621_40_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 243/243 [935.0ms elapsed, 0s remaining, 251.3 docs/s]
# Backing up: sahi_v1_ms1_0710-0726_36_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_ms1_0710-0726_36_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 471/471 [2.1s elapsed, 0s remaining, 144.0 docs/s]
# Backing up: sahi_v1_ms1_0726-0809_11_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_ms1_0726-0809_11_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 464/464 [1.4s elapsed, 0s remaining, 334.2 docs/s]
# Backing up: sahi_v1_ms1_0809-0823_34_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_ms1_0809-0823_34_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 323/323 [898.5ms elapsed, 0s remaining, 359.5 docs/s]
# Backing up: sahi_v1_ms2_0726-0809_13_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [886.7ms elapsed, 0s remaining, 314.7 docs/s]
# Backing up: sahi_v1_ms2_0809-0823_10_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [2.6s elapsed, 0s remaining, 217.1 docs/s]
# Backing up: sahi_v1_sw1_0605-0613_07_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/sahi_v1_sw1_0605-0613_07_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████████| 6/6 [14.6ms elapsed, 0s remaining, 412.3 docs/s]
# Backing up: v1_ms1_0710-0726_36_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v1_ms1_0710-0726_36_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 1664/1664 [2.2s elapsed, 0s remaining, 750.6 docs/s]
# Backing up: v1_ms1_0809-0823_34_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v1_ms1_0809-0823_34_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 1743/1743 [1.2s elapsed, 0s remaining, 1.4K docs/s]
# Backing up: v1_ms2_0726-0809_13_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v1_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 1713/1713 [783.6ms elapsed, 0s remaining, 2.2K docs/s]
# Backing up: v1_sw1_0605-0613_07_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v1_sw1_0605-0613_07_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 206/206 [119.1ms elapsed, 0s remaining, 1.7K docs/s]
# Backing up: v2_ms1_0605-0621_40_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v2_ms1_0605-0621_40_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 757/757 [339.3ms elapsed, 0s remaining, 2.2K docs/s]
# Backing up: v2_ms1_0726-0809_11_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v2_ms1_0726-0809_11_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 1386/1386 [693.7ms elapsed, 0s remaining, 2.0K docs/s]
# Backing up: v2_ms2_0809-0823_10_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v2_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |██████████████████| 2245/2245 [997.1ms elapsed, 0s remaining, 2.3K docs/s]
# Backing up: v3_sahi_ms1_0605-0621_40_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_ms1_0605-0621_40_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 243/243 [102.1ms elapsed, 0s remaining, 2.4K docs/s]
# Backing up: v3_sahi_ms1_0710-0726_36_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_ms1_0710-0726_36_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 471/471 [171.8ms elapsed, 0s remaining, 2.7K docs/s]
# Backing up: v3_sahi_ms1_0726-0809_11_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_ms1_0726-0809_11_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 464/464 [141.2ms elapsed, 0s remaining, 3.3K docs/s]
# Backing up: v3_sahi_ms1_0809-0823_34_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_ms1_0809-0823_34_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 323/323 [77.3ms elapsed, 0s remaining, 4.2K docs/s]
# Backing up: v3_sahi_ms2_0726-0809_13_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_ms2_0726-0809_13_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 279/279 [68.2ms elapsed, 0s remaining, 4.1K docs/s]
# Backing up: v3_sahi_ms2_0809-0823_10_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_ms2_0809-0823_10_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 578/578 [128.3ms elapsed, 0s remaining, 4.5K docs/s]
# Backing up: v3_sahi_sw1_0605-0613_07_ok
# Directory '/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2/v3_sahi_sw1_0605-0613_07_ok' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████████| 6/6 [1.7ms elapsed, 0s remaining, 3.5K docs/s]

# %% [markdown]
# # 恢复dataset

# %%
import fiftyone as fo
import os

# get name list
root = "/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/backup_v2"
name_list = os.listdir(root)
# name_list = ["00_try"]

# sort name list
name_list.sort()

for dataset_name in name_list:
    print(dataset_name)

    ds = fo.Dataset.from_dir(
        f"{root}/{dataset_name}",
        fo.types.FiftyOneDataset,
        name=dataset_name,
    )
# Out:
# my-dataset
# Importing samples...
#  100% |█████████████████████| 0/0 [505.0us elapsed, ? remaining, ? samples/s]
# Migrating dataset 'my-dataset' to v1.13.0
# sahi_null_v2_ms1_0605-0621_40_ok
# Importing samples...
#  100% |█████████████████| 243/243 [67.8ms elapsed, 0s remaining, 3.6K samples/s]
# Migrating dataset 'sahi_null_v2_ms1_0605-0621_40_ok' to v1.13.0
# sahi_null_v2_ms1_0710-0726_36_ok
# Importing samples...
#  100% |█████████████████| 471/471 [95.2ms elapsed, 0s remaining, 4.9K samples/s]
# Migrating dataset 'sahi_null_v2_ms1_0710-0726_36_ok' to v1.13.0
# sahi_null_v2_ms1_0726-0809_11_ok
# Importing samples...
#  100% |█████████████████| 464/464 [66.7ms elapsed, 0s remaining, 7.0K samples/s]
# Migrating dataset 'sahi_null_v2_ms1_0726-0809_11_ok' to v1.13.0
# sahi_null_v2_ms1_0809-0823_34_ok
# Importing samples...
#  100% |█████████████████| 323/323 [34.3ms elapsed, 0s remaining, 9.4K samples/s]
# Migrating dataset 'sahi_null_v2_ms1_0809-0823_34_ok' to v1.13.0
# sahi_null_v2_ms2_0726-0809_13_ok
# Importing samples...
#  100% |█████████████████| 279/279 [40.1ms elapsed, 0s remaining, 7.0K samples/s]
# Migrating dataset 'sahi_null_v2_ms2_0726-0809_13_ok' to v1.13.0
# sahi_null_v2_ms2_0809-0823_10_ok
# Importing samples...
#  100% |█████████████████| 578/578 [68.2ms elapsed, 0s remaining, 8.5K samples/s]
# Migrating dataset 'sahi_null_v2_ms2_0809-0823_10_ok' to v1.13.0
# sahi_null_v2_sw1_0605-0613_07_ok
# Importing samples...
#  100% |█████████████████████| 6/6 [1.8ms elapsed, 0s remaining, 3.3K samples/s]
# Migrating dataset 'sahi_null_v2_sw1_0605-0613_07_ok' to v1.13.0
# sahi_null_v3_ms1_0605-0621_40_ok
# Importing samples...
#  100% |█████████████████| 243/243 [286.9ms elapsed, 0s remaining, 849.8 samples/s]
# Migrating dataset 'sahi_null_v3_ms1_0605-0621_40_ok' to v1.13.0
# sahi_null_v3_ms1_0710-0726_36_ok
# Importing samples...
#  100% |█████████████████| 471/471 [443.6ms elapsed, 0s remaining, 1.1K samples/s]
# Migrating dataset 'sahi_null_v3_ms1_0710-0726_36_ok' to v1.13.0
# sahi_null_v3_ms1_0726-0809_11_ok
# Importing samples...
#  100% |█████████████████| 464/464 [323.3ms elapsed, 0s remaining, 1.4K samples/s]
# Migrating dataset 'sahi_null_v3_ms1_0726-0809_11_ok' to v1.13.0
# sahi_null_v3_ms1_0809-0823_34_ok
# Importing samples...
#  100% |█████████████████| 323/323 [206.7ms elapsed, 0s remaining, 1.6K samples/s]
# Migrating dataset 'sahi_null_v3_ms1_0809-0823_34_ok' to v1.13.0
# sahi_null_v3_ms2_0726-0809_13_ok
# Importing samples...
#  100% |█████████████████| 279/279 [180.1ms elapsed, 0s remaining, 1.5K samples/s]
# Migrating dataset 'sahi_null_v3_ms2_0726-0809_13_ok' to v1.13.0
# sahi_null_v3_ms2_0809-0823_10_ok
# Importing samples...
#  100% |█████████████████| 578/578 [263.2ms elapsed, 0s remaining, 2.2K samples/s]
# Migrating dataset 'sahi_null_v3_ms2_0809-0823_10_ok' to v1.13.0
# sahi_null_v3_sw1_0605-0613_07_ok
# Importing samples...
#  100% |█████████████████████| 6/6 [3.7ms elapsed, 0s remaining, 1.6K samples/s]
# Migrating dataset 'sahi_null_v3_sw1_0605-0613_07_ok' to v1.13.0
# sahi_v1_ms1_0605-0621_40_ok
# Importing samples...
#  100% |█████████████████| 243/243 [111.7ms elapsed, 0s remaining, 2.2K samples/s]
# Migrating dataset 'sahi_v1_ms1_0605-0621_40_ok' to v1.13.0
# sahi_v1_ms1_0710-0726_36_ok
# Importing samples...
#  100% |█████████████████| 471/471 [188.4ms elapsed, 0s remaining, 2.5K samples/s]
# Migrating dataset 'sahi_v1_ms1_0710-0726_36_ok' to v1.13.0
# sahi_v1_ms1_0726-0809_11_ok
# Importing samples...
#  100% |█████████████████| 464/464 [154.1ms elapsed, 0s remaining, 3.0K samples/s]
# Migrating dataset 'sahi_v1_ms1_0726-0809_11_ok' to v1.13.0
# sahi_v1_ms1_0809-0823_34_ok
# Importing samples...
#  100% |█████████████████| 323/323 [64.9ms elapsed, 0s remaining, 5.0K samples/s]
# Migrating dataset 'sahi_v1_ms1_0809-0823_34_ok' to v1.13.0
# sahi_v1_ms2_0726-0809_13_ok
# Importing samples...
#  100% |█████████████████| 279/279 [79.7ms elapsed, 0s remaining, 3.5K samples/s]
# Migrating dataset 'sahi_v1_ms2_0726-0809_13_ok' to v1.13.0
# sahi_v1_ms2_0809-0823_10_ok
# Importing samples...
#  100% |█████████████████| 578/578 [109.7ms elapsed, 0s remaining, 5.3K samples/s]
# Migrating dataset 'sahi_v1_ms2_0809-0823_10_ok' to v1.13.0
# sahi_v1_sw1_0605-0613_07_ok
# Importing samples...
#  100% |█████████████████████| 6/6 [2.5ms elapsed, 0s remaining, 2.4K samples/s]
# Migrating dataset 'sahi_v1_sw1_0605-0613_07_ok' to v1.13.0
# v1_ms1_0710-0726_36_ok
# Importing samples...
#  100% |███████████████| 1664/1664 [1.0s elapsed, 0s remaining, 1.6K samples/s]
# Migrating dataset 'v1_ms1_0710-0726_36_ok' to v1.13.0
# v1_ms1_0809-0823_34_ok
# Importing samples...
#  100% |███████████████| 1743/1743 [407.3ms elapsed, 0s remaining, 4.3K samples/s]
# Migrating dataset 'v1_ms1_0809-0823_34_ok' to v1.13.0
# v1_ms2_0726-0809_13_ok
# Importing samples...
#  100% |███████████████| 1713/1713 [275.3ms elapsed, 0s remaining, 6.2K samples/s]
# Migrating dataset 'v1_ms2_0726-0809_13_ok' to v1.13.0
# v1_sw1_0605-0613_07_ok
# Importing samples...
#  100% |█████████████████| 206/206 [51.7ms elapsed, 0s remaining, 4.0K samples/s]
# Migrating dataset 'v1_sw1_0605-0613_07_ok' to v1.13.0
# v2_ms1_0605-0621_40_ok
# Importing samples...
#  100% |█████████████████| 757/757 [128.1ms elapsed, 0s remaining, 5.9K samples/s]
# Migrating dataset 'v2_ms1_0605-0621_40_ok' to v1.13.0
# v2_ms1_0726-0809_11_ok
# Importing samples...
#  100% |███████████████| 1386/1386 [238.0ms elapsed, 0s remaining, 5.8K samples/s]
# Migrating dataset 'v2_ms1_0726-0809_11_ok' to v1.13.0
# v2_ms2_0809-0823_10_ok
# Importing samples...
#  100% |███████████████| 2245/2245 [343.1ms elapsed, 0s remaining, 6.5K samples/s]
# Migrating dataset 'v2_ms2_0809-0823_10_ok' to v1.13.0
# v3_sahi_ms1_0605-0621_40_ok
# Importing samples...
#  100% |█████████████████| 243/243 [37.7ms elapsed, 0s remaining, 6.4K samples/s]
# Migrating dataset 'v3_sahi_ms1_0605-0621_40_ok' to v1.13.0
# v3_sahi_ms1_0710-0726_36_ok
# Importing samples...
#  100% |█████████████████| 471/471 [54.5ms elapsed, 0s remaining, 8.6K samples/s]
# Migrating dataset 'v3_sahi_ms1_0710-0726_36_ok' to v1.13.0
# v3_sahi_ms1_0726-0809_11_ok
# Importing samples...
#  100% |█████████████████| 464/464 [48.7ms elapsed, 0s remaining, 9.5K samples/s]
# Migrating dataset 'v3_sahi_ms1_0726-0809_11_ok' to v1.13.0
# v3_sahi_ms1_0809-0823_34_ok
# Importing samples...
#  100% |█████████████████| 323/323 [20.9ms elapsed, 0s remaining, 15.5K samples/s]
# Migrating dataset 'v3_sahi_ms1_0809-0823_34_ok' to v1.13.0
# v3_sahi_ms2_0726-0809_13_ok
# Importing samples...
#  100% |█████████████████| 279/279 [27.5ms elapsed, 0s remaining, 10.2K samples/s]
# Migrating dataset 'v3_sahi_ms2_0726-0809_13_ok' to v1.13.0
# v3_sahi_ms2_0809-0823_10_ok
# Importing samples...
#  100% |█████████████████| 578/578 [41.3ms elapsed, 0s remaining, 14.0K samples/s]
# Migrating dataset 'v3_sahi_ms2_0809-0823_10_ok' to v1.13.0
# v3_sahi_sw1_0605-0613_07_ok
# Importing samples...
#  100% |█████████████████████| 6/6 [1.8ms elapsed, 0s remaining, 3.3K samples/s]
# Migrating dataset 'v3_sahi_sw1_0605-0613_07_ok' to v1.13.0

# %%
# delete all datasets
for ds_name in fo.list_datasets():
    print(f"{ds_name}")
    fo.delete_dataset(ds_name) 

# # # fo.delete_dataset("ms1_0605-0621_40_ok_v3")
# Out:
# my-dataset
# sahi_null_v2_ms1_0605-0621_40_ok
