# %%
import papermill as pm

pm.inspect_notebook('/home/tianqi/D/01_Projects/01_swd/02_code/pipeline/ultralytics_ty/_ty/03_code/04_fiftyone/tools/12_data_quality_check.ipynb')
# Out:
# {'DATASET_NAME': {'name': 'DATASET_NAME',
#   'inferred_type_name': 'None',
#   'default': '"sahi_null_v2_ms1_0605-0621_40_ok"',
#   'help': ''},
#  'GT_FIELD': {'name': 'GT_FIELD',
#   'inferred_type_name': 'None',
#   'default': '"ground_truth"',
#   'help': ''},
#  'FILENAME_YEAR': {'name': 'FILENAME_YEAR',
#   'inferred_type_name': 'None',
#   'default': '2024',
#   'help': ''},
#  'MIN_IMAGE_SIZE': {'name': 'MIN_IMAGE_SIZE',
#   'inferred_type_name': 'None',
#   'default': '3400',
#   'help': '宽或高小于此值视为异常'},
#  'TAG_BAD_FILENAME': {'name': 'TAG_BAD_FILENAME',
#   'inferred_type_name': 'None',
#   'default': '"bad_filename"',
#   'help': ''},
#  'TAG_BAD_BBOX': {'name': 'TAG_BAD_BBOX',
#   'inferred_type_name': 'None',
#   'default': '"bad_bbox"',
#   'help': ''},
#  'ENABLE_AUTO_TAG': {'name': 'ENABLE_AUTO_TAG',
#   'inferred_type_name': 'None',
#   'default': 'False',
#   'help': '改为 True 才自动打 Tag'}}
