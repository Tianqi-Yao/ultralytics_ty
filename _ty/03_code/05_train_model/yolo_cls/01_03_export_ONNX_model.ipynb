# %% [markdown]
# # 导出ONNX模型

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/workspace/_ty/02_models/best_models/91_swd_cls/data_split_0.6_0.4_0.0_yolo11m-cls_4.pt")  # load a custom trained model

# Export the model
model.export(format="onnx")
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Core(TM) Ultra 7 265KF)
# YOLO11m-cls summary (fused): 57 layers, 10,345,475 parameters, 0 gradients, 39.3 GFLOPs
#
# PyTorch: starting from '/workspace/_ty/02_models/best_models/91_swd_cls/data_split_0.6_0.4_0.0_yolo11m-cls_4.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 3) (19.9 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 0.7s, saved as '/workspace/_ty/02_models/best_models/91_swd_cls/data_split_0.6_0.4_0.0_yolo11m-cls_4.onnx' (39.5 MB)
#
# Export complete (2.1s)
# Results saved to /workspace/_ty/02_models/best_models/91_swd_cls
# Predict:         yolo predict task=classify model=/workspace/_ty/02_models/best_models/91_swd_cls/data_split_0.6_0.4_0.0_yolo11m-cls_4.onnx imgsz=224
# ...
