# %% [markdown]
# # Grad-Cam  可视化与可解释
# ## 一张照片例子

# %%
model_path = "/workspace/models/best_model/yolo11m-cls-best_v8.pt"
img_path = "/workspace/models/SAHI/run_v7/air2_0729-0813_04/raw_data_sliced_merge/06_track_galleries_v9/id_0001_x1_swd/01_07-29_13:37_0729_1337_640.jpg"
out_path = "/workspace/models/gradcam"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os, glob, cv2, torch, numpy as np
from pathlib import Path
from ultralytics import YOLO

# grad-cam 家族（按需开关）
from pytorch_grad_cam import GradCAM, GradCAMPlusPlus, EigenCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# ==================== 你可以在这里配置 ====================
MODEL = model_path              # 你的 yolov11-cls 权重
IMGS  = img_path            # 文件/通配/目录
IMG_SIZE = 224                 # 和训练一致：常见 224/256/384/512
DO_METHODS = ("gradcam", "gradcam++", "eigen")  # 要导出的 CAM 类型
TARGET_CLASS = "swd"            # None=自动Top1；或 int 类别id；或 str 类名
SAVE_ORIG_OVERLAY = False       # 同时在“原始分辨率”上叠加一份热力图
OUT_DIR = out_path            # 输出目录
ALPHA = 0.7                   # 叠加透明度（show_cam_on_image 内部使用）
# =========================================================

# ---------- 稳妥的日志与断言工具 ----------
def _assert_tensor4d_rgb01(x: torch.Tensor):
    assert x.ndim == 4 and x.shape[0] == 1, f"Expect [1,3,H,W], got {tuple(x.shape)}"
    assert x.shape[1] == 3, f"Expect 3 channels RGB, got {x.shape[1]}"
    assert x.dtype in (torch.float32, torch.float16, torch.bfloat16), f"Expect float tensor, got {x.dtype}"

# ---------- 预处理：优先用 ultralytics 官方 classify_transforms ----------
def build_preprocess(imgsz: int):
    """
    返回 preprocess(img_bgr) -> (rgb01_square, tensor, meta)
    meta 用于把 CAM 回投影回原图：包含 scale 和 padding。
    如果官方 transforms 不可用，则回退到 letterbox_square。
    """
    try:
        from ultralytics.data.augment import classify_transforms
        tfm = classify_transforms(imgsz=imgsz)  # 返回一个可调用对象
        def _preprocess(img_bgr):
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            out = tfm(image=img_rgb)            # dict {'img': tensor[C,H,W], ...}
            tensor = out["img"].unsqueeze(0)    # [1,3,H,W], float, 0~1
            # 我们不知道官方是否做了crop，这里只保证方形尺寸与张量一致
            H, W = tensor.shape[2:]
            rgb01_square = cv2.resize(img_rgb, (W, H), interpolation=cv2.INTER_LINEAR).astype(np.float32)/255.0
            meta = dict(mode="unknown_square", size=(H, W))  # 用于后续安全叠加
            return rgb01_square, tensor, meta
        return _preprocess
    except Exception:
        # —— 回退：我们自己做“等比缩放 + 居中填充”的正方形 letterbox —— #
        def letterbox_square(img_bgr, new_size, color=(114,114,114)):
            h, w = img_bgr.shape[:2]
            scale = min(new_size / h, new_size / w)
            nh, nw = int(round(h * scale)), int(round(w * scale))
            resized = cv2.resize(img_bgr, (nw, nh), interpolation=cv2.INTER_LINEAR)
            top = (new_size - nh) // 2
            bottom = new_size - nh - top
            left = (new_size - nw) // 2
            right = new_size - nw - left
            padded = cv2.copyMakeBorder(resized, top, bottom, left, right,
                                        borderType=cv2.BORDER_CONSTANT, value=color)
            meta = dict(mode="letterbox", scale=scale, pad=(top, bottom, left, right), resized_hw=(nh, nw))
            return padded, meta

        def _preprocess(img_bgr):
            sq_bgr, meta = letterbox_square(img_bgr, imgsz)
            rgb01 = cv2.cvtColor(sq_bgr, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
            tensor = torch.from_numpy(rgb01).permute(2,0,1).unsqueeze(0)  # [1,3,H,W]
            return rgb01, tensor, meta
        return _preprocess

# ---------- 把方形 CAM 回投影到原始图尺寸（仅对 letterbox 回退路径严格正确） ----------
def cam_to_original(grayscale_cam, orig_shape, meta):
    H0, W0 = orig_shape[:2]
    if meta.get("mode") != "letterbox":
        # 官方 transforms 情况不保证有精确逆变换；退化到简单 resize 回原图大小
        cam_resized = cv2.resize(grayscale_cam, (W0, H0), interpolation=cv2.INTER_LINEAR)
        return cam_resized
    # letterbox: 先把 CAM 裁掉 padding，再按 1/scale 放大回原尺寸
    top, bottom, left, right = meta["pad"]
    nh, nw = meta["resized_hw"]
    size = top + nh + bottom  # == left + nw + right == square size
    # CAM 先缩放到 square，再去掉边
    cam_sq = cv2.resize(grayscale_cam, (size, size), interpolation=cv2.INTER_LINEAR)
    cam_cropped = cam_sq[top: top+nh, left: left+nw]
    cam_orig = cv2.resize(cam_cropped, (W0, H0), interpolation=cv2.INTER_LINEAR)
    return cam_orig

# ---------- 选择“最后一个 Conv2d” ----------
def find_last_conv_layer(module: torch.nn.Module):
    last = None
    for m in module.modules():
        if isinstance(m, torch.nn.Conv2d):
            last = m
    if last is None:
        raise RuntimeError("未在模型中找到 Conv2d 层，请确认这是分类权重。")
    return last

# ---------- 统一输出：[N,C] logits ----------
class LogitsOnly(torch.nn.Module):
    def __init__(self, base: torch.nn.Module):
        super().__init__()
        self.base = base
    def forward(self, x):
        out = self.base(x)
        if torch.is_tensor(out) and out.ndim == 2:
            return out
        if isinstance(out, (list, tuple)):
            for t in out:
                if torch.is_tensor(t) and t.ndim == 2:
                    return t
            for t in out:
                if torch.is_tensor(t):
                    return t
        if isinstance(out, dict):
            if "logits" in out and torch.is_tensor(out["logits"]):
                return out["logits"]
            for v in out.values():
                if torch.is_tensor(v) and v.ndim == 2:
                    return v
        raise TypeError(f"无法从模型输出提取 logits（got {type(out)})")

# ---------- 根据类名/类id 解析目标类别 ----------
def resolve_target_class(target, names):
    if target is None:
        return None
    if isinstance(target, int):
        return target
    if isinstance(target, str):
        if isinstance(names, dict):
            inv = {v: k for k, v in names.items()}
            if target in inv:
                return inv[target]
    raise ValueError(f"TARGET_CLASS 无法解析：{target!r}")

# ---------- 主流程 ----------
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    os.makedirs(OUT_DIR, exist_ok=True)

    # 1) 加载 YOLOv11-cls
    wrapper = YOLO(MODEL)
    base: torch.nn.Module = wrapper.model.eval().to(device)  # 原始 nn.Module
    net  = LogitsOnly(base).eval().to(device)                 # 统一输出
    target_layer = find_last_conv_layer(base)
    class_names = getattr(wrapper, "names", None)

    # 2) 预处理
    preprocess = build_preprocess(IMG_SIZE)

    # 3) 收集图片
    if os.path.isdir(IMGS):
        paths = sorted(sum([glob.glob(str(Path(IMGS)/p)) for p in ("*.jpg","*.jpeg","*.png","*.bmp","*.webp")], []))
    elif any(ch in IMGS for ch in "*?[]"):
        paths = sorted(glob.glob(IMGS))
    else:
        paths = [IMGS]
    assert paths, f"未找到图片：{IMGS}"

    # 4) 目标类解析（允许 None / int / str）
    target_id = resolve_target_class(TARGET_CLASS, class_names)

    # 5) CAM 方法映射
    method_map = {
        "gradcam": GradCAM,
        "gradcam++": GradCAMPlusPlus,
        "eigen": EigenCAM
    }
    methods = [m for m in DO_METHODS if m in method_map]
    assert methods, f"DO_METHODS 设置有误：{DO_METHODS}"

    # 6) 推理 + CAM
    for p in paths:
        img_bgr = cv2.imread(p)
        if img_bgr is None:
            print(f"[跳过] 无法读取 {p}")
            continue
        rgb01_square, x, meta = preprocess(img_bgr)   # rgb01:[H,W,3] in [0,1]; x:[1,3,H,W]
        x = x.to(device)
        _assert_tensor4d_rgb01(x)

        # ====== 关键：CAM 前必须允许梯度 ======
        torch.set_grad_enabled(True)
        net.zero_grad(set_to_none=True)
        for param in net.parameters():
            param.requires_grad_(True)
        x.requires_grad_(True)

        # 自动 Top1 或指定类
        cam_targets = None if target_id is None else [ClassifierOutputTarget(target_id)]

        # ====== 做 CAM（逐方法导出） ======
        for mname in methods:
            CAM = method_map[mname]
            with CAM(model=net, target_layers=[target_layer]) as cam:
                grayscale_cam = cam(input_tensor=x, targets=cam_targets)[0]  # HxW, 0~1

            # 方形图上叠加
            vis_square = show_cam_on_image(rgb01_square.copy(), grayscale_cam, use_rgb=True, image_weight=ALPHA)
            stem = Path(p).stem
            out1 = os.path.join(OUT_DIR, f"{stem}_{mname}_square.jpg")
            cv2.imwrite(out1, cv2.cvtColor(vis_square, cv2.COLOR_RGB2BGR))

            # 原图上叠加（尽可能复原）
            if SAVE_ORIG_OVERLAY:
                cam_orig = cam_to_original(grayscale_cam, img_bgr.shape, meta)
                cam_orig_rgb = show_cam_on_image(
                    cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB).astype(np.float32)/255.0,
                    cam_orig, use_rgb=True, image_weight=ALPHA)
                out2 = os.path.join(OUT_DIR, f"{stem}_{mname}_orig.jpg")
                cv2.imwrite(out2, cv2.cvtColor(cam_orig_rgb, cv2.COLOR_RGB2BGR))

        # ====== 单独做一次无梯度前向，只为显示 Top1 名称/概率 ======
        with torch.no_grad():
            logits = net(x.detach())
            probs  = torch.softmax(logits.float(), dim=1)
            top1   = int(probs.argmax(dim=1).item())
            top1_p = float(probs[0, top1].item())
        top1_name = class_names.get(top1, top1) if isinstance(class_names, dict) else top1
        target_disp = (class_names.get(target_id, target_id) if isinstance(class_names, dict) else target_id) if target_id is not None else f"Top1({top1_name})"

        print(f"[OK] {p} | Pred={top1_name} ({top1_p:.3f}) | CAM for {target_disp} -> {OUT_DIR}")
    print("全部完成。")

if __name__ == "__main__":
    main()
# Out:
# [OK] /workspace/models/SAHI/run_v7/air2_0729-0813_04/raw_data_sliced_merge/06_track_galleries_v9/id_0001_x1_swd/01_07-29_13:37_0729_1337_640.jpg | Pred=others (0.576) | CAM for swd -> /workspace/models/gradcam
# 全部完成。

# %% [markdown]
# ## 批量执行

# %%
# model_path = "/workspace/models/best_model/yolo11m-cls-best_v8.pt"
# model_path = "/workspace/models/best_model/yolo11m-cls-best_v7.pt"
# model_path = "/workspace/models/best_model/yolo11m-cls-best_v6.pt"
model_path = "/workspace/models/best_model/yolo11n-cls-best_v5.pt"
# model_path = "/workspace/models/best_model/yolo11m-cls-best_v4.pt"
# model_path = "/workspace/models/best_model/yolo11s-cls-best_v3.pt"
# model_path = "/workspace/models/best_model/yolo11s-cls-best_v2.pt"

imgs_folder_path = "/workspace/models/runs_yolov11_cls/cropped_objects/swd"
out_path = "/workspace/models/gradcam"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os, glob, cv2, torch, numpy as np
from pathlib import Path
from ultralytics import YOLO

from pytorch_grad_cam import GradCAM, GradCAMPlusPlus, EigenCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# ==================== 配置 ====================
MODEL = model_path               # yolov11-cls 权重
IMGS  = imgs_folder_path         # 目录 / 文件 / 通配
IMG_SIZE = 224                   # 与训练一致：224/256/384/512
DO_METHODS = ("gradcam", "gradcam++", "eigen")
TARGET_CLASS = "swd"               # None=自动Top1；或 int 类别id；或 str 类名
SAVE_ORIG_OVERLAY = False        # 同时在原图大小上叠加一份
OUT_DIR = out_path               # 基础输出目录
ALPHA = 0.7                      # 叠加透明度（show_cam_on_image 内部使用）
# =================================================

def _assert_tensor4d_rgb01(x: torch.Tensor):
    assert x.ndim == 4 and x.shape[0] == 1, f"Expect [1,3,H,W], got {tuple(x.shape)}"
    assert x.shape[1] == 3, f"Expect 3 channels RGB, got {x.shape[1]}"
    assert x.dtype in (torch.float32, torch.float16, torch.bfloat16), f"Expect float tensor, got {x.dtype}"

def build_preprocess(imgsz: int):
    try:
        from ultralytics.data.augment import classify_transforms
        tfm = classify_transforms(imgsz=imgsz)
        def _preprocess(img_bgr):
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            out = tfm(image=img_rgb)
            tensor = out["img"].unsqueeze(0)
            H, W = tensor.shape[2:]
            rgb01_square = cv2.resize(img_rgb, (W, H), interpolation=cv2.INTER_LINEAR).astype(np.float32)/255.0
            meta = dict(mode="unknown_square", size=(H, W))
            return rgb01_square, tensor, meta
        return _preprocess
    except Exception:
        def letterbox_square(img_bgr, new_size, color=(114,114,114)):
            h, w = img_bgr.shape[:2]
            scale = min(new_size / h, new_size / w)
            nh, nw = int(round(h * scale)), int(round(w * scale))
            resized = cv2.resize(img_bgr, (nw, nh), interpolation=cv2.INTER_LINEAR)
            top = (new_size - nh) // 2
            bottom = new_size - nh - top
            left = (new_size - nw) // 2
            right = new_size - nw - left
            padded = cv2.copyMakeBorder(resized, top, bottom, left, right,
                                        borderType=cv2.BORDER_CONSTANT, value=color)
            meta = dict(mode="letterbox", scale=scale, pad=(top,bottom,left,right), resized_hw=(nh,nw))
            return padded, meta
        def _preprocess(img_bgr):
            sq_bgr, meta = letterbox_square(img_bgr, imgsz)
            rgb01 = cv2.cvtColor(sq_bgr, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
            tensor = torch.from_numpy(rgb01).permute(2,0,1).unsqueeze(0)
            return rgb01, tensor, meta
        return _preprocess

def cam_to_original(grayscale_cam, orig_shape, meta):
    H0, W0 = orig_shape[:2]
    if meta.get("mode") != "letterbox":
        return cv2.resize(grayscale_cam, (W0, H0), interpolation=cv2.INTER_LINEAR)
    top, bottom, left, right = meta["pad"]
    nh, nw = meta["resized_hw"]
    size = top + nh + bottom
    cam_sq = cv2.resize(grayscale_cam, (size, size), interpolation=cv2.INTER_LINEAR)
    cam_cropped = cam_sq[top: top+nh, left: left+nw]
    cam_orig = cv2.resize(cam_cropped, (W0, H0), interpolation=cv2.INTER_LINEAR)
    return cam_orig

def find_last_conv_layer(module: torch.nn.Module):
    last = None
    for m in module.modules():
        if isinstance(m, torch.nn.Conv2d):
            last = m
    if last is None:
        raise RuntimeError("未在模型中找到 Conv2d 层，请确认是分类权重。")
    return last

class LogitsOnly(torch.nn.Module):
    def __init__(self, base: torch.nn.Module):
        super().__init__()
        self.base = base
    def forward(self, x):
        out = self.base(x)
        if torch.is_tensor(out) and out.ndim == 2:
            return out
        if isinstance(out, (list, tuple)):
            for t in out:
                if torch.is_tensor(t) and t.ndim == 2:
                    return t
            for t in out:
                if torch.is_tensor(t):
                    return t
        if isinstance(out, dict):
            if "logits" in out and torch.is_tensor(out["logits"]):
                return out["logits"]
            for v in out.values():
                if torch.is_tensor(v) and v.ndim == 2:
                    return v
        raise TypeError(f"无法从模型输出提取 logits（got {type(out)})")

def resolve_target_class(target, names):
    if target is None:
        return None
    if isinstance(target, int):
        return target
    if isinstance(target, str):
        if isinstance(names, dict):
            inv = {v: k for k, v in names.items()}
            if target in inv:
                return inv[target]
    raise ValueError(f"TARGET_CLASS 无法解析：{target!r}")

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    os.makedirs(OUT_DIR, exist_ok=True)

    wrapper = YOLO(MODEL)
    base: torch.nn.Module = wrapper.model.eval().to(device)
    net  = LogitsOnly(base).eval().to(device)
    target_layer = find_last_conv_layer(base)
    class_names = getattr(wrapper, "names", None)

    preprocess = build_preprocess(IMG_SIZE)

    if os.path.isdir(IMGS):
        paths = sorted(sum([glob.glob(str(Path(IMGS)/p)) for p in ("*.jpg","*.jpeg","*.png","*.bmp","*.webp")], []))
    elif any(ch in IMGS for ch in "*?[]"):
        paths = sorted(glob.glob(IMGS))
    else:
        paths = [IMGS]
    assert paths, f"未找到图片：{IMGS}"

    target_id = resolve_target_class(TARGET_CLASS, class_names)

    method_map = {
        "gradcam": GradCAM,
        "gradcam++": GradCAMPlusPlus,
        "eigen": EigenCAM
    }
    methods = [m for m in DO_METHODS if m in method_map]
    assert methods, f"DO_METHODS 设置有误：{DO_METHODS}"

    # —— 为每个方法准备子目录 —— #
    method_dirs = {}
    for mname in methods:
        mdir = os.path.join(OUT_DIR, mname)
        os.makedirs(mdir, exist_ok=True)
        method_dirs[mname] = mdir

    for p in paths:
        img_bgr = cv2.imread(p)
        if img_bgr is None:
            print(f"[跳过] 无法读取 {p}")
            continue
        rgb01_square, x, meta = preprocess(img_bgr)
        x = x.to(device)
        _assert_tensor4d_rgb01(x)

        torch.set_grad_enabled(True)
        net.zero_grad(set_to_none=True)
        for param in net.parameters():
            param.requires_grad_(True)
        x.requires_grad_(True)

        cam_targets = None if target_id is None else [ClassifierOutputTarget(target_id)]
        stem = Path(p).stem

        for mname in methods:
            CAM = method_map[mname]
            with CAM(model=net, target_layers=[target_layer]) as cam:
                grayscale_cam = cam(input_tensor=x, targets=cam_targets)[0]

            vis_square = show_cam_on_image(rgb01_square.copy(), grayscale_cam, use_rgb=True, image_weight=ALPHA)
            out_square = os.path.join(method_dirs[mname], f"{stem}_square.jpg")
            cv2.imwrite(out_square, cv2.cvtColor(vis_square, cv2.COLOR_RGB2BGR))

            if SAVE_ORIG_OVERLAY:
                cam_orig = cam_to_original(grayscale_cam, img_bgr.shape, meta)
                cam_orig_rgb = show_cam_on_image(
                    cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB).astype(np.float32)/255.0,
                    cam_orig, use_rgb=True, image_weight=ALPHA)
                out_orig = os.path.join(method_dirs[mname], f"{stem}_orig.jpg")
                cv2.imwrite(out_orig, cv2.cvtColor(cam_orig_rgb, cv2.COLOR_RGB2BGR))

        # 单独做一次无梯度前向，只为打印信息
        with torch.no_grad():
            logits = net(x.detach())
            probs  = torch.softmax(logits.float(), dim=1)
            top1   = int(probs.argmax(dim=1).item())
            top1_p = float(probs[0, top1].item())
        top1_name = class_names.get(top1, top1) if isinstance(class_names, dict) else top1
        target_disp = (class_names.get(target_id, target_id) if isinstance(class_names, dict) else target_id) if target_id is not None else f"Top1({top1_name})"
        print(f"[OK] {p} | Pred={top1_name} ({top1_p:.3f}) | Methods -> {', '.join(methods)} in {OUT_DIR}")

    print("全部完成。输出目录：", OUT_DIR)

if __name__ == "__main__":
    main()
# Out:
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/01_06-16_06_02_0616_0602_580.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/01_07-16_06_38_0716_0638_820.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/02_06-16_06_12_0616_0612_580.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/02_07-16_07_52_0716_0752_820.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/03_07-16_08_44_0716_0844_820.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/04_07-16_08_48_0716_0848_740.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_0731_700_obj0_swd_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_0731_700_obj6_swd_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_0801_700_obj1_swd_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_0831_700_obj4_swd_uuid_43850137-a234-44c7-8005-fc9f3ba5394d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_0901_700_obj2_swd_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_1031_700_obj4_swd_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0607_1031_700_obj7_swd_uuid_68e56662-0412-4703-ab87-2b36a4cb2393.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1131_700_obj0_swd_uuid_d171f9a1-1d37-4230-893f-82049d74cb05.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1131_700_obj1_swd_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1201_700_obj2_swd_uuid_57a22d60-d965-4788-a1b5-5bfc62336b07.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1301_700_obj0_swd_uuid_d64091e3-4914-4ff0-8665-3618096f71da.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1301_700_obj3_swd_uuid_bde9315e-4bf4-47f6-ace3-016391cf26fc.jpg | Pred=others (0.563) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1331_700_obj6_swd_uuid_809d621f-894a-4b1c-b5ce-bebc064c7b93.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1401_700_obj3_swd_uuid_e0a7482d-c38a-4278-9796-53af48e2400e.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1401_700_obj6_swd_uuid_ed36fbce-ec0a-41a9-8271-26a0a5d0639d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1431_700_obj7_swd_uuid_5273fab0-16e6-494b-a2ae-9710cf159313.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1501_700_obj6_swd_uuid_d9958617-2b53-4b46-8d1f-f7a402c047d3.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1531_700_obj10_swd_uuid_931bda08-0145-47a3-8880-832ad4df40b8.jpg | Pred=others (0.569) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0611_1631_700_obj8_swd_uuid_00600deb-0c3e-4468-8a4c-e41d8b6204ab.jpg | Pred=others (0.565) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0612_0701_700_obj10_swd_uuid_3b6bb0e6-8ea7-49e0-ba63-d97566a20a19.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0612_0831_700_obj17_swd_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_0931_700_obj0_swd_uuid_0c5612bc-2f33-4df4-8951-1171d802812c.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_0931_700_obj1_swd_uuid_66ef8c78-572b-4509-af31-8b7dbc5fdf19.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_0931_700_obj21_swd_uuid_932dccde-efb5-4c4f-81c4-647ecad04bc1.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_1001_700_obj14_swd_uuid_35c5f557-da9a-4288-bd74-fb486f4a4e78.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_1001_700_obj1_swd_uuid_2090a01b-d10e-4099-ac80-947b03273c0e.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_1031_700_obj0_swd_uuid_682712ba-90b0-426d-bdb1-95dc0615c5fd.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_1031_700_obj21_swd_uuid_cdb5505e-1a2c-4b61-816e-1edca1f7f879.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_1101_700_obj11_swd_uuid_0dc895d4-f5b5-454f-a65f-5ecd09f8b405.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0614_1131_700_obj78_swd_uuid_78b859a6-390c-41a1-a975-607ec4ccff0d.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0617_0947_780_obj21_swd_uuid_24bc624c-5c0a-429b-a6dd-6ccfa6f4ab64.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0617_1208_780_obj22_swd_uuid_0f4de36e-8803-41d2-bbe2-8d38eb5dff92.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0618_0838_780_obj10_swd_uuid_a041a009-292c-455b-afc1-42aa1dad5e15.jpg | Pred=others (0.570) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0618_1008_780_obj2_swd_uuid_0ebfdb29-6a63-4ed7-a03d-fa4bb851b616.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0618_1108_780_obj4_swd_uuid_7ef8f9df-718c-4df0-aea0-5c98164e3cb0.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0619_0731_700_obj29_swd_uuid_9737ea3c-2f78-4869-bd6f-0045c583a414.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0707_2027_760_obj0_swd_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2.jpg | Pred=others (0.560) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0707_2106_760_obj0_swd_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_0357_760_obj1_swd_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_0457_760_obj1_swd_uuid_a66530e3-4460-4761-85fc-2548345385e9.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_0457_760_obj7_swd_uuid_2311272d-3825-4fee-be48-6a8d73936cd4.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_0458_800_obj6_swd_uuid_3553c5e8-68ca-4eb9-b2f4-1ac96a9144a5.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_0527_760_obj2_swd_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c.jpg | Pred=others (0.570) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_1157_760_obj3_swd_uuid_8c9cd716-4380-4ed9-9d3e-14e3d4614390.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_1922_760_obj1_swd_uuid_ac32b96a-93b9-4c9f-83c8-cb739da6fbdb.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0709_1952_760_obj3_swd_uuid_afe891a5-c230-47c3-b326-128c8d4cf500.jpg | Pred=others (0.564) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0716_2005_600_obj0_swd_uuid_6280a194-c455-4e1d-bfe1-14ff887d20f3.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0716_2006_640_obj0_swd_uuid_66f4a0b4-6f9a-4b15-87b3-ec97f9e3ade9.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0716_2008_680_obj2_swd_uuid_acecd886-1bf2-456b-9c41-6de1edd8dde2.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0607_640_obj1_swd_uuid_682f3e4e-5f14-4a32-ac14-f19d8e148f9b.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0607_640_obj3_swd_uuid_fcd43230-bec7-49e5-9752-2c90a11ed7ac.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0607_640_obj4_swd_uuid_ecedf4cf-03ac-4a42-9e4c-f5ddeb63bb12.jpg | Pred=others (0.559) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0608_680_obj10_swd_uuid_4234817c-4909-4d3f-bf6c-c71773600743.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0635_640_obj0_swd_uuid_1c52d7b9-ed3e-455d-a4a8-55045721bb11.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0635_640_obj21_swd_uuid_fe19a80e-31bd-4641-a554-ee944b513278.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0705_640_obj2_swd_uuid_bbff0fbe-4573-475d-9de0-c98a7857fff1.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0705_640_obj47_swd_uuid_55b08a45-f860-494a-be30-96753c43a17c.jpg | Pred=others (0.561) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0707_680_obj0_swd_uuid_54f55b71-4a3a-4add-bf87-60d02dd195eb.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0707_680_obj17_swd_uuid_482cad8b-aea5-47d3-bf97-da1accb8064d.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0734_600_obj1_swd_uuid_3b23fde5-0e7b-4eb0-95de-51f31898ac47.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0735_640_obj12_swd_uuid_5be41150-30f2-4706-9316-0095e245d757.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0737_680_obj0_swd_uuid_13e61627-eb37-4451-a7f5-a425be72ffb5.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0737_680_obj20_swd_uuid_23c6a032-f1d3-4ad1-bf51-af6271d32bf0.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0804_600_obj32_swd_uuid_032cbee1-dac0-4ce1-8dec-bc8dd756aafe.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0805_640_obj6_swd_uuid_e51dcbfc-29b2-4f76-858f-f8e1b8011641.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0717_0807_680_obj0_swd_uuid_b3e44a45-7e77-4666-860f-234364cbdd80.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj0_swd_uuid_7e16cd77-348f-4c85-967b-cb11074f9cc4.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj100_swd_uuid_2658e8a8-b6c1-4fdd-904e-f016022e27a5.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj110_swd_uuid_d4a36cc5-845a-408c-bc28-45e531e7349a.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj118_swd_uuid_a6e2aacc-ca1d-48e6-a45b-45dc6c9e7613.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj11_swd_uuid_ccec919e-ae17-4c50-a34c-1930cd3ed7ce.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj12_swd_uuid_c0f3fc2b-3037-476a-87a9-7638d153f6f5.jpg | Pred=others (0.566) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj13_swd_uuid_d63dc616-a379-4f42-afec-14644b466a27.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj16_swd_uuid_0724bcb8-3cbf-4b26-967f-217cab143219.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj17_swd_uuid_ce70fbe6-c438-44cb-a2af-7ff70411e36d.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj19_swd_uuid_fa0734d7-7a09-45f7-bea8-80e1c8d500ed.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj1_swd_uuid_e1fca472-8ada-4cd2-a3d9-313148080064.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj20_swd_uuid_c81c7a4f-4a95-4966-a947-1b173d51ea06.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj21_swd_uuid_2c925241-8f3c-41a7-a75f-40d80d3c00ba.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj22_swd_uuid_d146a05f-83a4-4296-9fe0-c9b10e3e4cf2.jpg | Pred=others (0.563) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj23_swd_uuid_e970103d-a5c3-4da6-8dd2-eb8ace3abc06.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj24_swd_uuid_88c591c1-bab1-44cb-9212-9921f8e8e2d8.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj25_swd_uuid_7276dbdb-bb45-4f00-8997-04619470c907.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj26_swd_uuid_ccdf27b4-34ae-4927-8c20-d1acc6c372b6.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj33_swd_uuid_9cf41af7-0ac2-4b56-9630-18f97029aaee.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj39_swd_uuid_ca610392-642d-4122-af32-f69a03c3b696.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj3_swd_uuid_7f79bb59-db0f-4f4d-831c-0a98f5c829a9.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj46_swd_uuid_db0aa6a5-e637-42e9-a7bd-7495318fca98.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj47_swd_uuid_16e1ceae-fc2c-4b24-983f-3c55b7a20384.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj49_swd_uuid_6eb6b405-9327-40a9-a213-795b4430ee83.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj4_swd_uuid_f00273a4-df1e-4667-87ec-02ecb48d82c1.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj52_swd_uuid_2154f12b-4801-48ae-87be-0270fcde50b2.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj55_swd_uuid_d376f5e3-17e8-4e8f-be48-ed7196f3c5da.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj58_swd_uuid_43409b19-f1f8-41ad-bad4-406a422c60c0.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj5_swd_uuid_1e081cfd-e9e5-422a-b915-9a1191bcadcc.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj66_swd_uuid_fb478a08-2234-40b4-9066-e3a4bc57ad2a.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj68_swd_uuid_ca214a41-70ac-4ca0-8b48-024a22888c1c.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj6_swd_uuid_412c71a8-4c34-4933-89d7-3be620e21ce7.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj71_swd_uuid_5ff31570-85c2-4a6b-aeb8-ed714ec1eaaa.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj72_swd_uuid_a6feb86e-0f70-421f-9a92-37f43acaf50c.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj75_swd_uuid_8b8b49aa-cbf5-4c48-9eae-d5c350be16b0.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj76_swd_uuid_d90f2717-04ad-4acd-a54e-1ac23225dddc.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj7_swd_uuid_b4371061-b3dd-4493-a992-9de3535f611c.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj83_swd_uuid_24f8a94b-6328-463d-94e5-9379c50b728e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj84_swd_uuid_09bb14a2-86de-4fe5-ae85-aadc401255d8.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj88_swd_uuid_ef230297-d521-4c26-a666-8a9eda5e88ad.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj8_swd_uuid_45372ca7-e42b-4ece-8cb5-81219f145246.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj92_swd_uuid_66b424e4-12b2-4b6a-b5b4-cfe9fad76c4f.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj99_swd_uuid_379e8de8-1cf1-485e-a130-5c0789bda1ba.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0603_540_obj9_swd_uuid_b3630d1a-f51a-4937-8bdf-0719c36a4df6.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj0_swd_uuid_b812225d-fb4e-459c-b6ff-69cc47770519.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj100_swd_uuid_159f4a3e-070e-4d86-a537-fb2b52c81442.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj102_swd_uuid_00a70a8a-2a5f-4beb-ba09-305db855cdb5.jpg | Pred=others (0.555) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj105_swd_uuid_a04251e3-71ec-4c03-a7ba-e8b4af87ec51.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj109_swd_uuid_d5ec5baa-ff76-4e46-8106-c8ccb9aaf918.jpg | Pred=others (0.569) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj10_swd_uuid_9fa24f7f-d9f1-4b81-9f3d-398ad4da38e7.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj112_swd_uuid_7e97b943-3312-43d2-9fee-df1ef22d26dc.jpg | Pred=others (0.567) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj114_swd_uuid_8fa16185-8b67-434f-8759-e3b6a34da481.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj117_swd_uuid_d751c797-c83d-4a6e-bb78-f95efbea8287.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj11_swd_uuid_47bd76dd-db23-4de9-b845-56b8242a7729.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj121_swd_uuid_4d0bb137-83c1-4cba-91aa-b039dcdca64c.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj125_swd_uuid_09af853e-4ebd-45d9-8a83-a78499bf732b.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj127_swd_uuid_0fd4a10d-0de1-44f7-a0fa-ad8020fa7893.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj12_swd_uuid_35fe6e14-6aa9-4d39-a6b3-1f0a176d6a14.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj143_swd_uuid_9b4e3e34-32dc-4446-a98e-ed82fa6c23e7.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj144_swd_uuid_29cfc240-0eba-4ff3-a757-e612b0295814.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj15_swd_uuid_512aa0bb-dcdb-4c9c-bb60-c2a1d333485e.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj16_swd_uuid_cf045604-3253-4617-b715-44a183c310e4.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj18_swd_uuid_7f422d1b-99d3-4926-9427-ba6196bb9280.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj19_swd_uuid_98e62cc7-05f1-4990-a281-80e6fa27234a.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj1_swd_uuid_1290a74e-0151-4b5c-87c3-8029b564c094.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj20_swd_uuid_7dba3ca0-dc79-41f9-a705-0b59dbfa4149.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj21_swd_uuid_06846582-4314-4c59-8048-f6616034f9de.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj22_swd_uuid_fd91b830-6b59-45f7-9fcb-8112093a6aa4.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj23_swd_uuid_0d971a44-af84-497d-9620-11cb4a3abad7.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj24_swd_uuid_53cf20bf-8349-4b27-a5c4-bad7225d05f0.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj25_swd_uuid_709449d2-53c5-499d-96cf-20a28350a70c.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj26_swd_uuid_ac988cdb-3bbe-4eb9-a19f-43be5fa2f139.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj29_swd_uuid_28f6259e-2421-435c-83cf-d7f43e65ee61.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj2_swd_uuid_b4125e47-ef79-4f83-9180-b26333f17516.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj30_swd_uuid_69ad3deb-9a58-47ae-a26f-0991265f8e84.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj31_swd_uuid_4feae038-61a4-4ffe-aab7-b35fd4c44110.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj32_swd_uuid_10b41cf3-187b-4d53-8507-2ba31117834e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj34_swd_uuid_f9914882-1b12-4f3b-9dad-4ad469ab56c8.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj35_swd_uuid_f9e9f21f-ab37-4c17-95f1-55fbdfb385d9.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj36_swd_uuid_304e76e3-8d84-4180-981b-4da17d09d9d3.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj37_swd_uuid_b383f0ae-205c-44ae-8cbd-8635e1d3a872.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj38_swd_uuid_d2c8c01f-e3cd-4e21-a6ee-e9f309bdf099.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj39_swd_uuid_20bf3dc2-7fa1-42f9-b427-021e764e9c57.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj3_swd_uuid_db00f7dd-f914-466e-9604-eb33808dc0f1.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj40_swd_uuid_1906e1b0-d135-4174-8bcd-fd46428b9f67.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj41_swd_uuid_e6bed284-393f-4195-b424-dff429b3e442.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj42_swd_uuid_918fe0bf-d021-4f48-9d75-468dc06f2b44.jpg | Pred=others (0.567) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj43_swd_uuid_ebd9931d-afe6-44c4-8999-879f0e130230.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj44_swd_uuid_2522924d-808e-4555-a843-d7b2f26a9df8.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj45_swd_uuid_590831df-36fc-4c8e-8de8-a9ae34d31f8b.jpg | Pred=others (0.570) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj46_swd_uuid_1f91e9fb-ccb3-4b1f-9989-00a391b783ef.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj47_swd_uuid_6fb6a598-15a4-443c-87b7-e3572524e312.jpg | Pred=others (0.566) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj49_swd_uuid_89228717-e707-47cf-b5a9-b07d5b0aed03.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj50_swd_uuid_e4a8c49c-566f-48b4-9534-28cdcdead8c2.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj52_swd_uuid_9b576be4-c662-41fa-aef7-4062a3643bdc.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj56_swd_uuid_7dbd3c55-ba9e-46db-afc2-5545b469ab63.jpg | Pred=others (0.566) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj58_swd_uuid_430f514f-fad8-4846-8346-8f03a8d2c02d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj59_swd_uuid_bef3d953-ba63-4959-ae4c-fdce766d2422.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj5_swd_uuid_34cb6a6d-a118-411f-8d7b-932764714b57.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj62_swd_uuid_c044e2b4-59ef-4c03-8595-b7e1cd4b3d31.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj63_swd_uuid_af1b225b-b7e0-4abf-b7b8-89e437c1f760.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj64_swd_uuid_b335eefc-d798-4fdf-9e1e-05246957b724.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj67_swd_uuid_0337678c-bd4a-442b-934f-5e3d1a7af9f7.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj68_swd_uuid_90092954-202f-48ad-babb-3bb7fffa9911.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj6_swd_uuid_d6aa8e54-d37a-42ce-ac71-6a0e84cff0da.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj70_swd_uuid_b15b4fdd-0da5-48c3-a496-f5fda92c7a1a.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj72_swd_uuid_d365dbd8-d8a6-4f64-bb8d-4f91f85231b6.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj73_swd_uuid_0a854a45-a751-46b0-b13f-ae07b7275bab.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj74_swd_uuid_f68d2524-86f6-4ad9-92e2-eba5fca6c452.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj75_swd_uuid_3129ef49-2c95-4841-a39a-350de1da7abd.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj76_swd_uuid_ba667db1-2025-4c9a-a6c9-d56debd67f3a.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj77_swd_uuid_3f4e211c-f906-4edf-a32c-b35ed3ef85a6.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj78_swd_uuid_340bb0f5-aa10-4c1b-946f-15980f79ad29.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj79_swd_uuid_d01ddf88-14ea-4849-a14b-9f65e3522c50.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj7_swd_uuid_79b2025e-fff9-4bf2-b6b6-e9b3120a1e48.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj81_swd_uuid_c7e9dfec-3952-4bbe-b528-bfb6cef08047.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj85_swd_uuid_af213a7f-c8a2-4dcc-891e-490bc4549afd.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj88_swd_uuid_167baba7-f361-41c7-8d43-f28d89399311.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj89_swd_uuid_4af10e3d-e836-41a9-af6c-0e787d8634f5.jpg | Pred=others (0.568) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj90_swd_uuid_8180ab37-3383-4443-9e72-c50ef7aaf5ff.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj91_swd_uuid_7ac0a96f-b441-4fd1-9fa9-10aa1a8805e1.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj92_swd_uuid_9ee6af68-064e-4f43-a8ee-0f0af3a2ccad.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj93_swd_uuid_70b75809-d81b-4dd4-8154-0ec1afaeb121.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj96_swd_uuid_c2093fd1-9be0-4c5d-adbc-df333a9da923.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj98_swd_uuid_2e473511-2440-412c-b8f4-5ec737d7e3b7.jpg | Pred=others (0.570) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj99_swd_uuid_ebf7d8c6-11d4-4fc0-9d3c-1910a8ed0030.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0604_580_obj9_swd_uuid_64cbdb6a-e49c-47e3-ae95-42f9272085e8.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj102_swd_uuid_3a8745d7-8bea-41d8-a103-d9ad7ce61584.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj106_swd_uuid_6a5ef503-3f54-4b10-8562-6c50435e078d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj10_swd_uuid_3315000c-4385-4ba7-b6e2-41e2e4c4d633.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj110_swd_uuid_d157e055-d310-4726-82d9-fec9a6a1fbf9.jpg | Pred=others (0.560) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj112_swd_uuid_11562946-0e04-49d8-8e20-086504590715.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj115_swd_uuid_d312a5ee-2364-499e-9493-c09b3153583e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj118_swd_uuid_69b46bc8-2ce1-4097-bc3b-e4067317758b.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj11_swd_uuid_c2d720f6-d021-4915-b52e-7180731a9f1d.jpg | Pred=others (0.556) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj121_swd_uuid_503d774b-28bc-4d6e-b4e6-9aaffdef2aa5.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj12_swd_uuid_b09f5bc3-9e1b-43a0-a941-d82fd505d0d1.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj138_swd_uuid_b7775c04-d52d-42b1-8729-abbfb5d6e8f9.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj13_swd_uuid_cb7b144f-68d9-4ea7-9a1b-bdb8510bf13e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj140_swd_uuid_2e17214b-933e-4425-bbf5-1182e5052f69.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj144_swd_uuid_3eb717c8-5c5b-4d91-81b0-18e6ec034ef3.jpg | Pred=others (0.570) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj149_swd_uuid_bcaf886b-c168-42b8-9509-3a21cd9a65d9.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj162_swd_uuid_ee690162-ec30-46b3-bc01-c85ca4785ca7.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj16_swd_uuid_1d54ea7e-cfef-434e-853c-d844108562de.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj17_swd_uuid_b9a0b011-84bb-471f-ab42-5e5a30d0385e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj18_swd_uuid_a3fc0683-0b5e-469d-b138-8ae6da53b93d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0605_600_obj19_swd_uuid_f55a3708-ef8d-4ca3-b0ea-ae54ba25dbb3.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# ...
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj11_swd_uuid_a377f8a1-d604-417b-ad7b-56a11b35a53f.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj12_swd_uuid_8bc959f7-ecd4-4499-a11a-0c851beae943.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj13_swd_uuid_1e2476c8-b7ba-4bf9-b379-03a5c1db3312.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj14_swd_uuid_c3fd4980-8595-4f7b-8870-6fd72e413093.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj15_swd_uuid_7eb1175e-afb0-421a-aff2-8bde0fd3f538.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj16_swd_uuid_52a3a4a3-e05e-48d5-9ad0-207c87cfa882.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj17_swd_uuid_28a1c9cb-3358-4ef2-a29c-585aac94905d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj18_swd_uuid_5e574e9b-ebb9-49a2-a7a7-650ab721734c.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj19_swd_uuid_5818efc0-78a9-4981-a4ff-de1f8a4e6686.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj20_swd_uuid_6424b981-3153-4e6b-ab03-d7226ca3d4ae.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj21_swd_uuid_4ea94154-0da2-485b-ab02-56eb7750acb4.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj25_swd_uuid_8801e44f-1173-448b-873f-fff32d1796b6.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj27_swd_uuid_554467d8-d35a-47d2-b5ac-922ce94584e0.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj28_swd_uuid_a79f9f3f-80c6-4cae-bddb-4276f5e15eb5.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj2_swd_uuid_1ae8ba15-34de-4053-908c-1217d47622dc.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj30_swd_uuid_dd96d364-6e3f-4a54-804e-d5b531fd943d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj38_swd_uuid_e2f7a215-90ea-400b-af4f-2aa51ba8d8b3.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj40_swd_uuid_1e54ef68-a8fb-468b-ac5f-f16d597770ca.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj41_swd_uuid_963bc61b-fc38-42d2-89c2-26711d2df159.jpg | Pred=others (0.571) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj42_swd_uuid_99478b58-8f2c-4795-933b-d7cea9d66ea6.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj45_swd_uuid_436ad8e1-bc47-4cda-b340-cfe9d96371e9.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj46_swd_uuid_9a59dee9-fbca-423e-8204-3b9fd8a87c72.jpg | Pred=others (0.570) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj47_swd_uuid_c590018c-ad5d-41ee-8884-b29c8cbf513b.jpg | Pred=others (0.574) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj49_swd_uuid_da439fb7-32aa-48fd-bc97-83bceecf185c.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj53_swd_uuid_32cbd0b9-5ede-496d-9e8f-cf7651315950.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj54_swd_uuid_839425e3-def4-4bd1-a0d6-6c8fc6cb543f.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj55_swd_uuid_271d6494-ab70-4f85-a43a-6ca32f9c0a27.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj56_swd_uuid_07d0c021-8d67-408c-a517-b9ab03f79c53.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj57_swd_uuid_1ff929c8-6f9f-4620-9c4f-9ac5e7c67f0b.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj5_swd_uuid_f68dad61-a75e-4889-a0e5-dc917d8e477d.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj65_swd_uuid_22f3f098-0860-4ef4-8224-88494d5df57b.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj68_swd_uuid_33a9b0d5-fb01-48c8-be7e-25a1e37fc3cf.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj73_swd_uuid_f5f43414-14df-4659-82c6-093453fee306.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj76_swd_uuid_4938c5d2-6910-44f5-a231-89e1f4b451ba.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj77_swd_uuid_175875e5-a5c0-40c0-bf4e-061de1a90169.jpg | Pred=others (0.567) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj78_swd_uuid_fafd8dfc-742c-4997-abbc-04688c6a221e.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj7_swd_uuid_1e06aaad-4dfb-42e6-b9ee-ade28708beb0.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj80_swd_uuid_33cf5995-9811-4823-bbe2-30da29af1548.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj88_swd_uuid_aa477280-b145-4c47-b717-4eaf7e9d910f.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj8_swd_uuid_d8dc8105-bd12-4d6f-8f1d-bb6db360c771.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0705_600_obj90_swd_uuid_8388402c-75c4-460f-ac2b-8ab6c414619c.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj0_swd_uuid_502da088-1e3d-4d36-8262-95895525703c.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj10_swd_uuid_9fa20cd5-062d-4ee6-b91d-9cae622c8954.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj110_swd_uuid_769bc5ee-47dc-497c-9520-15427b059770.jpg | Pred=others (0.569) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj115_swd_uuid_eba55582-80a4-46f5-9042-701d363c10c6.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj13_swd_uuid_9669d25c-0c52-4f45-9ce2-f3267395bbf6.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj16_swd_uuid_c50d4f45-cdc2-4583-a7bb-cc9c8eee23b0.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj21_swd_uuid_d969029c-cfe5-4a4b-beef-525618785720.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj22_swd_uuid_0c3ce80d-ebd8-4490-8c13-55a973b82ebe.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj24_swd_uuid_666e9b19-3915-41b2-9037-f79c92c9d9cc.jpg | Pred=others (0.572) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj25_swd_uuid_7bbe01d4-4e37-49c3-a77c-d27ce31cd579.jpg | Pred=others (0.556) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj26_swd_uuid_74f9887b-d07a-41cd-9093-77b21fed36eb.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj2_swd_uuid_03168f50-ce5b-423e-b054-01b081cc1596.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj30_swd_uuid_32b1873a-1e81-40e5-b774-69765b83a3d3.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj35_swd_uuid_c65202fb-c5ea-4b62-9197-0c104c288bdd.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# [OK] /workspace/models/runs_yolov11_cls/cropped_objects/swd/0718_0706_640_obj36_swd_uuid_81f57e20-9bbb-42ab-b8eb-4b9ad5d21119.jpg | Pred=others (0.573) | Methods -> gradcam, gradcam++, eigen in /workspace/models/gradcam
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 203
#     200     print("全部完成。输出目录：", OUT_DIR)
#     202 if __name__ == "__main__":
# --> 203     main()
#
# Cell In[39], line 176, in main()
#     174 CAM = method_map[mname]
#     175 with CAM(model=net, target_layers=[target_layer]) as cam:
# --> 176     grayscale_cam = cam(input_tensor=x, targets=cam_targets)[0]
#     178 vis_square = show_cam_on_image(rgb01_square.copy(), grayscale_cam, use_rgb=True, image_weight=ALPHA)
#     179 out_square = os.path.join(method_dirs[mname], f"{stem}_square.jpg")
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_grad_cam/base_cam.py:209, in BaseCAM.__call__(self, input_tensor, targets, aug_smooth, eigen_smooth)
#     206 if aug_smooth is True:
#     207     return self.forward_augmentation_smoothing(input_tensor, targets, eigen_smooth)
# --> 209 return self.forward(input_tensor, targets, eigen_smooth)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_grad_cam/base_cam.py:129, in BaseCAM.forward(self, input_tensor, targets, eigen_smooth)
#     118         self.__htcore.mark_step()
#     120 # In most of the saliency attribution papers, the saliency is
#     121 # computed with a single target layer.
#     122 # Commonly it is the last convolutional layer.
#    (...)    127 # use all conv layers for example, all Batchnorm layers,
#     128 # or something else.
# --> 129 cam_per_layer = self.compute_cam_per_layer(input_tensor, targets, eigen_smooth)
#     130 return self.aggregate_multi_layers(cam_per_layer)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_grad_cam/base_cam.py:164, in BaseCAM.compute_cam_per_layer(self, input_tensor, targets, eigen_smooth)
#     161 if i < len(grads_list):
#     162     layer_grads = grads_list[i]
# --> 164 cam = self.get_cam_image(input_tensor, target_layer, targets, layer_activations, layer_grads, eigen_smooth)
#     165 cam = np.maximum(cam, 0)
#     166 scaled = scale_cam_image(cam, target_size)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_grad_cam/eigen_cam.py:22, in EigenCAM.get_cam_image(self, input_tensor, target_layer, target_category, activations, grads, eigen_smooth)
#      15 def get_cam_image(self,
#      16                   input_tensor,
#      17                   target_layer,
#    (...)     20                   grads,
#      21                   eigen_smooth):
# ---> 22     return get_2d_projection(activations)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_grad_cam/utils/svd_on_activations.py:16, in get_2d_projection(activation_batch)
#      12 # Centering before the SVD seems to be important here,
#      13 # Otherwise the image returned is negative
#      14 reshaped_activations = reshaped_activations - \
#      15     reshaped_activations.mean(axis=0)
# ---> 16 U, S, VT = np.linalg.svd(reshaped_activations, full_matrices=True)
#      17 projection = reshaped_activations @ VT[0, :]
#      18 projection = projection.reshape(activations.shape[1:])
#
# File /opt/conda/lib/python3.11/site-packages/numpy/linalg/_linalg.py:1839, in svd(a, full_matrices, compute_uv, hermitian)
#    1835 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1836 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1837               invalid='call', over='ignore', divide='ignore',
#    1838               under='ignore'):
# -> 1839     u, s, vh = gufunc(a, signature=signature)
#    1840 u = u.astype(result_t, copy=False)
#    1841 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:
