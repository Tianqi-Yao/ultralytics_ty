# %% [markdown]
# # 训练instance segmentation模型

# %%
import wandb
wandb.login(key="957096cc564005d5332d45e2da6a75838e1cc9ac")

# %%
from lark import logger
from ultralytics import YOLO

# ===== project name =====
PROJECT_NAME = "swd_model_obb_v1"
runPath = "/workspace/_ty/03_code/05_train_model/yolo_obb/yaml/"
# ========================

# ==== 你需要手动填写的列表 ====
yamlFileNames = [  # 数据集 yaml 文件名（不要写后缀 .yaml）
    "data_split_0.6_0.4_0.0",
    "data_split_0.8_0.2_0.0",
]
batchSizes = [
    4, 8, 16, 
]
models = [
    "/workspace/_ty/02_models/best_models/04_swd_hbb/model_v2_4datasets_noAug_seed0_yolo11s_data_split_custom_8.pt",
    "yolo11n-obb.pt",
    "yolo11s-obb.pt",
    "yolo11m-obb.pt",
]

# =================================

# 循环遍历
for yamlFileName in yamlFileNames:
    yamlPath = runPath + yamlFileName + ".yaml"
    for modelFile in models:
        for batch in batchSizes:
            print(f"\n🚀 Training model={modelFile}, dataset={yamlFileName}, batch={batch}")

            model = YOLO(modelFile)

            try:
                model.train(
                    data=yamlPath,
                    epochs=1000,
                    imgsz=640,
                    batch=batch,
                    device=0,
                    workers=4,
                    project=f"output/{PROJECT_NAME}",   # 输出目录
                    name=f"{modelFile}_{yamlFileName}_{batch}",
                )

                # 测试集验证
                # model.val(
                #     data=yamlPath,
                #     split="test",
                #     name=f"{modelFile}_{yamlFileName}_{batch}_test",
                # )
            except RuntimeError as e:
                if "CUDA out of memory" in str(e):
                    print(f"⚠️  跳过: model={modelFile}, yaml={yamlFileName}, batch={batch} —— 显存不足")
                    continue
                else:
                    raise  # 不是 OOM 的错误则继续抛出
# Out:
# 🚀 Training model=yolo11n-obb.pt, dataset=data_split_0.6_0.4_0.0, batch=4
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 15818MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/_ty/03_code/05_train_model/yolo_obb/yaml/data_split_0.6_0.4_0.0.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n-obb.pt_data_split_0.6_0.4_0.0_42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=output/swd_model_obb_v1, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    502534  ultralytics.nn.modules.head.OBB              [1, 1, [64, 128, 256]]
# YOLO11n-obb summary: 196 layers, 2,661,702 parameters, 2,661,686 gradients, 6.7 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspace/_ty/03_code/05_train_model/yolo_obb/wandb/run-20251211_004138-lebsm8qb</code>
# Syncing run <strong><a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/lebsm8qb' target="_blank">yolo11n-obb.pt_data_split_0.6_0.4_0.0_42</a></strong> to <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1</a>
#  View run at <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/lebsm8qb' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/lebsm8qb</a>
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3156.2±822.1 MB/s, size: 54.0 KB)
# train: Scanning /workspace/_ty/03_code/05_train_model/yolo_obb/data/data_split_0.6_0.4_0.0/train/labels.cache... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 906.4±539.9 MB/s, size: 52.6 KB)
# val: Scanning /workspace/_ty/03_code/05_train_model/yolo_obb/data/data_split_0.6_0.4_0.0/val/labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Plotting labels to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10     0.713G      1.695      7.352      1.845          2        640: 100%|██████████| 4/4 [00:00<00:00, 19.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 46.89it/s]
#                    all         10         11    0.00379      0.818    0.00451    0.00221
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10     0.729G      1.541      7.795      1.602          3        640: 100%|██████████| 4/4 [00:00<00:00, 26.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 58.13it/s]
#                    all         10         11    0.00342      0.818    0.00494    0.00223
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10     0.729G      1.743      8.879      1.746          4        640: 100%|██████████| 4/4 [00:00<00:00, 26.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 44.33it/s]
#                    all         10         11    0.00338      0.818    0.00519    0.00228
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10     0.742G      1.534      8.199      1.554          2        640: 100%|██████████| 4/4 [00:00<00:00, 24.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 59.12it/s]
#                    all         10         11    0.00363      0.636     0.0122     0.0058
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10     0.758G      1.489      6.438      1.623          4        640: 100%|██████████| 4/4 [00:00<00:00, 25.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 53.81it/s]
#                    all         10         11     0.0276     0.0909     0.0184     0.0109
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10     0.758G      1.231      5.413       1.56          3        640: 100%|██████████| 4/4 [00:00<00:00, 26.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 52.77it/s]
#                    all         10         11     0.0457      0.244      0.038     0.0177
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10     0.758G      1.112      5.542      1.509          4        640: 100%|██████████| 4/4 [00:00<00:00, 28.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 55.65it/s]
#                    all         10         11     0.0457      0.244      0.038     0.0177
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10     0.758G      1.409      5.338      1.502          4        640: 100%|██████████| 4/4 [00:00<00:00, 26.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 60.54it/s]
#                    all         10         11     0.0543     0.0909     0.0438     0.0189
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10     0.758G      1.098      6.203      1.494          2        640: 100%|██████████| 4/4 [00:00<00:00, 23.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 55.11it/s]
#                    all         10         11      0.131     0.0909     0.0751     0.0337
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10     0.758G      1.504       5.56      1.675          3        640: 100%|██████████| 4/4 [00:00<00:00, 26.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 43.74it/s]
#                    all         10         11      0.131     0.0909     0.0751     0.0337
# 10 epochs completed in 0.001 hours.
# Optimizer stripped from output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42/weights/last.pt, 5.7MB
# Optimizer stripped from output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42/weights/best.pt, 5.7MB
#
# Validating output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42/weights/best.pt...
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 15818MiB)
# YOLO11n-obb summary (fused): 109 layers, 2,653,918 parameters, 0 gradients, 6.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 44.80it/s]
#                    all         10         11       0.13     0.0909     0.0755     0.0336
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_42
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▁▄▆▇██▇▆▄▂</td></tr><tr><td>lr/pg1</td><td>▁▄▆▇██▇▆▄▂</td></tr><tr><td>lr/pg2</td><td>▁▄▆▇██▇▆▄▂</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▁▁▂▂▄▄▅██</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▁▁▂▃▄▄▅██</td></tr><tr><td>metrics/precision(B)</td><td>▁▁▁▁▂▃▃▄██</td></tr><tr><td>metrics/recall(B)</td><td>███▆▁▂▂▁▁▁</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>9e-05</td></tr><tr><td>lr/pg1</td><td>9e-05</td></tr><tr><td>lr/pg2</td><td>9e-05</td></tr><tr><td>metrics/mAP50(B)</td><td>0.07552</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.03364</td></tr><tr><td>metrics/precision(B)</td><td>0.13016</td></tr><tr><td>metrics/recall(B)</td><td>0.09091</td></tr><tr><td>model/GFLOPs</td><td>6.688</td></tr><tr><td>model/parameters</td><td>2661702</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>2.551</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">yolo11n-obb.pt_data_split_0.6_0.4_0.0_42</strong> at: <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/lebsm8qb' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/lebsm8qb</a><br> View project at: <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1</a><br>Synced 4 W&B file(s), 21 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251211_004138-lebsm8qb/logs</code>
# 🚀 Training model=yolo11n-obb.pt, dataset=data_split_0.6_0.4_0.0, batch=8
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 15818MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/_ty/03_code/05_train_model/yolo_obb/yaml/data_split_0.6_0.4_0.0.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n-obb.pt_data_split_0.6_0.4_0.0_8, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=output/swd_model_obb_v1, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    502534  ultralytics.nn.modules.head.OBB              [1, 1, [64, 128, 256]]
# YOLO11n-obb summary: 196 layers, 2,661,702 parameters, 2,661,686 gradients, 6.7 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspace/_ty/03_code/05_train_model/yolo_obb/wandb/run-20251211_004150-kdtekctj</code>
# Syncing run <strong><a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/kdtekctj' target="_blank">yolo11n-obb.pt_data_split_0.6_0.4_0.0_8</a></strong> to <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1</a>
#  View run at <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/kdtekctj' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/kdtekctj</a>
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3201.8±831.4 MB/s, size: 54.0 KB)
# train: Scanning /workspace/_ty/03_code/05_train_model/yolo_obb/data/data_split_0.6_0.4_0.0/train/labels.cache... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1435.2±756.5 MB/s, size: 52.6 KB)
# val: Scanning /workspace/_ty/03_code/05_train_model/yolo_obb/data/data_split_0.6_0.4_0.0/val/labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Plotting labels to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      1.35G      1.699      6.894      1.957         10        640: 100%|██████████| 2/2 [00:06<00:00,  3.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.01it/s]
#                    all         10         11    0.00389      0.818    0.00355    0.00178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      1.36G        1.5      7.654      1.741          8        640: 100%|██████████| 2/2 [00:00<00:00, 20.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 41.65it/s]
#                    all         10         11    0.00369      0.818    0.00455    0.00224
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      1.36G      1.641      7.577       1.75          9        640: 100%|██████████| 2/2 [00:00<00:00, 23.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 49.76it/s]
#                    all         10         11    0.00353      0.818    0.00533    0.00241
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      1.36G      1.587      7.498      1.748          7        640: 100%|██████████| 2/2 [00:00<00:00, 22.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 48.96it/s]
#                    all         10         11    0.00348      0.818    0.00507    0.00195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      1.36G      1.365      7.135      1.597          9        640: 100%|██████████| 2/2 [00:00<00:00, 23.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 48.87it/s]
#                    all         10         11    0.00352      0.818    0.00913    0.00416
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      1.39G      1.569      6.938      1.643          8        640: 100%|██████████| 2/2 [00:00<00:00, 24.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 46.53it/s]
#                    all         10         11    0.00451      0.636     0.0138    0.00736
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10       1.4G      1.362      6.694      1.684          7        640: 100%|██████████| 2/2 [00:00<00:00, 23.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 46.08it/s]
#                    all         10         11    0.00522      0.545     0.0145    0.00864
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10       1.4G      1.241      6.166        1.4         10        640: 100%|██████████| 2/2 [00:00<00:00, 23.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 48.69it/s]
#                    all         10         11    0.00514      0.545     0.0234     0.0126
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10       1.4G      1.248      6.147      1.516          6        640: 100%|██████████| 2/2 [00:00<00:00, 22.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 50.28it/s]
#                    all         10         11    0.00665      0.545     0.0278     0.0154
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10       1.4G      1.314      5.657      1.486          7        640: 100%|██████████| 2/2 [00:00<00:00, 23.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 49.13it/s]
#                    all         10         11    0.00806      0.455      0.035     0.0181
# 10 epochs completed in 0.003 hours.
# Optimizer stripped from output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8/weights/last.pt, 5.7MB
# Optimizer stripped from output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8/weights/best.pt, 5.7MB
#
# Validating output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8/weights/best.pt...
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 15818MiB)
# YOLO11n-obb summary (fused): 109 layers, 2,653,918 parameters, 0 gradients, 6.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 54.21it/s]
#                    all         10         11    0.00812      0.455     0.0344     0.0191
# Speed: 0.1ms preprocess, 0.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_8
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▁▄▆▇███▇▅▃</td></tr><tr><td>lr/pg1</td><td>▁▄▆▇███▇▅▃</td></tr><tr><td>lr/pg2</td><td>▁▄▆▇███▇▅▃</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▁▁▁▂▃▃▆▆█</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▁▁▁▂▃▄▅▆█</td></tr><tr><td>metrics/precision(B)</td><td>▂▁▁▁▁▃▄▄▆█</td></tr><tr><td>metrics/recall(B)</td><td>█████▄▃▃▃▁</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>4e-05</td></tr><tr><td>lr/pg1</td><td>4e-05</td></tr><tr><td>lr/pg2</td><td>4e-05</td></tr><tr><td>metrics/mAP50(B)</td><td>0.03439</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.01914</td></tr><tr><td>metrics/precision(B)</td><td>0.00812</td></tr><tr><td>metrics/recall(B)</td><td>0.45455</td></tr><tr><td>model/GFLOPs</td><td>6.688</td></tr><tr><td>model/parameters</td><td>2661702</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>96.286</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">yolo11n-obb.pt_data_split_0.6_0.4_0.0_8</strong> at: <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/kdtekctj' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/kdtekctj</a><br> View project at: <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1</a><br>Synced 4 W&B file(s), 19 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251211_004150-kdtekctj/logs</code>
# 🚀 Training model=yolo11n-obb.pt, dataset=data_split_0.6_0.4_0.0, batch=16
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 15818MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/_ty/03_code/05_train_model/yolo_obb/yaml/data_split_0.6_0.4_0.0.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n-obb.pt_data_split_0.6_0.4_0.0_16, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=output/swd_model_obb_v1, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_16, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    502534  ultralytics.nn.modules.head.OBB              [1, 1, [64, 128, 256]]
# YOLO11n-obb summary: 196 layers, 2,661,702 parameters, 2,661,686 gradients, 6.7 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspace/_ty/03_code/05_train_model/yolo_obb/wandb/run-20251211_004209-grpha4zq</code>
# Syncing run <strong><a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/grpha4zq' target="_blank">yolo11n-obb.pt_data_split_0.6_0.4_0.0_16</a></strong> to <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1</a>
#  View run at <a href='https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/grpha4zq' target="_blank">https://wandb.ai/yaotianqi6666/output-swd_model_obb_v1/runs/grpha4zq</a>
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2055.7±544.4 MB/s, size: 54.0 KB)
# train: Scanning /workspace/_ty/03_code/05_train_model/yolo_obb/data/data_split_0.6_0.4_0.0/train/labels.cache... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1509.7±692.3 MB/s, size: 52.6 KB)
# val: Scanning /workspace/_ty/03_code/05_train_model/yolo_obb/data/data_split_0.6_0.4_0.0/val/labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Plotting labels to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_16/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to output/swd_model_obb_v1/yolo11n-obb.pt_data_split_0.6_0.4_0.0_16
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      2.32G      1.562      7.189      1.851         19        640: 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 35
#      32 model = YOLO(modelFile)
#      34 try:
# ---> 35     model.train(
#      36         data=yamlPath,
#      37         epochs=10,
#      38         imgsz=640,
#      39         batch=batch,
#      40         device=0,
#      41         workers=4,
#      42         project=f"output/{PROJECT_NAME}",   # 输出目录
#      43         name=f"{modelFile}_{yamlFileName}_{batch}",
#      44     )
#      46     # 测试集验证
#      47     # model.val(
#      48     #     data=yamlPath,
#      49     #     split="test",
#      50     #     name=f"{modelFile}_{yamlFileName}_{batch}_test",
#      51     # )
#      52 except RuntimeError as e:
#
# File /workspace/ultralytics/engine/model.py:799, in Model.train(self, trainer, **kwargs)
#     796     self.model = self.trainer.model
#     798 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799 self.trainer.train()
#     800 # Update model and cfg after training
#     801 if RANK in {-1, 0}:
#
# File /workspace/ultralytics/engine/trainer.py:227, in BaseTrainer.train(self)
#     224         ddp_cleanup(self, str(file))
#     226 else:
# --> 227     self._do_train(world_size)
#
# File /workspace/ultralytics/engine/trainer.py:460, in BaseTrainer._do_train(self, world_size)
#     458 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
#     459     self._clear_memory(threshold=0.5)  # prevent VRAM spike
# --> 460     self.metrics, self.fitness = self.validate()
#     461 self.save_metrics(metrics={**self.label_loss_items(self.tloss), **self.metrics, **self.lr})
#     462 self.stop |= self.stopper(epoch + 1, self.fitness) or final_epoch
#
# File /workspace/ultralytics/engine/trainer.py:660, in BaseTrainer.validate(self)
#     652 def validate(self):
#     653     """
#     654     Run validation on test set using self.validator.
#     655
#    (...)    658         fitness (float): Fitness score for the validation.
#     659     """
# --> 660     metrics = self.validator(self)
#     661     fitness = metrics.pop("fitness", -self.loss.detach().cpu().numpy())  # use loss as fitness measure if not found
#     662     if not self.best_fitness or self.best_fitness < fitness:
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /workspace/ultralytics/engine/validator.py:208, in BaseValidator.__call__(self, trainer, model)
#     206 # Inference
#     207 with dt[1]:
# --> 208     preds = model(batch["img"], augment=augment)
#     210 # Loss
#     211 with dt[2]:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ultralytics/nn/tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File /workspace/ultralytics/nn/tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File /workspace/ultralytics/nn/tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ultralytics/nn/modules/head.py:327, in OBB.forward(self, x)
#     325 if not self.training:
#     326     self.angle = angle
# --> 327 x = Detect.forward(self, x)
#     328 if self.training:
#     329     return x, angle
#
# File /workspace/ultralytics/nn/modules/head.py:120, in Detect.forward(self, x)
#     117     return self.forward_end2end(x)
#     119 for i in range(self.nl):
# --> 120     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     121 if self.training:  # Training path
#     122     return x
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ultralytics/nn/modules/conv.py:80, in Conv.forward(self, x)
#      70 def forward(self, x):
#      71     """
#      72     Apply convolution, batch normalization and activation to input tensor.
#      73
#    (...)     78         (torch.Tensor): Output tensor.
#      79     """
# ---> 80     return self.act(self.bn(self.conv(x)))
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7c0206dbce50>> (for post_run_cell), with arguments args (<ExecutionResult object at 7c064413fd10, execution_count=2 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 7c025d049650, raw_cell="from lark import logger
# from ultralytics import YO.." transformed_cell="from lark import logger
# from ultralytics import YO.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f756c7472616c79746963735f7479227d/workspace/_ty/03_code/05_train_model/yolo_obb/01_02_main_train_And_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:603, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     600     return
#     602 self._logger.info("resuming backend")
# --> 603 self.backend.interface.publish_resume()
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:820, in InterfaceBase.publish_resume(self)
#     818 def publish_resume(self) -> None:
#     819     resume = pb.ResumeRequest()
# --> 820     self._publish_resume(resume)
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File /opt/conda/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/conda/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File /opt/conda/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File /opt/conda/lib/python3.11/asyncio/streams.py:392, in StreamWriter.drain(self)
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
# --> 392 await self._protocol._drain_helper()
#
# File /opt/conda/lib/python3.11/asyncio/streams.py:166, in FlowControlMixin._drain_helper(self)
#     164 async def _drain_helper(self):
#     165     if self._connection_lost:
# --> 166         raise ConnectionResetError('Connection lost')
#     167     if not self._paused:
#     168         return
#
# ConnectionResetError: Connection lost
