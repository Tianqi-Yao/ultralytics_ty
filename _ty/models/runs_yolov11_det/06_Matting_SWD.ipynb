# %% [markdown]
# # SWD 提取points 边界

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import re
import json
import glob
from pathlib import Path
from typing import Any, Dict, Iterable, List, Set, Tuple
from collections import defaultdict

# ========= 配置（按需修改） =========
JPG_DIR = Path("/workspace/models/runs_yolov11_det/cropped_objects_v6/swd")

# v7 结构：run_v7/*/raw_data_sliced_merge/filtered_annotations_v2..v9.json
RUN_ROOTS = [Path("/workspace/models/SAHI/run_v7")]

# v4/5/6 结构：run_vX/raw_data_sliced_merge/filtered_annotations.json
RUN_ROOTS2 = [
    Path("/workspace/models/SAHI/run_v4"),
    Path("/workspace/models/SAHI/run_v5"),
    Path("/workspace/models/SAHI/run_v6"),
]

# 输出文件
OUT_JSONL = Path("matched_points.jsonl")
OUT_UNMATCHED = Path("unmatched_uuids.txt")

# ========= 工具函数 =========

UUID_RE = re.compile(r"_uuid_([0-9a-fA-F-]{36})(?:\.[jJ][pP][eE]?[gG])?$")

def extract_uuid_from_filename(name: str) -> str | None:
    m = UUID_RE.search(name)
    return m.group(1).lower() if m else None

def find_all_jpg_uuids(jpg_dir: Path) -> Tuple[Set[str], List[Tuple[str, str]]]:
    uuids: Set[str] = set()
    pairs: List[Tuple[str, str]] = []
    for p in sorted(jpg_dir.glob("*.jpg")):
        uid = extract_uuid_from_filename(p.name)
        if uid:
            uuids.add(uid)
            pairs.append((uid, p.stem))
    return uuids, pairs

def iter_filtered_json_paths_v7(roots: List[Path]) -> Iterable[Path]:
    """
    run_v7：run_v7/*/raw_data_sliced_merge/filtered_annotations_v2..v9.json
    """
    for root in roots:
        pattern = str(root / "*" / "raw_data_sliced_merge" / "filtered_annotations_v[2-9].json")
        for p in glob.iglob(pattern):
            yield Path(p)

def iter_filtered_json_paths_v456(roots: List[Path]) -> Iterable[Path]:
    """
    run_v4/5/6：run_vX/raw_data_sliced_merge/filtered_annotations.json
    """
    for root in roots:
        pattern = str(root / "raw_data_sliced_merge" / "merged_annotations.json")
        for p in glob.iglob(pattern):
            yield Path(p)

def walk_json(obj: Any) -> Iterable[Dict[str, Any]]:
    if isinstance(obj, dict):
        yield obj
        for v in obj.values():
            yield from walk_json(v)
    elif isinstance(obj, list):
        for it in obj:
            yield from walk_json(it)

# ========= 主逻辑 =========

def main():
    # 1) 收集所有 jpg 的 uuid
    uuid_set, uuid_pairs = find_all_jpg_uuids(JPG_DIR)
    if not uuid_set:
        print(f"[WARN] 没在 {JPG_DIR} 找到任何符合模式的 jpg/uuid。")
        return
    print(f"[INFO] 从 JPG 提取到 {len(uuid_set)} 个唯一 UUID。")

    # 2) 汇总 JSON 路径
    json_paths = list(iter_filtered_json_paths_v7(RUN_ROOTS))
    json_paths.extend(iter_filtered_json_paths_v456(RUN_ROOTS2))
    if not json_paths:
        print(f"[WARN] 没找到任何匹配的 JSON（v7: v2~v9；v4/5/6: filtered_annotations.json）。")
        return
    print(f"[INFO] 找到 {len(json_paths)} 个 JSON 文件可供检索。")

    # 3) 聚合：uuid -> 去重后的 points 列表（同一 uuid 保持唯一行）
    agg_items: Dict[str, List[Dict[str, Any]]] = defaultdict(list)
    seen_points_keys: Dict[str, Set[str]] = defaultdict(set)  # uuid -> {serialized points}

    def _serialize_points(pts: Any) -> str:
        # 将 points 规范序列化用于去重
        try:
            return json.dumps(pts, ensure_ascii=False, sort_keys=True)
        except Exception:
            return str(pts)

    # 遍历 JSON
    for jpath in json_paths:
        try:
            with jpath.open("r", encoding="utf-8") as f:
                data = json.load(f)
        except Exception as e:
            print(f"[ERROR] 读取 JSON 失败：{jpath} -> {e}")
            continue

        for d in walk_json(data):
            key = "uuid" if "uuid" in d else ("UUID" if "UUID" in d else None)
            if not key:
                continue
            uid = str(d.get(key, "")).lower()
            if uid in uuid_set:
                points = d.get("points", None)
                original_name = d.get("original_name", None)
                pkey = _serialize_points(points)
                if pkey not in seen_points_keys[uid]:
                    seen_points_keys[uid].add(pkey)
                    agg_items[uid].append({"json_path": str(jpath), "original_name": str(original_name), "points": points})

    # 4) 写出结果（每个 uuid 一行）
    matched_uuids = set(agg_items.keys())
    with OUT_JSONL.open("w", encoding="utf-8") as fout:
        for uid, items in agg_items.items():
            rec = {
                "uuid": uid,
                "matches": items  # 去重后的 {json_path, points} 列表
            }
            fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

    # 5) 未命中统计
    unmatched = [u for u, _ in uuid_pairs if u not in matched_uuids]
    with OUT_UNMATCHED.open("w", encoding="utf-8") as f:
        for u in unmatched:
            f.write(u + "\n")

    print(f"[DONE] 命中 {sum(len(v) for v in agg_items.values())} 条记录，涉及 {len(matched_uuids)} 个 UUID。")
    print(f"[DONE] 结果已写入：{OUT_JSONL.resolve()}（每行一个 uuid，内部 points 去重）")
    print(f"[DONE] 未命中的 UUID 共 {len(unmatched)} 个，已写入：{OUT_UNMATCHED.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] 从 JPG 提取到 849 个唯一 UUID。
# [INFO] 找到 227 个 JSON 文件可供检索。
# [DONE] 命中 849 条记录，涉及 849 个 UUID。
# [DONE] 结果已写入：/workspace/models/runs_yolov11_det/matched_points.jsonl（每行一个 uuid，内部 points 去重）
# [DONE] 未命中的 UUID 共 0 个，已写入：/workspace/models/runs_yolov11_det/unmatched_uuids.txt

# %% [markdown]
# # mayswd 提取points 边界

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import re
import json
import glob
from pathlib import Path
from typing import Any, Dict, Iterable, List, Set, Tuple
from collections import defaultdict

# ========= 配置（按需修改） =========
JPG_DIR = Path("/workspace/models/runs_yolov11_det/cropped_objects_v6/mayswd")

# v7 结构：run_v7/*/raw_data_sliced_merge/filtered_annotations_v2..v9.json
RUN_ROOTS = [Path("/workspace/models/SAHI/run_v7")]

# v4/5/6 结构：run_vX/raw_data_sliced_merge/filtered_annotations.json
RUN_ROOTS2 = [
    Path("/workspace/models/SAHI/run_v3"),
    Path("/workspace/models/SAHI/run_v4"),
    Path("/workspace/models/SAHI/run_v5"),
    Path("/workspace/models/SAHI/run_v6"),
]

# 输出文件
OUT_JSONL = Path("matched_points_mayswd.jsonl")
OUT_UNMATCHED = Path("unmatched_uuids_mayswd.txt")

# ========= 工具函数 =========

UUID_RE = re.compile(r"_uuid_([0-9a-fA-F-]{36})(?:\.[jJ][pP][eE]?[gG])?$")

def extract_uuid_from_filename(name: str) -> str | None:
    m = UUID_RE.search(name)
    return m.group(1).lower() if m else None

def find_all_jpg_uuids(jpg_dir: Path) -> Tuple[Set[str], List[Tuple[str, str]]]:
    uuids: Set[str] = set()
    pairs: List[Tuple[str, str]] = []
    for p in sorted(jpg_dir.glob("*.jpg")):
        uid = extract_uuid_from_filename(p.name)
        if uid:
            uuids.add(uid)
            pairs.append((uid, p.stem))
    return uuids, pairs

def iter_filtered_json_paths_v7(roots: List[Path]) -> Iterable[Path]:
    """
    run_v7：run_v7/*/raw_data_sliced_merge/filtered_annotations_v2..v9.json
    """
    for root in roots:
        pattern = str(root / "*" / "raw_data_sliced_merge" / "filtered_annotations_v[2-9].json")
        for p in glob.iglob(pattern):
            yield Path(p)

def iter_filtered_json_paths_v456(roots: List[Path]) -> Iterable[Path]:
    """
    run_v4/5/6：run_vX/raw_data_sliced_merge/filtered_annotations.json
    """
    for root in roots:
        pattern = str(root / "raw_data_sliced_merge" / "merged_annotations.json")
        for p in glob.iglob(pattern):
            yield Path(p)

def walk_json(obj: Any) -> Iterable[Dict[str, Any]]:
    if isinstance(obj, dict):
        yield obj
        for v in obj.values():
            yield from walk_json(v)
    elif isinstance(obj, list):
        for it in obj:
            yield from walk_json(it)

# ========= 主逻辑 =========

def main():
    # 1) 收集所有 jpg 的 uuid
    uuid_set, uuid_pairs = find_all_jpg_uuids(JPG_DIR)
    if not uuid_set:
        print(f"[WARN] 没在 {JPG_DIR} 找到任何符合模式的 jpg/uuid。")
        return
    print(f"[INFO] 从 JPG 提取到 {len(uuid_set)} 个唯一 UUID。")

    # 2) 汇总 JSON 路径
    json_paths = list(iter_filtered_json_paths_v7(RUN_ROOTS))
    json_paths.extend(iter_filtered_json_paths_v456(RUN_ROOTS2))
    if not json_paths:
        print(f"[WARN] 没找到任何匹配的 JSON（v7: v2~v9；v4/5/6: filtered_annotations.json）。")
        return
    print(f"[INFO] 找到 {len(json_paths)} 个 JSON 文件可供检索。")

    # 3) 聚合：uuid -> 去重后的 points 列表（同一 uuid 保持唯一行）
    agg_items: Dict[str, List[Dict[str, Any]]] = defaultdict(list)
    seen_points_keys: Dict[str, Set[str]] = defaultdict(set)  # uuid -> {serialized points}

    def _serialize_points(pts: Any) -> str:
        # 将 points 规范序列化用于去重
        try:
            return json.dumps(pts, ensure_ascii=False, sort_keys=True)
        except Exception:
            return str(pts)

    # 遍历 JSON
    for jpath in json_paths:
        try:
            with jpath.open("r", encoding="utf-8") as f:
                data = json.load(f)
        except Exception as e:
            print(f"[ERROR] 读取 JSON 失败：{jpath} -> {e}")
            continue

        for d in walk_json(data):
            key = "uuid" if "uuid" in d else ("UUID" if "UUID" in d else None)
            if not key:
                continue
            uid = str(d.get(key, "")).lower()
            if uid in uuid_set:
                points = d.get("points", None)
                original_name = d.get("original_name", None)
                pkey = _serialize_points(points)
                if pkey not in seen_points_keys[uid]:
                    seen_points_keys[uid].add(pkey)
                    agg_items[uid].append({"json_path": str(jpath), "original_name": str(original_name), "points": points})

    # 4) 写出结果（每个 uuid 一行）
    matched_uuids = set(agg_items.keys())
    with OUT_JSONL.open("w", encoding="utf-8") as fout:
        for uid, items in agg_items.items():
            rec = {
                "uuid": uid,
                "matches": items  # 去重后的 {json_path, points} 列表
            }
            fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

    # 5) 未命中统计
    unmatched = [u for u, _ in uuid_pairs if u not in matched_uuids]
    with OUT_UNMATCHED.open("w", encoding="utf-8") as f:
        for u in unmatched:
            f.write(u + "\n")

    print(f"[DONE] 命中 {sum(len(v) for v in agg_items.values())} 条记录，涉及 {len(matched_uuids)} 个 UUID。")
    print(f"[DONE] 结果已写入：{OUT_JSONL.resolve()}（每行一个 uuid，内部 points 去重）")
    print(f"[DONE] 未命中的 UUID 共 {len(unmatched)} 个，已写入：{OUT_UNMATCHED.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] 从 JPG 提取到 38 个唯一 UUID。
# [INFO] 找到 228 个 JSON 文件可供检索。
# [DONE] 命中 38 条记录，涉及 38 个 UUID。
# [DONE] 结果已写入：/workspace/models/runs_yolov11_det/matched_points_mayswd.jsonl（每行一个 uuid，内部 points 去重）
# [DONE] 未命中的 UUID 共 0 个，已写入：/workspace/models/runs_yolov11_det/unmatched_uuids_mayswd.txt

# %% [markdown]
# # 抠图

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import cv2
import glob
import numpy as np
from pathlib import Path
from typing import List, Tuple, Any, Optional, Dict

# ========= 配置 =========
# JSONL_PATH   = Path("matched_points_mayswd.jsonl")
JSONL_PATH   = Path("matched_points.jsonl")
OUT_DIR_RECT = Path("/workspace/models/runs_yolov11_det/crops_by_points/rect")  # 正方形裁剪（取长边）
OUT_DIR_MASK = Path("/workspace/models/runs_yolov11_det/crops_by_points/mask")  # 多边形抠图（透明）
SAVE_BBOX    = True
SAVE_MASK    = True

# ========= 工具 =========
IMG_EXTS = [".jpg", ".jpeg", ".png", ".JPG", ".JPEG", ".PNG"]

def to_xy_list(points: Any) -> List[Tuple[float, float]]:
    """将 points 统一为 [(x,y), ...]，兼容 [[x,y], ...] 或 [{'x':..,'y':..}, ...]"""
    if points is None:
        return []
    xy = []
    if isinstance(points, (list, tuple)):
        for pt in points:
            if isinstance(pt, (list, tuple)) and len(pt) >= 2:
                x, y = float(pt[0]), float(pt[1])
                xy.append((x, y))
            elif isinstance(pt, dict) and 'x' in pt and 'y' in pt:
                xy.append((float(pt['x']), float(pt['y'])))
    return xy

def clamp_bbox(xmin, ymin, xmax, ymax, w, h):
    xmin = max(0, min(int(np.floor(xmin)), w-1))
    ymin = max(0, min(int(np.floor(ymin)), h-1))
    xmax = max(0, min(int(np.ceil (xmax)), w-1))
    ymax = max(0, min(int(np.ceil (ymax)), h-1))
    if xmax < xmin: xmax = xmin
    if ymax < ymin: ymax = ymin
    return xmin, ymin, xmax, ymax

def square_bbox_from_points(xy: List[Tuple[float, float]], w: int, h: int) -> Tuple[int,int,int,int]:
    """
    基于点集的外接矩形，扩为以中心为基准的正方形（边长=长边）。
    若越界，则整体平移窗口以尽量保持完整正方形；最后 clamp 到图内。
    返回：xmin, ymin, xmax, ymax
    """
    xs = [p[0] for p in xy]; ys = [p[1] for p in xy]
    xmin0, ymin0, xmax0, ymax0 = min(xs), min(ys), max(xs), max(ys)
    bw = xmax0 - xmin0 + 1
    bh = ymax0 - ymin0 + 1
    side = int(np.ceil(max(bw, bh)))  # 取长边并向上取整

    # 以中心为基准构建正方形窗口
    cx = (xmin0 + xmax0) / 2.0
    cy = (ymin0 + ymax0) / 2.0
    xmin = int(np.floor(cx - side / 2.0))
    ymin = int(np.floor(cy - side / 2.0))
    xmax = xmin + side - 1
    ymax = ymin + side - 1

    # 越界则整体平移
    if xmin < 0:
        shift = -xmin
        xmin += shift; xmax += shift
    if ymin < 0:
        shift = -ymin
        ymin += shift; ymax += shift
    if xmax >= w:
        shift = xmax - (w - 1)
        xmin -= shift; xmax -= shift
    if ymax >= h:
        shift = ymax - (h - 1)
        ymin -= shift; ymax -= shift

    # 最终 clamp
    xmin, ymin, xmax, ymax = clamp_bbox(xmin, ymin, xmax, ymax, w, h)

    # 保底再对齐为正方形（在边界内微调）
    cur_w = xmax - xmin + 1
    cur_h = ymax - ymin + 1
    if cur_w != cur_h:
        side = min(max(cur_w, cur_h), min(w, h))
        cx = (xmin + xmax) / 2.0
        cy = (ymin + ymax) / 2.0
        xmin = int(np.floor(cx - side / 2.0))
        ymin = int(np.floor(cy - side / 2.0))
        xmax = xmin + side - 1
        ymax = ymin + side - 1
        xmin, ymin, xmax, ymax = clamp_bbox(xmin, ymin, xmax, ymax, w, h)

    return xmin, ymin, xmax, ymax

def crop_bbox_square(img: np.ndarray, xy: List[Tuple[float, float]]) -> Tuple[np.ndarray, Tuple[int,int,int,int]]:
    """按长边扩成正方形的裁切，返回 (crop, (xmin,ymin,xmax,ymax))."""
    h, w = img.shape[:2]
    xmin, ymin, xmax, ymax = square_bbox_from_points(xy, w, h)
    return img[ymin:ymax+1, xmin:xmax+1].copy(), (xmin, ymin, xmax, ymax)

def crop_polygon_mask(img: np.ndarray, xy: List[Tuple[float, float]]) -> Tuple[np.ndarray, Tuple[int,int,int,int]]:
    """按多边形外接矩形裁切并制作透明 Mask，返回 (rgba_crop, (xmin,ymin,xmax,ymax))."""
    xs = [p[0] for p in xy]; ys = [p[1] for p in xy]
    h, w = img.shape[:2]
    xmin, ymin, xmax, ymax = clamp_bbox(min(xs), min(ys), max(xs), max(ys), w, h)

    crop = img[ymin:ymax+1, xmin:xmax+1].copy()
    ch, cw = crop.shape[:2]

    pts = np.array([[p[0]-xmin, p[1]-ymin] for p in xy], dtype=np.float32)
    pts = np.round(pts).astype(np.int32)

    mask = np.zeros((ch, cw), dtype=np.uint8)
    if len(pts) >= 3:
        cv2.fillPoly(mask, [pts], 255)
    else:
        mask[:, :] = 255  # 点数不足，退化为矩形

    if crop.ndim == 2:
        crop = cv2.cvtColor(crop, cv2.COLOR_GRAY2BGR)
    b, g, r = cv2.split(crop)
    rgba = cv2.merge([b, g, r, mask])
    return rgba, (xmin, ymin, xmax, ymax)

def safe_write(parent: Path, name: str, img: np.ndarray):
    parent.mkdir(parents=True, exist_ok=True)
    out_path = parent / name
    if out_path.suffix.lower() == ".png":
        cv2.imwrite(str(out_path), img)
    else:
        if img.ndim == 3 and img.shape[2] == 4:  # 去掉 alpha 写 jpg
            img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)
        cv2.imwrite(str(out_path), img)

def safe_write_points(parent: Path, name: str, payload: Dict):
    """保存 points 与上下文到 JSON 文件"""
    parent.mkdir(parents=True, exist_ok=True)
    out_path = parent / name
    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(payload, f, ensure_ascii=False, indent=2)

def guess_raw_data_dir_from_json(json_path: Path) -> Path:
    """
    从 …/raw_data_sliced_merge/filtered_annotations_*.json 推断 raw_data 目录：
      - v7:   …/<batch>/raw_data_sliced_merge/ -> …/<batch>/raw_data/
      - v4/5/6: …/run_vX/raw_data_sliced_merge/ -> …/run_vX/raw_data/
    """
    sliced = json_path.parent  # raw_data_sliced_merge
    return sliced.parent / "raw_data"

def find_original_image(raw_dir: Path, original_stem: str) -> Optional[Path]:
    """在 raw_data 目录下根据 stem 查找原图；先平铺查找，找不到再递归兜底。"""
    for ext in IMG_EXTS:
        p = raw_dir / f"{original_stem}{ext}"
        if p.exists():
            return p
    pattern = str(raw_dir / "**" / f"{original_stem}*")
    for p in glob.iglob(pattern, recursive=True):
        path = Path(p)
        if path.suffix in IMG_EXTS and path.stem == original_stem:
            return path
    return None

# ========= 主流程 =========
def main():
    OUT_DIR_RECT.mkdir(parents=True, exist_ok=True)
    OUT_DIR_MASK.mkdir(parents=True, exist_ok=True)

    if not JSONL_PATH.exists():
        print(f"[ERROR] 未找到 {JSONL_PATH}")
        return

    roi_cnt = 0
    out_cnt = 0
    missing_img = 0

    with JSONL_PATH.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                rec = json.loads(line)
            except Exception as e:
                print(f"[WARN] 跳过无法解析的行：{e}")
                continue

            uuid = str(rec.get("uuid", "")).lower().strip()
            matches = rec.get("matches", [])
            if not uuid or not matches:
                continue

            for i, m in enumerate(matches):
                json_path = Path(m.get("json_path", ""))
                original_name = str(m.get("original_name", "")).strip()
                xy = to_xy_list(m.get("points"))
                if not original_name or not xy:
                    continue

                raw_dir = guess_raw_data_dir_from_json(json_path)
                big_img_path = find_original_image(raw_dir, original_name)
                if big_img_path is None:
                    print(f"[WARN] 原始图未找到：uuid={uuid}, original_name={original_name}, raw_dir={raw_dir}")
                    missing_img += 1
                    continue

                img = cv2.imread(str(big_img_path), cv2.IMREAD_UNCHANGED)
                if img is None:
                    print(f"[WARN] 无法读取原始图：{big_img_path}")
                    missing_img += 1
                    continue

                # 统一的扁平文件名，避免重名冲突
                # 例：0801_2302_800_uuid_2da2..._roi000_bbox.jpg
                base = f"{big_img_path.stem}_uuid_{uuid}_roi{i:03d}"

                # ===== 正方形裁剪 =====
                if SAVE_BBOX:
                    crop, rect = crop_bbox_square(img, xy)  # 正方形裁剪
                    if crop.size > 0:
                        img_name = f"{base}_bbox.jpg"
                        json_name = f"{base}_bbox.json"
                        safe_write(OUT_DIR_RECT, img_name, crop)

                        xmin, ymin, xmax, ymax = rect
                        points_rel = [[float(x - xmin), float(y - ymin)] for (x, y) in xy]
                        payload = {
                            "type": "bbox",
                            "uuid": uuid,
                            "original_name": original_name,
                            "json_path": str(json_path),
                            "raw_image_path": str(big_img_path),
                            "crop_rect": [int(xmin), int(ymin), int(xmax), int(ymax)],
                            "points_abs": [[float(x), float(y)] for (x, y) in xy],
                            "points_rel": points_rel  # 相对裁剪左上角
                        }
                        safe_write_points(OUT_DIR_RECT, json_name, payload)
                        out_cnt += 1

                # ===== 多边形抠图 =====
                if SAVE_MASK:
                    poly, rect = crop_polygon_mask(img, xy)
                    if poly.size > 0:
                        img_name = f"{base}_mask.png"
                        json_name = f"{base}_mask.json"
                        safe_write(OUT_DIR_MASK, img_name, poly)

                        xmin, ymin, xmax, ymax = rect
                        points_rel = [[float(x - xmin), float(y - ymin)] for (x, y) in xy]
                        payload = {
                            "type": "mask",
                            "uuid": uuid,
                            "original_name": original_name,
                            "json_path": str(json_path),
                            "raw_image_path": str(big_img_path),
                            "crop_rect": [int(xmin), int(ymin), int(xmax), int(ymax)],
                            "points_abs": [[float(x), float(y)] for (x, y) in xy],
                            "points_rel": points_rel  # 相对裁剪左上角
                        }
                        safe_write_points(OUT_DIR_MASK, json_name, payload)
                        out_cnt += 1

                roi_cnt += 1

    print(f"[DONE] 共处理 ROI：{roi_cnt}，输出文件：{out_cnt}。")
    print(f"[INFO] 原图缺失/不可读：{missing_img} 次。")
    print(f"[OUT ] 正方形裁剪：{OUT_DIR_RECT.resolve()}")
    print(f"[OUT ] 多边形抠图：{OUT_DIR_MASK.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# [DONE] 共处理 ROI：849，输出文件：1698。
# [INFO] 原图缺失/不可读：0 次。
# [OUT ] 正方形裁剪：/workspace/models/runs_yolov11_det/crops_by_points/rect
# [OUT ] 多边形抠图：/workspace/models/runs_yolov11_det/crops_by_points/mask

# %% [markdown]
# # 图片放大

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import cv2
import glob
import numpy as np
from pathlib import Path
from typing import List, Tuple, Any, Dict, Optional

# ========== 配置（请改这里） ==========
IN_DIR      = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/mask")  # ← 你的“已导出裁剪+JSON”的目录（不回源头）
OUT_RESIZED = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/mask/resized_640_lb")         # ← 640×640(等比+补边) 的图片和更新后的 JSON
OUT_VIS     = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/mask/resized_640_lb_vis")     # ← 叠加 Polygon 的可视化图片
TARGET_SIZE = 640

IMG_EXTS = [".jpg", ".jpeg", ".png", ".JPG", ".JPEG", ".PNG"]

# ========== 工具 ==========
def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)

def is_image(p: Path) -> bool:
    return p.suffix in IMG_EXTS

def paired_json_for(img_path: Path) -> Path:
    return img_path.with_suffix(".json")

def _normalize_points_list(points: Any) -> Optional[List[List[float]]]:
    """兼容 [[x,y], ...] 或 [{'x':..,'y':..}, ...] -> [[x,y], ...]"""
    if points is None:
        return None
    out = []
    if isinstance(points, (list, tuple)):
        for pt in points:
            if isinstance(pt, (list, tuple)) and len(pt) >= 2:
                out.append([float(pt[0]), float(pt[1])])
            elif isinstance(pt, dict) and ("x" in pt) and ("y" in pt):
                out.append([float(pt["x"]), float(pt["y"])])
    return out if out else None

def load_rel_points_for_image(json_path: Path) -> Optional[List[List[float]]]:
    """
    读取与“当前裁剪图”同名的 JSON，返回该图坐标系下的点（未放大前的相对坐标）。
    优先 points_rel；否则尝试 points_abs + crop_rect；最后尝试 points。
    """
    if not json_path.exists():
        return None
    with json_path.open("r", encoding="utf-8") as f:
        data = json.load(f)

    if isinstance(data, dict) and "points_rel" in data:
        return _normalize_points_list(data["points_rel"])

    if isinstance(data, dict) and ("points_abs" in data) and ("crop_rect" in data):
        pts_abs = _normalize_points_list(data["points_abs"])
        rect = data.get("crop_rect", None)
        if isinstance(rect, (list, tuple)) and len(rect) >= 4 and pts_abs:
            xmin, ymin = float(rect[0]), float(rect[1])
            return [[x - xmin, y - ymin] for (x, y) in pts_abs]

    if isinstance(data, dict) and "points" in data:
        return _normalize_points_list(data["points"])

    return None

def letterbox_resize(img: np.ndarray, out_size: int = 640,
                     pad_value_bgr=(0,0,0)) -> Tuple[np.ndarray, float, Tuple[int, int, int, int]]:
    """
    等比缩放 + 补边到 out_size x out_size：
    返回：resized_img, scale, pads(left, top, right, bottom)
    - 若有 alpha，保持 alpha，并对 alpha 也做补边（alpha 补 0 = 全透明）。
    """
    h, w = img.shape[:2]
    if h == 0 or w == 0:
        return img, 1.0, (0, 0, 0, 0)

    scale = min(out_size / float(w), out_size / float(h))
    new_w = int(round(w * scale))
    new_h = int(round(h * scale))

    interp = cv2.INTER_CUBIC if scale > 1.0 else cv2.INTER_AREA

    if img.ndim == 2:
        resized = cv2.resize(img, (new_w, new_h), interpolation=interp)
        canvas = np.full((out_size, out_size), pad_value_bgr[0], dtype=resized.dtype)
        left = (out_size - new_w) // 2
        top  = (out_size - new_h) // 2
        canvas[top:top+new_h, left:left+new_w] = resized
        right = out_size - left - new_w
        bottom = out_size - top - new_h
        return canvas, scale, (left, top, right, bottom)

    if img.shape[2] == 4:
        b, g, r, a = cv2.split(img)
        bgr = cv2.merge([b, g, r])
        bgr_resized = cv2.resize(bgr, (new_w, new_h), interpolation=interp)
        a_resized   = cv2.resize(a,   (new_w, new_h), interpolation=interp)

        canvas_bgr = np.full((out_size, out_size, 3), pad_value_bgr, dtype=bgr_resized.dtype)
        canvas_a   = np.zeros((out_size, out_size), dtype=a_resized.dtype)  # 透明补边

        left = (out_size - new_w) // 2
        top  = (out_size - new_h) // 2
        canvas_bgr[top:top+new_h, left:left+new_w] = bgr_resized
        canvas_a  [top:top+new_h, left:left+new_w] = a_resized

        right = out_size - left - new_w
        bottom= out_size - top - new_h

        b2, g2, r2 = cv2.split(canvas_bgr)
        canvas_rgba = cv2.merge([b2, g2, r2, canvas_a])
        return canvas_rgba, scale, (left, top, right, bottom)

    # 普通 BGR
    resized = cv2.resize(img, (new_w, new_h), interpolation=interp)
    canvas = np.full((out_size, out_size, 3), pad_value_bgr, dtype=resized.dtype)
    left = (out_size - new_w) // 2
    top  = (out_size - new_h) // 2
    canvas[top:top+new_h, left:left+new_w] = resized
    right = out_size - left - new_w
    bottom= out_size - top - new_h
    return canvas, scale, (left, top, right, bottom)

def map_points_scale_pad(points: Optional[List[List[float]]], scale: float, pad: Tuple[int,int,int,int]) -> Optional[List[List[float]]]:
    """点位按 scale 缩放后，再加上 left/top 的补边偏移。"""
    if not points:
        return None
    left, top, _, _ = pad
    out = []
    for x, y in points:
        out.append([x * scale + left, y * scale + top])
    return out

def save_image(out_path: Path, img: np.ndarray):
    ensure_dir(out_path.parent)
    if out_path.suffix.lower() == ".png":
        cv2.imwrite(str(out_path), img)
    else:
        if img.ndim == 3 and img.shape[2] == 4:
            img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)
        cv2.imwrite(str(out_path), img)

def draw_polygon_on_image(img: np.ndarray,
                          pts: List[List[float]],
                          fill_alpha: float = 0.25,
                          edge_thickness: int = 2) -> np.ndarray:
    """在 img 上绘制 polygon（半透明填充+边界+点）"""
    if img is None or img.size == 0 or not pts:
        return img
    canvas = img
    if canvas.ndim == 3 and canvas.shape[2] == 4:
        canvas = cv2.cvtColor(canvas, cv2.COLOR_BGRA2BGR)

    overlay = canvas.copy()
    np_pts = np.array(pts, dtype=np.float32)
    np_pts = np.round(np_pts).astype(np.int32)

    color_fill = (255, 0, 0)   # BGR
    color_edge = (0, 0, 255)
    color_dot  = (0, 255, 255)

    if len(np_pts) >= 3:
        cv2.fillPoly(overlay, [np_pts], color_fill)
        canvas = cv2.addWeighted(overlay, fill_alpha, canvas, 1 - fill_alpha, 0)
    if len(np_pts) >= 2:
        cv2.polylines(canvas, [np_pts], isClosed=True, color=color_edge, thickness=edge_thickness)
    for p in np_pts:
        cv2.circle(canvas, (int(p[0]), int(p[1])), radius=3, color=color_dot, thickness=-1)

    return canvas

# ========== JSON 写入 ==========
def update_json_scaled_letterbox(in_json: Path, out_json: Path,
                                 scale: float, pad: Tuple[int,int,int,int],
                                 in_w: int, in_h: int, out_w: int, out_h: int,
                                 scaled_points_rel: Optional[List[List[float]]]) -> None:
    with in_json.open("r", encoding="utf-8") as f:
        data = json.load(f)

    if scaled_points_rel is not None:
        data["points_rel_resized"] = [[float(x), float(y)] for (x, y) in scaled_points_rel]

    meta = data.get("meta", {})
    meta.update({
        "method": "letterbox",
        "resized_from": [int(in_w), int(in_h)],
        "resized_to": [int(out_w), int(out_h)],
        "scale": float(scale),
        "pad": {
            "left": int(pad[0]),
            "top": int(pad[1]),
            "right": int(pad[2]),
            "bottom": int(pad[3])
        }
    })
    data["meta"] = meta

    ensure_dir(out_json.parent)
    with out_json.open("w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# ========== 主处理 ==========
def process_one(img_path: Path):
    img = cv2.imread(str(img_path), cv2.IMREAD_UNCHANGED)
    if img is None:
        print(f"[WARN] 读取失败：{img_path}")
        return

    h, w = img.shape[:2]
    in_json = paired_json_for(img_path)
    rel_points = load_rel_points_for_image(in_json)  # 未放大前的相对坐标（当前图坐标系）

    # 等比缩放 + 补边
    lb_img, scale, pad = letterbox_resize(img, out_size=TARGET_SIZE, pad_value_bgr=(114,114,114))

    # 点位同步：先 *scale，再 +left/top
    scaled_rel_points = map_points_scale_pad(rel_points, scale, pad)

    # 输出路径
    rel = img_path.relative_to(IN_DIR)
    out_img  = OUT_RESIZED / rel
    out_vis  = OUT_VIS / rel.with_suffix(".jpg")     # 可视化统一用 JPG
    out_json = OUT_RESIZED / rel.with_suffix(".json")

    # 写图
    save_image(out_img, lb_img)

    # 写 JSON
    if in_json.exists():
        update_json_scaled_letterbox(
            in_json, out_json,
            scale=scale, pad=pad,
            in_w=w, in_h=h, out_w=TARGET_SIZE, out_h=TARGET_SIZE,
            scaled_points_rel=scaled_rel_points
        )

    # 可视化
    if scaled_rel_points is not None:
        vis = draw_polygon_on_image(lb_img.copy(), scaled_rel_points,
                                    fill_alpha=0.25, edge_thickness=2)
    else:
        vis = lb_img.copy()

    save_image(out_vis, vis)

    print(f"[OK] {img_path} -> {out_img.name}, {out_vis.name} (scale={scale:.4f}, pad={pad})")

def main():
    if not IN_DIR.exists():
        print(f"[ERROR] 输入目录不存在：{IN_DIR}")
        return
    ensure_dir(OUT_RESIZED)
    ensure_dir(OUT_VIS)

    patterns = [str(IN_DIR / "**" / f"*{ext}") for ext in IMG_EXTS]
    files = []
    for pat in patterns:
        files.extend(glob.glob(pat, recursive=True))
    img_files = [Path(p) for p in files]

    if not img_files:
        print(f"[INFO] 未找到图片：{IN_DIR}")
        return

    cnt = 0
    for p in img_files:
        try:
            process_one(p)
            cnt += 1
        except Exception as e:
            print(f"[ERR ] 处理失败：{p} -> {e}")

    print(f"[DONE] 共处理图片：{cnt}")
    print(f"[OUT ] 放大图 & 更新 JSON：{OUT_RESIZED.resolve()}")
    print(f"[OUT ] 可视化图：{OUT_VIS.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_0731_700_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9_roi000_mask.png -> 0607_0731_700_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9_roi000_mask.png, 0607_0731_700_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9_roi000_mask.jpg (scale=10.8475, pad=(0, 16, 0, 17))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_0731_700_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d_roi000_mask.png -> 0607_0731_700_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d_roi000_mask.png, 0607_0731_700_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d_roi000_mask.jpg (scale=11.4286, pad=(17, 0, 17, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_0801_700_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e_roi000_mask.png -> 0607_0801_700_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e_roi000_mask.png, 0607_0801_700_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e_roi000_mask.jpg (scale=11.6364, pad=(0, 17, 0, 18))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_0831_700_uuid_43850137-a234-44c7-8005-fc9f3ba5394d_roi000_mask.png -> 0607_0831_700_uuid_43850137-a234-44c7-8005-fc9f3ba5394d_roi000_mask.png, 0607_0831_700_uuid_43850137-a234-44c7-8005-fc9f3ba5394d_roi000_mask.jpg (scale=9.8462, pad=(69, 0, 69, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1104_800_uuid_763cb397-03e6-4f2b-8a0b-e17914bc4d12_roi000_mask.png -> 0731_1104_800_uuid_763cb397-03e6-4f2b-8a0b-e17914bc4d12_roi000_mask.png, 0731_1104_800_uuid_763cb397-03e6-4f2b-8a0b-e17914bc4d12_roi000_mask.jpg (scale=12.8000, pad=(13, 0, 13, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1104_800_uuid_7c314724-2fc5-4b62-aee9-d8dba9f4bc10_roi000_mask.png -> 0731_1104_800_uuid_7c314724-2fc5-4b62-aee9-d8dba9f4bc10_roi000_mask.png, 0731_1104_800_uuid_7c314724-2fc5-4b62-aee9-d8dba9f4bc10_roi000_mask.jpg (scale=10.6667, pad=(42, 0, 43, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1133_760_uuid_21fcb8b5-2ae6-4637-af1d-b3089fd87be8_roi000_mask.png -> 0731_1133_760_uuid_21fcb8b5-2ae6-4637-af1d-b3089fd87be8_roi000_mask.png, 0731_1133_760_uuid_21fcb8b5-2ae6-4637-af1d-b3089fd87be8_roi000_mask.jpg (scale=11.8519, pad=(0, 23, 0, 24))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1134_800_uuid_abccd58e-2358-485f-b45d-d62a0a0b4a7d_roi000_mask.png -> 0731_1134_800_uuid_abccd58e-2358-485f-b45d-d62a0a0b4a7d_roi000_mask.png, 0731_1134_800_uuid_abccd58e-2358-485f-b45d-d62a0a0b4a7d_roi000_mask.jpg (scale=11.4286, pad=(68, 0, 69, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2040_840_uuid_b517b888-4cb9-4100-b859-9f906cecfd5b_roi000_mask.png -> 0731_2040_840_uuid_b517b888-4cb9-4100-b859-9f906cecfd5b_roi000_mask.png, 0731_2040_840_uuid_b517b888-4cb9-4100-b859-9f906cecfd5b_roi000_mask.jpg (scale=11.4286, pad=(0, 57, 0, 57))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2111_760_uuid_c1a5a1f7-a887-4dd7-b09e-20f42449ba61_roi000_mask.png -> 0731_2111_760_uuid_c1a5a1f7-a887-4dd7-b09e-20f42449ba61_roi000_mask.png, 0731_2111_760_uuid_c1a5a1f7-a887-4dd7-b09e-20f42449ba61_roi000_mask.jpg (scale=10.8475, pad=(0, 124, 0, 125))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2112_800_uuid_0f820073-800a-4293-a763-6ac14e4a1dac_roi000_mask.png -> 0731_2112_800_uuid_0f820073-800a-4293-a763-6ac14e4a1dac_roi000_mask.png, 0731_2112_800_uuid_0f820073-800a-4293-a763-6ac14e4a1dac_roi000_mask.jpg (scale=12.3077, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2112_800_uuid_3614c9d3-d3e7-4353-8cd4-554128320672_roi000_mask.png -> 0731_2112_800_uuid_3614c9d3-d3e7-4353-8cd4-554128320672_roi000_mask.png, 0731_2112_800_uuid_3614c9d3-d3e7-4353-8cd4-554128320672_roi000_mask.jpg (scale=10.0000, pad=(120, 0, 120, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2039_800_uuid_12f5c1fc-5211-4e99-bab0-0e5b8956de2e_roi000_mask.png -> 0731_2039_800_uuid_12f5c1fc-5211-4e99-bab0-0e5b8956de2e_roi000_mask.png, 0731_2039_800_uuid_12f5c1fc-5211-4e99-bab0-0e5b8956de2e_roi000_mask.jpg (scale=11.2281, pad=(0, 50, 0, 51))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2039_800_uuid_5bdac058-9a1f-423e-afe1-f281b481cbcc_roi000_mask.png -> 0731_2039_800_uuid_5bdac058-9a1f-423e-afe1-f281b481cbcc_roi000_mask.png, 0731_2039_800_uuid_5bdac058-9a1f-423e-afe1-f281b481cbcc_roi000_mask.jpg (scale=12.3077, pad=(0, 12, 0, 13))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2039_800_uuid_c898453c-d284-429d-8b39-3d179f3331f3_roi000_mask.png -> 0731_2039_800_uuid_c898453c-d284-429d-8b39-3d179f3331f3_roi000_mask.png, 0731_2039_800_uuid_c898453c-d284-429d-8b39-3d179f3331f3_roi000_mask.jpg (scale=12.5490, pad=(69, 0, 69, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2039_800_uuid_caf53adc-3d5c-41f7-9b2b-86127808119d_roi000_mask.png -> 0731_2039_800_uuid_caf53adc-3d5c-41f7-9b2b-86127808119d_roi000_mask.png, 0731_2039_800_uuid_caf53adc-3d5c-41f7-9b2b-86127808119d_roi000_mask.jpg (scale=11.4286, pad=(0, 114, 0, 115))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1203_760_uuid_6e949986-8b74-4b09-b49c-2733c95d7eb1_roi000_mask.png -> 0731_1203_760_uuid_6e949986-8b74-4b09-b49c-2733c95d7eb1_roi000_mask.png, 0731_1203_760_uuid_6e949986-8b74-4b09-b49c-2733c95d7eb1_roi000_mask.jpg (scale=14.8837, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1204_800_uuid_4ac0d4e4-0159-4fa4-ba97-6cff9f14beae_roi000_mask.png -> 0731_1204_800_uuid_4ac0d4e4-0159-4fa4-ba97-6cff9f14beae_roi000_mask.png, 0731_1204_800_uuid_4ac0d4e4-0159-4fa4-ba97-6cff9f14beae_roi000_mask.jpg (scale=11.4286, pad=(91, 0, 92, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1204_800_uuid_877e6907-0552-4475-9704-aa3697c0282d_roi000_mask.png -> 0731_1204_800_uuid_877e6907-0552-4475-9704-aa3697c0282d_roi000_mask.png, 0731_1204_800_uuid_877e6907-0552-4475-9704-aa3697c0282d_roi000_mask.jpg (scale=13.3333, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1233_760_uuid_b52d3d9b-25eb-4438-8be4-ac4d301ed731_roi000_mask.png -> 0731_1233_760_uuid_b52d3d9b-25eb-4438-8be4-ac4d301ed731_roi000_mask.png, 0731_1233_760_uuid_b52d3d9b-25eb-4438-8be4-ac4d301ed731_roi000_mask.jpg (scale=14.5455, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2037_760_uuid_16913f05-f4b6-432e-995b-e0c540862fa4_roi000_mask.png -> 0731_2037_760_uuid_16913f05-f4b6-432e-995b-e0c540862fa4_roi000_mask.png, 0731_2037_760_uuid_16913f05-f4b6-432e-995b-e0c540862fa4_roi000_mask.jpg (scale=13.3333, pad=(80, 0, 80, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2037_760_uuid_26eff48e-d7e0-4d35-89dd-00e0165bd124_roi000_mask.png -> 0731_2037_760_uuid_26eff48e-d7e0-4d35-89dd-00e0165bd124_roi000_mask.png, 0731_2037_760_uuid_26eff48e-d7e0-4d35-89dd-00e0165bd124_roi000_mask.jpg (scale=11.4286, pad=(0, 68, 0, 69))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2037_760_uuid_433815b6-38a1-4426-92c1-fe95a98ce3c9_roi000_mask.png -> 0731_2037_760_uuid_433815b6-38a1-4426-92c1-fe95a98ce3c9_roi000_mask.png, 0731_2037_760_uuid_433815b6-38a1-4426-92c1-fe95a98ce3c9_roi000_mask.jpg (scale=11.4286, pad=(0, 160, 0, 160))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2037_760_uuid_4c7e457d-8c85-4fb9-997d-c2d81377ad9f_roi000_mask.png -> 0731_2037_760_uuid_4c7e457d-8c85-4fb9-997d-c2d81377ad9f_roi000_mask.png, 0731_2037_760_uuid_4c7e457d-8c85-4fb9-997d-c2d81377ad9f_roi000_mask.jpg (scale=10.0000, pad=(0, 125, 0, 125))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2037_760_uuid_b242cdf6-6f80-477d-8e2f-91c4af478c6c_roi000_mask.png -> 0731_2037_760_uuid_b242cdf6-6f80-477d-8e2f-91c4af478c6c_roi000_mask.png, 0731_2037_760_uuid_b242cdf6-6f80-477d-8e2f-91c4af478c6c_roi000_mask.jpg (scale=11.4286, pad=(0, 188, 0, 189))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_0901_700_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0_roi000_mask.png -> 0607_0901_700_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0_roi000_mask.png, 0607_0901_700_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0_roi000_mask.jpg (scale=12.0755, pad=(78, 0, 79, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0612_0831_700_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b_roi000_mask.png -> 0612_0831_700_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b_roi000_mask.png, 0612_0831_700_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b_roi000_mask.jpg (scale=10.4918, pad=(47, 0, 47, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_1031_700_uuid_682712ba-90b0-426d-bdb1-95dc0615c5fd_roi000_mask.png -> 0614_1031_700_uuid_682712ba-90b0-426d-bdb1-95dc0615c5fd_roi000_mask.png, 0614_1031_700_uuid_682712ba-90b0-426d-bdb1-95dc0615c5fd_roi000_mask.jpg (scale=9.8462, pad=(0, 128, 0, 128))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0716_2005_600_uuid_6280a194-c455-4e1d-bfe1-14ff887d20f3_roi000_mask.png -> 0716_2005_600_uuid_6280a194-c455-4e1d-bfe1-14ff887d20f3_roi000_mask.png, 0716_2005_600_uuid_6280a194-c455-4e1d-bfe1-14ff887d20f3_roi000_mask.jpg (scale=10.3226, pad=(0, 175, 0, 176))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2142_800_uuid_b1ef0a02-01f1-451d-bcef-bbd684bb5929_roi000_mask.png -> 0731_2142_800_uuid_b1ef0a02-01f1-451d-bcef-bbd684bb5929_roi000_mask.png, 0731_2142_800_uuid_b1ef0a02-01f1-451d-bcef-bbd684bb5929_roi000_mask.jpg (scale=13.3333, pad=(46, 0, 47, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2211_760_uuid_56da1137-9f54-48b7-8d72-814bb4519c98_roi000_mask.png -> 0731_2211_760_uuid_56da1137-9f54-48b7-8d72-814bb4519c98_roi000_mask.png, 0731_2211_760_uuid_56da1137-9f54-48b7-8d72-814bb4519c98_roi000_mask.jpg (scale=14.5455, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2211_760_uuid_d5f41b97-e608-48a1-b38c-95f590863a83_roi000_mask.png -> 0731_2211_760_uuid_d5f41b97-e608-48a1-b38c-95f590863a83_roi000_mask.png, 0731_2211_760_uuid_d5f41b97-e608-48a1-b38c-95f590863a83_roi000_mask.jpg (scale=10.6667, pad=(128, 0, 128, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2241_760_uuid_d5307554-f7be-434b-abac-d3177a577a62_roi000_mask.png -> 0731_2241_760_uuid_d5307554-f7be-434b-abac-d3177a577a62_roi000_mask.png, 0731_2241_760_uuid_d5307554-f7be-434b-abac-d3177a577a62_roi000_mask.jpg (scale=15.2381, pad=(15, 0, 15, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0801_0542_800_uuid_43096618-dea8-44f5-96c6-7607d2d99c8f_roi000_mask.png -> 0801_0542_800_uuid_43096618-dea8-44f5-96c6-7607d2d99c8f_roi000_mask.png, 0801_0542_800_uuid_43096618-dea8-44f5-96c6-7607d2d99c8f_roi000_mask.jpg (scale=12.8000, pad=(13, 0, 13, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0802_0852_760_uuid_5b2f2f99-a093-42f6-a4d0-b0555d43a63d_roi000_mask.png -> 0802_0852_760_uuid_5b2f2f99-a093-42f6-a4d0-b0555d43a63d_roi000_mask.png, 0802_0852_760_uuid_5b2f2f99-a093-42f6-a4d0-b0555d43a63d_roi000_mask.jpg (scale=10.6667, pad=(64, 0, 64, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0802_0854_800_uuid_6130bfaf-862f-4bb5-932a-7229c523d5b7_roi000_mask.png -> 0802_0854_800_uuid_6130bfaf-862f-4bb5-932a-7229c523d5b7_roi000_mask.png, 0802_0854_800_uuid_6130bfaf-862f-4bb5-932a-7229c523d5b7_roi000_mask.jpg (scale=12.3077, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_0913_760_uuid_66dede5e-915a-426f-82a9-2ae766970b71_roi000_mask.png -> 0803_0913_760_uuid_66dede5e-915a-426f-82a9-2ae766970b71_roi000_mask.png, 0803_0913_760_uuid_66dede5e-915a-426f-82a9-2ae766970b71_roi000_mask.jpg (scale=11.0345, pad=(0, 121, 0, 122))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_0943_760_uuid_c3c60a70-c98c-4601-aaed-6345f92b8392_roi000_mask.png -> 0803_0943_760_uuid_c3c60a70-c98c-4601-aaed-6345f92b8392_roi000_mask.png, 0803_0943_760_uuid_c3c60a70-c98c-4601-aaed-6345f92b8392_roi000_mask.jpg (scale=10.6667, pad=(0, 128, 0, 128))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1043_760_uuid_9a47261e-60f7-4028-a86f-12aac5eb6adc_roi000_mask.png -> 0803_1043_760_uuid_9a47261e-60f7-4028-a86f-12aac5eb6adc_roi000_mask.png, 0803_1043_760_uuid_9a47261e-60f7-4028-a86f-12aac5eb6adc_roi000_mask.jpg (scale=13.3333, pad=(80, 0, 80, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1113_760_uuid_7705b98b-12c2-49ea-b1e8-fa9acdd9b0dc_roi000_mask.png -> 0803_1113_760_uuid_7705b98b-12c2-49ea-b1e8-fa9acdd9b0dc_roi000_mask.png, 0803_1113_760_uuid_7705b98b-12c2-49ea-b1e8-fa9acdd9b0dc_roi000_mask.jpg (scale=12.5490, pad=(94, 0, 94, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1343_760_uuid_a7ef328e-d886-448a-8a4e-715c0373fc7f_roi000_mask.png -> 0803_1343_760_uuid_a7ef328e-d886-448a-8a4e-715c0373fc7f_roi000_mask.png, 0803_1343_760_uuid_a7ef328e-d886-448a-8a4e-715c0373fc7f_roi000_mask.jpg (scale=13.3333, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1413_760_uuid_9fc92a55-ce93-4880-bb2f-799d62b92afc_roi000_mask.png -> 0803_1413_760_uuid_9fc92a55-ce93-4880-bb2f-799d62b92afc_roi000_mask.png, 0803_1413_760_uuid_9fc92a55-ce93-4880-bb2f-799d62b92afc_roi000_mask.jpg (scale=12.3077, pad=(74, 0, 74, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1443_760_uuid_9a48f1eb-bd0e-4fb3-ac24-ee75dddf7a91_roi000_mask.png -> 0803_1443_760_uuid_9a48f1eb-bd0e-4fb3-ac24-ee75dddf7a91_roi000_mask.png, 0803_1443_760_uuid_9a48f1eb-bd0e-4fb3-ac24-ee75dddf7a91_roi000_mask.jpg (scale=11.4286, pad=(91, 0, 92, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1513_760_uuid_10805ce0-086b-4775-9825-93141286e722_roi000_mask.png -> 0803_1513_760_uuid_10805ce0-086b-4775-9825-93141286e722_roi000_mask.png, 0803_1513_760_uuid_10805ce0-086b-4775-9825-93141286e722_roi000_mask.jpg (scale=11.6364, pad=(87, 0, 88, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_0934_800_uuid_5579357b-7b9c-40cc-b9f8-5c884e679710_roi000_mask.png -> 0731_0934_800_uuid_5579357b-7b9c-40cc-b9f8-5c884e679710_roi000_mask.png, 0731_0934_800_uuid_5579357b-7b9c-40cc-b9f8-5c884e679710_roi000_mask.jpg (scale=11.4286, pad=(51, 0, 52, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_0934_800_uuid_90f728c2-281c-4337-90ee-442519876201_roi000_mask.png -> 0731_0934_800_uuid_90f728c2-281c-4337-90ee-442519876201_roi000_mask.png, 0731_0934_800_uuid_90f728c2-281c-4337-90ee-442519876201_roi000_mask.jpg (scale=14.5455, pad=(29, 0, 29, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1003_760_uuid_1ace56e3-1024-4f6b-96b6-9472607c680b_roi000_mask.png -> 0731_1003_760_uuid_1ace56e3-1024-4f6b-96b6-9472607c680b_roi000_mask.png, 0731_1003_760_uuid_1ace56e3-1024-4f6b-96b6-9472607c680b_roi000_mask.jpg (scale=14.5455, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_1004_800_uuid_f57844a9-3fd7-4696-a557-95546555001b_roi000_mask.png -> 0731_1004_800_uuid_f57844a9-3fd7-4696-a557-95546555001b_roi000_mask.png, 0731_1004_800_uuid_f57844a9-3fd7-4696-a557-95546555001b_roi000_mask.jpg (scale=14.5455, pad=(0, 7, 0, 8))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0114_760_uuid_bb105020-21d5-4fc3-be9f-190e574b9469_roi000_mask.png -> 0720_0114_760_uuid_bb105020-21d5-4fc3-be9f-190e574b9469_roi000_mask.png, 0720_0114_760_uuid_bb105020-21d5-4fc3-be9f-190e574b9469_roi000_mask.jpg (scale=10.6667, pad=(0, 112, 0, 112))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0132_760_uuid_6653f1f1-5c7f-4d99-b1ae-9542436f682a_roi000_mask.png -> 0720_0132_760_uuid_6653f1f1-5c7f-4d99-b1ae-9542436f682a_roi000_mask.png, 0720_0132_760_uuid_6653f1f1-5c7f-4d99-b1ae-9542436f682a_roi000_mask.jpg (scale=11.4286, pad=(0, 45, 0, 46))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0202_760_uuid_ab86d4ec-b636-46b7-8ee1-e1bd5cb08c58_roi000_mask.png -> 0720_0202_760_uuid_ab86d4ec-b636-46b7-8ee1-e1bd5cb08c58_roi000_mask.png, 0720_0202_760_uuid_ab86d4ec-b636-46b7-8ee1-e1bd5cb08c58_roi000_mask.jpg (scale=11.6364, pad=(134, 0, 134, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0232_760_uuid_53b680ae-585a-43f2-b7c9-459bc8a3477c_roi000_mask.png -> 0720_0232_760_uuid_53b680ae-585a-43f2-b7c9-459bc8a3477c_roi000_mask.png, 0720_0232_760_uuid_53b680ae-585a-43f2-b7c9-459bc8a3477c_roi000_mask.jpg (scale=12.3077, pad=(24, 0, 25, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0402_760_uuid_2ad00337-179e-4919-82d5-31472f725957_roi000_mask.png -> 0720_0402_760_uuid_2ad00337-179e-4919-82d5-31472f725957_roi000_mask.png, 0720_0402_760_uuid_2ad00337-179e-4919-82d5-31472f725957_roi000_mask.jpg (scale=11.6364, pad=(40, 0, 41, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0432_760_uuid_47359ffa-9f24-4842-906d-a38104fdf884_roi000_mask.png -> 0720_0432_760_uuid_47359ffa-9f24-4842-906d-a38104fdf884_roi000_mask.png, 0720_0432_760_uuid_47359ffa-9f24-4842-906d-a38104fdf884_roi000_mask.jpg (scale=9.4118, pad=(0, 75, 0, 76))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0720_0532_760_uuid_abfb9c2b-569f-4077-ad39-4f9439f6e72a_roi000_mask.png -> 0720_0532_760_uuid_abfb9c2b-569f-4077-ad39-4f9439f6e72a_roi000_mask.png, 0720_0532_760_uuid_abfb9c2b-569f-4077-ad39-4f9439f6e72a_roi000_mask.jpg (scale=11.6364, pad=(0, 17, 0, 18))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1143_760_uuid_781e0934-3f82-4baa-9f53-a87e3bbc959b_roi000_mask.png -> 0803_1143_760_uuid_781e0934-3f82-4baa-9f53-a87e3bbc959b_roi000_mask.png, 0803_1143_760_uuid_781e0934-3f82-4baa-9f53-a87e3bbc959b_roi000_mask.jpg (scale=12.3077, pad=(98, 0, 99, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1243_760_uuid_0b507d48-389e-4394-bf7a-49657d18420a_roi000_mask.png -> 0803_1243_760_uuid_0b507d48-389e-4394-bf7a-49657d18420a_roi000_mask.png, 0803_1243_760_uuid_0b507d48-389e-4394-bf7a-49657d18420a_roi000_mask.jpg (scale=12.5490, pad=(69, 0, 69, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1243_760_uuid_79603824-c256-489c-904a-65a6ce260d01_roi000_mask.png -> 0803_1243_760_uuid_79603824-c256-489c-904a-65a6ce260d01_roi000_mask.png, 0803_1243_760_uuid_79603824-c256-489c-904a-65a6ce260d01_roi000_mask.jpg (scale=10.6667, pad=(128, 0, 128, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1313_760_uuid_12768f06-0266-454b-8188-3f8c5391e7b3_roi000_mask.png -> 0803_1313_760_uuid_12768f06-0266-454b-8188-3f8c5391e7b3_roi000_mask.png, 0803_1313_760_uuid_12768f06-0266-454b-8188-3f8c5391e7b3_roi000_mask.jpg (scale=11.6364, pad=(0, 110, 0, 111))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1513_760_uuid_b0937a73-e2a6-4aab-a1b3-bea78d657f08_roi000_mask.png -> 0803_1513_760_uuid_b0937a73-e2a6-4aab-a1b3-bea78d657f08_roi000_mask.png, 0803_1513_760_uuid_b0937a73-e2a6-4aab-a1b3-bea78d657f08_roi000_mask.jpg (scale=11.6364, pad=(0, 87, 0, 88))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1543_760_uuid_118450bc-5173-42d6-8d97-5b1e4f93b5eb_roi000_mask.png -> 0803_1543_760_uuid_118450bc-5173-42d6-8d97-5b1e4f93b5eb_roi000_mask.png, 0803_1543_760_uuid_118450bc-5173-42d6-8d97-5b1e4f93b5eb_roi000_mask.jpg (scale=10.6667, pad=(0, 128, 0, 128))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1543_760_uuid_3ccb9eab-6ada-409c-91ab-b8c5f95d4e1f_roi000_mask.png -> 0803_1543_760_uuid_3ccb9eab-6ada-409c-91ab-b8c5f95d4e1f_roi000_mask.png, 0803_1543_760_uuid_3ccb9eab-6ada-409c-91ab-b8c5f95d4e1f_roi000_mask.jpg (scale=12.3077, pad=(123, 0, 123, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1613_760_uuid_70ca6f13-2b22-4c21-8e6f-39b917b63ce2_roi000_mask.png -> 0803_1613_760_uuid_70ca6f13-2b22-4c21-8e6f-39b917b63ce2_roi000_mask.png, 0803_1613_760_uuid_70ca6f13-2b22-4c21-8e6f-39b917b63ce2_roi000_mask.jpg (scale=11.4286, pad=(0, 91, 0, 92))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1643_760_uuid_9b6ce2df-3621-4cd8-8e5e-bea2e5b270a8_roi000_mask.png -> 0803_1643_760_uuid_9b6ce2df-3621-4cd8-8e5e-bea2e5b270a8_roi000_mask.png, 0803_1643_760_uuid_9b6ce2df-3621-4cd8-8e5e-bea2e5b270a8_roi000_mask.jpg (scale=11.4286, pad=(0, 114, 0, 115))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1713_760_uuid_7c5a1898-93f8-4e07-9d2b-ecb819304a45_roi000_mask.png -> 0803_1713_760_uuid_7c5a1898-93f8-4e07-9d2b-ecb819304a45_roi000_mask.png, 0803_1713_760_uuid_7c5a1898-93f8-4e07-9d2b-ecb819304a45_roi000_mask.jpg (scale=11.6364, pad=(0, 87, 0, 88))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1743_760_uuid_d305e724-a812-49a1-bb60-1f0980ea3b28_roi000_mask.png -> 0803_1743_760_uuid_d305e724-a812-49a1-bb60-1f0980ea3b28_roi000_mask.png, 0803_1743_760_uuid_d305e724-a812-49a1-bb60-1f0980ea3b28_roi000_mask.jpg (scale=10.6667, pad=(0, 106, 0, 107))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0111_760_uuid_0ec81b15-c165-4996-8e30-43fdb8530a44_roi000_mask.png -> 0719_0111_760_uuid_0ec81b15-c165-4996-8e30-43fdb8530a44_roi000_mask.png, 0719_0111_760_uuid_0ec81b15-c165-4996-8e30-43fdb8530a44_roi000_mask.jpg (scale=11.6364, pad=(87, 0, 88, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0111_760_uuid_202ce91f-a3ac-4a72-bbde-b4a4b7165527_roi000_mask.png -> 0719_0111_760_uuid_202ce91f-a3ac-4a72-bbde-b4a4b7165527_roi000_mask.png, 0719_0111_760_uuid_202ce91f-a3ac-4a72-bbde-b4a4b7165527_roi000_mask.jpg (scale=11.4286, pad=(91, 0, 92, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0111_760_uuid_35715a06-28f0-453c-a25c-5ed5e94e4d79_roi000_mask.png -> 0719_0111_760_uuid_35715a06-28f0-453c-a25c-5ed5e94e4d79_roi000_mask.png, 0719_0111_760_uuid_35715a06-28f0-453c-a25c-5ed5e94e4d79_roi000_mask.jpg (scale=11.4286, pad=(45, 0, 46, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0111_760_uuid_83f1c984-8b53-4c7f-9ff4-6abb26fd10e2_roi000_mask.png -> 0719_0111_760_uuid_83f1c984-8b53-4c7f-9ff4-6abb26fd10e2_roi000_mask.png, 0719_0111_760_uuid_83f1c984-8b53-4c7f-9ff4-6abb26fd10e2_roi000_mask.jpg (scale=10.6667, pad=(149, 0, 150, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0141_760_uuid_2aaa56ff-8108-45d2-9b62-e1a6b4451f24_roi000_mask.png -> 0719_0141_760_uuid_2aaa56ff-8108-45d2-9b62-e1a6b4451f24_roi000_mask.png, 0719_0141_760_uuid_2aaa56ff-8108-45d2-9b62-e1a6b4451f24_roi000_mask.jpg (scale=12.3077, pad=(49, 0, 49, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0141_760_uuid_92a4d9f7-55cd-4f17-8aaa-fac75874d237_roi000_mask.png -> 0719_0141_760_uuid_92a4d9f7-55cd-4f17-8aaa-fac75874d237_roi000_mask.png, 0719_0141_760_uuid_92a4d9f7-55cd-4f17-8aaa-fac75874d237_roi000_mask.jpg (scale=11.6364, pad=(0, 6, 0, 6))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0141_760_uuid_aa83de1d-07eb-4abc-94a3-323a6575a8e3_roi000_mask.png -> 0719_0141_760_uuid_aa83de1d-07eb-4abc-94a3-323a6575a8e3_roi000_mask.png, 0719_0141_760_uuid_aa83de1d-07eb-4abc-94a3-323a6575a8e3_roi000_mask.jpg (scale=13.3333, pad=(133, 0, 134, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0141_760_uuid_d487c18b-c791-42b5-a4c8-e34cdac40e74_roi000_mask.png -> 0719_0141_760_uuid_d487c18b-c791-42b5-a4c8-e34cdac40e74_roi000_mask.png, 0719_0141_760_uuid_d487c18b-c791-42b5-a4c8-e34cdac40e74_roi000_mask.jpg (scale=11.4286, pad=(0, 114, 0, 115))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0211_760_uuid_2712f95d-1fb6-43ec-a950-eee41b7783af_roi000_mask.png -> 0719_0211_760_uuid_2712f95d-1fb6-43ec-a950-eee41b7783af_roi000_mask.png, 0719_0211_760_uuid_2712f95d-1fb6-43ec-a950-eee41b7783af_roi000_mask.jpg (scale=11.6364, pad=(40, 0, 41, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0211_760_uuid_9e098409-e5d0-4416-9ad7-efdf3b6b888f_roi000_mask.png -> 0719_0211_760_uuid_9e098409-e5d0-4416-9ad7-efdf3b6b888f_roi000_mask.png, 0719_0211_760_uuid_9e098409-e5d0-4416-9ad7-efdf3b6b888f_roi000_mask.jpg (scale=9.4118, pad=(0, 132, 0, 132))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0730_2207_800_uuid_f95891d1-84e2-426d-93a7-a167c3feb63d_roi000_mask.png -> 0730_2207_800_uuid_f95891d1-84e2-426d-93a7-a167c3feb63d_roi000_mask.png, 0730_2207_800_uuid_f95891d1-84e2-426d-93a7-a167c3feb63d_roi000_mask.jpg (scale=10.6667, pad=(0, 48, 0, 48))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_0903_760_uuid_1fad8d0f-3463-4095-b94a-a7fe9ed68ef7_roi000_mask.png -> 0731_0903_760_uuid_1fad8d0f-3463-4095-b94a-a7fe9ed68ef7_roi000_mask.png, 0731_0903_760_uuid_1fad8d0f-3463-4095-b94a-a7fe9ed68ef7_roi000_mask.jpg (scale=13.9130, pad=(0, 14, 0, 14))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_0904_800_uuid_a0fb7c26-f3d4-4d36-9fff-b96ea526f47a_roi000_mask.png -> 0731_0904_800_uuid_a0fb7c26-f3d4-4d36-9fff-b96ea526f47a_roi000_mask.png, 0731_0904_800_uuid_a0fb7c26-f3d4-4d36-9fff-b96ea526f47a_roi000_mask.jpg (scale=12.5490, pad=(0, 44, 0, 44))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_0933_760_uuid_5c8b635d-db6e-4e3d-8213-78a9cd0be648_roi000_mask.png -> 0731_0933_760_uuid_5c8b635d-db6e-4e3d-8213-78a9cd0be648_roi000_mask.png, 0731_0933_760_uuid_5c8b635d-db6e-4e3d-8213-78a9cd0be648_roi000_mask.jpg (scale=14.5455, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0211_760_uuid_ff7a01f5-aee4-4430-bc25-8cc754d4e42e_roi000_mask.png -> 0719_0211_760_uuid_ff7a01f5-aee4-4430-bc25-8cc754d4e42e_roi000_mask.png, 0719_0211_760_uuid_ff7a01f5-aee4-4430-bc25-8cc754d4e42e_roi000_mask.jpg (scale=11.4286, pad=(137, 0, 137, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0212_800_uuid_6a5d5b92-151f-4f60-8f8f-1bf5df2d4b55_roi000_mask.png -> 0719_0212_800_uuid_6a5d5b92-151f-4f60-8f8f-1bf5df2d4b55_roi000_mask.png, 0719_0212_800_uuid_6a5d5b92-151f-4f60-8f8f-1bf5df2d4b55_roi000_mask.jpg (scale=11.4286, pad=(45, 0, 46, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0241_760_uuid_e95bdfc2-87dc-4982-9b0b-757a4e4162de_roi000_mask.png -> 0719_0241_760_uuid_e95bdfc2-87dc-4982-9b0b-757a4e4162de_roi000_mask.png, 0719_0241_760_uuid_e95bdfc2-87dc-4982-9b0b-757a4e4162de_roi000_mask.jpg (scale=11.4286, pad=(91, 0, 92, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0411_760_uuid_fcb2605f-6334-4235-9455-08801cf5f1a8_roi000_mask.png -> 0719_0411_760_uuid_fcb2605f-6334-4235-9455-08801cf5f1a8_roi000_mask.png, 0719_0411_760_uuid_fcb2605f-6334-4235-9455-08801cf5f1a8_roi000_mask.jpg (scale=11.4286, pad=(97, 0, 97, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_2105_760_uuid_9fdb36e0-7937-4d18-8a93-808da6d332b1_roi000_mask.png -> 0718_2105_760_uuid_9fdb36e0-7937-4d18-8a93-808da6d332b1_roi000_mask.png, 0718_2105_760_uuid_9fdb36e0-7937-4d18-8a93-808da6d332b1_roi000_mask.jpg (scale=10.0000, pad=(0, 140, 0, 140))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0041_760_uuid_b88ec47e-0c4d-46cb-a2ca-a7aead7d7ef5_roi000_mask.png -> 0719_0041_760_uuid_b88ec47e-0c4d-46cb-a2ca-a7aead7d7ef5_roi000_mask.png, 0719_0041_760_uuid_b88ec47e-0c4d-46cb-a2ca-a7aead7d7ef5_roi000_mask.jpg (scale=10.6667, pad=(149, 0, 150, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0041_760_uuid_fb3e7332-98d7-4435-9679-14cad38b854b_roi000_mask.png -> 0719_0041_760_uuid_fb3e7332-98d7-4435-9679-14cad38b854b_roi000_mask.png, 0719_0041_760_uuid_fb3e7332-98d7-4435-9679-14cad38b854b_roi000_mask.jpg (scale=10.6667, pad=(149, 0, 150, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0719_0041_760_uuid_fce907df-0744-4c41-b570-8b411f96c6db_roi000_mask.png -> 0719_0041_760_uuid_fce907df-0744-4c41-b570-8b411f96c6db_roi000_mask.png, 0719_0041_760_uuid_fce907df-0744-4c41-b570-8b411f96c6db_roi000_mask.jpg (scale=13.3333, pad=(0, 26, 0, 27))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0618_1108_780_uuid_7ef8f9df-718c-4df0-aea0-5c98164e3cb0_roi000_mask.png -> 0618_1108_780_uuid_7ef8f9df-718c-4df0-aea0-5c98164e3cb0_roi000_mask.png, 0618_1108_780_uuid_7ef8f9df-718c-4df0-aea0-5c98164e3cb0_roi000_mask.jpg (scale=11.4286, pad=(68, 0, 69, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0619_0731_700_uuid_9737ea3c-2f78-4869-bd6f-0045c583a414_roi000_mask.png -> 0619_0731_700_uuid_9737ea3c-2f78-4869-bd6f-0045c583a414_roi000_mask.png, 0619_0731_700_uuid_9737ea3c-2f78-4869-bd6f-0045c583a414_roi000_mask.jpg (scale=11.4286, pad=(114, 0, 115, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0707_2027_760_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2_roi000_mask.png -> 0707_2027_760_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2_roi000_mask.png, 0707_2027_760_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2_roi000_mask.jpg (scale=10.0000, pad=(180, 0, 180, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0707_2106_760_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487_roi000_mask.png -> 0707_2106_760_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487_roi000_mask.png, 0707_2106_760_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487_roi000_mask.jpg (scale=10.0000, pad=(0, 160, 0, 160))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0709_0357_760_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c_roi000_mask.png -> 0709_0357_760_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c_roi000_mask.png, 0709_0357_760_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c_roi000_mask.jpg (scale=12.3077, pad=(24, 0, 25, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2039_800_uuid_e8bd32e1-a920-4324-864d-23f189d7e634_roi000_mask.png -> 0731_2039_800_uuid_e8bd32e1-a920-4324-864d-23f189d7e634_roi000_mask.png, 0731_2039_800_uuid_e8bd32e1-a920-4324-864d-23f189d7e634_roi000_mask.jpg (scale=12.5490, pad=(44, 0, 44, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0731_2142_800_uuid_95875294-870a-4a2e-ade2-7a2db3ad5d8b_roi000_mask.png -> 0731_2142_800_uuid_95875294-870a-4a2e-ade2-7a2db3ad5d8b_roi000_mask.png, 0731_2142_800_uuid_95875294-870a-4a2e-ade2-7a2db3ad5d8b_roi000_mask.jpg (scale=10.0000, pad=(0, 140, 0, 140))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0803_1343_760_uuid_69cbf2cb-b969-40a4-93df-4bc7ed1c8203_roi000_mask.png -> 0803_1343_760_uuid_69cbf2cb-b969-40a4-93df-4bc7ed1c8203_roi000_mask.png, 0803_1343_760_uuid_69cbf2cb-b969-40a4-93df-4bc7ed1c8203_roi000_mask.jpg (scale=12.5490, pad=(94, 0, 94, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_1031_700_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8_roi000_mask.png -> 0607_1031_700_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8_roi000_mask.png, 0607_1031_700_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8_roi000_mask.jpg (scale=12.3077, pad=(0, 0, 0, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0607_1031_700_uuid_68e56662-0412-4703-ab87-2b36a4cb2393_roi000_mask.png -> 0607_1031_700_uuid_68e56662-0412-4703-ab87-2b36a4cb2393_roi000_mask.png, 0607_1031_700_uuid_68e56662-0412-4703-ab87-2b36a4cb2393_roi000_mask.jpg (scale=10.6667, pad=(133, 0, 134, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1131_700_uuid_d171f9a1-1d37-4230-893f-82049d74cb05_roi000_mask.png -> 0611_1131_700_uuid_d171f9a1-1d37-4230-893f-82049d74cb05_roi000_mask.png, 0611_1131_700_uuid_d171f9a1-1d37-4230-893f-82049d74cb05_roi000_mask.jpg (scale=13.9130, pad=(7, 0, 7, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1131_700_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7_roi000_mask.png -> 0611_1131_700_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7_roi000_mask.png, 0611_1131_700_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7_roi000_mask.jpg (scale=10.0000, pad=(0, 20, 0, 20))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_0931_700_uuid_0c5612bc-2f33-4df4-8951-1171d802812c_roi000_mask.png -> 0614_0931_700_uuid_0c5612bc-2f33-4df4-8951-1171d802812c_roi000_mask.png, 0614_0931_700_uuid_0c5612bc-2f33-4df4-8951-1171d802812c_roi000_mask.jpg (scale=9.8462, pad=(0, 98, 0, 99))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_0931_700_uuid_66ef8c78-572b-4509-af31-8b7dbc5fdf19_roi000_mask.png -> 0614_0931_700_uuid_66ef8c78-572b-4509-af31-8b7dbc5fdf19_roi000_mask.png, 0614_0931_700_uuid_66ef8c78-572b-4509-af31-8b7dbc5fdf19_roi000_mask.jpg (scale=9.4118, pad=(150, 0, 151, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_0931_700_uuid_932dccde-efb5-4c4f-81c4-647ecad04bc1_roi000_mask.png -> 0614_0931_700_uuid_932dccde-efb5-4c4f-81c4-647ecad04bc1_roi000_mask.png, 0614_0931_700_uuid_932dccde-efb5-4c4f-81c4-647ecad04bc1_roi000_mask.jpg (scale=9.6970, pad=(0, 29, 0, 29))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_1001_700_uuid_2090a01b-d10e-4099-ac80-947b03273c0e_roi000_mask.png -> 0614_1001_700_uuid_2090a01b-d10e-4099-ac80-947b03273c0e_roi000_mask.png, 0614_1001_700_uuid_2090a01b-d10e-4099-ac80-947b03273c0e_roi000_mask.jpg (scale=10.0000, pad=(0, 95, 0, 95))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1501_700_uuid_d9958617-2b53-4b46-8d1f-f7a402c047d3_roi000_mask.png -> 0611_1501_700_uuid_d9958617-2b53-4b46-8d1f-f7a402c047d3_roi000_mask.png, 0611_1501_700_uuid_d9958617-2b53-4b46-8d1f-f7a402c047d3_roi000_mask.jpg (scale=10.6667, pad=(128, 0, 128, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1531_700_uuid_931bda08-0145-47a3-8880-832ad4df40b8_roi000_mask.png -> 0611_1531_700_uuid_931bda08-0145-47a3-8880-832ad4df40b8_roi000_mask.png, 0611_1531_700_uuid_931bda08-0145-47a3-8880-832ad4df40b8_roi000_mask.jpg (scale=10.6667, pad=(170, 0, 171, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1631_700_uuid_00600deb-0c3e-4468-8a4c-e41d8b6204ab_roi000_mask.png -> 0611_1631_700_uuid_00600deb-0c3e-4468-8a4c-e41d8b6204ab_roi000_mask.png, 0611_1631_700_uuid_00600deb-0c3e-4468-8a4c-e41d8b6204ab_roi000_mask.jpg (scale=11.4286, pad=(160, 0, 160, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0612_0701_700_uuid_3b6bb0e6-8ea7-49e0-ba63-d97566a20a19_roi000_mask.png -> 0612_0701_700_uuid_3b6bb0e6-8ea7-49e0-ba63-d97566a20a19_roi000_mask.png, 0612_0701_700_uuid_3b6bb0e6-8ea7-49e0-ba63-d97566a20a19_roi000_mask.jpg (scale=10.0000, pad=(0, 120, 0, 120))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1201_700_uuid_57a22d60-d965-4788-a1b5-5bfc62336b07_roi000_mask.png -> 0611_1201_700_uuid_57a22d60-d965-4788-a1b5-5bfc62336b07_roi000_mask.png, 0611_1201_700_uuid_57a22d60-d965-4788-a1b5-5bfc62336b07_roi000_mask.jpg (scale=12.5490, pad=(62, 0, 63, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1301_700_uuid_bde9315e-4bf4-47f6-ace3-016391cf26fc_roi000_mask.png -> 0611_1301_700_uuid_bde9315e-4bf4-47f6-ace3-016391cf26fc_roi000_mask.png, 0611_1301_700_uuid_bde9315e-4bf4-47f6-ace3-016391cf26fc_roi000_mask.jpg (scale=10.6667, pad=(154, 0, 155, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1301_700_uuid_d64091e3-4914-4ff0-8665-3618096f71da_roi000_mask.png -> 0611_1301_700_uuid_d64091e3-4914-4ff0-8665-3618096f71da_roi000_mask.png, 0611_1301_700_uuid_d64091e3-4914-4ff0-8665-3618096f71da_roi000_mask.jpg (scale=10.4918, pad=(21, 0, 21, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1331_700_uuid_809d621f-894a-4b1c-b5ce-bebc064c7b93_roi000_mask.png -> 0611_1331_700_uuid_809d621f-894a-4b1c-b5ce-bebc064c7b93_roi000_mask.png, 0611_1331_700_uuid_809d621f-894a-4b1c-b5ce-bebc064c7b93_roi000_mask.jpg (scale=10.6667, pad=(149, 0, 150, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1401_700_uuid_e0a7482d-c38a-4278-9796-53af48e2400e_roi000_mask.png -> 0611_1401_700_uuid_e0a7482d-c38a-4278-9796-53af48e2400e_roi000_mask.png, 0611_1401_700_uuid_e0a7482d-c38a-4278-9796-53af48e2400e_roi000_mask.jpg (scale=11.2281, pad=(118, 0, 118, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0611_1431_700_uuid_5273fab0-16e6-494b-a2ae-9710cf159313_roi000_mask.png -> 0611_1431_700_uuid_5273fab0-16e6-494b-a2ae-9710cf159313_roi000_mask.png, 0611_1431_700_uuid_5273fab0-16e6-494b-a2ae-9710cf159313_roi000_mask.jpg (scale=11.2281, pad=(140, 0, 141, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_1101_700_uuid_0dc895d4-f5b5-454f-a65f-5ecd09f8b405_roi000_mask.png -> 0614_1101_700_uuid_0dc895d4-f5b5-454f-a65f-5ecd09f8b405_roi000_mask.png, 0614_1101_700_uuid_0dc895d4-f5b5-454f-a65f-5ecd09f8b405_roi000_mask.jpg (scale=10.0000, pad=(0, 120, 0, 120))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0614_1131_700_uuid_78b859a6-390c-41a1-a975-607ec4ccff0d_roi000_mask.png -> 0614_1131_700_uuid_78b859a6-390c-41a1-a975-607ec4ccff0d_roi000_mask.png, 0614_1131_700_uuid_78b859a6-390c-41a1-a975-607ec4ccff0d_roi000_mask.jpg (scale=10.1587, pad=(0, 137, 0, 137))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0617_0947_780_uuid_24bc624c-5c0a-429b-a6dd-6ccfa6f4ab64_roi000_mask.png -> 0617_0947_780_uuid_24bc624c-5c0a-429b-a6dd-6ccfa6f4ab64_roi000_mask.png, 0617_0947_780_uuid_24bc624c-5c0a-429b-a6dd-6ccfa6f4ab64_roi000_mask.jpg (scale=14.5455, pad=(0, 131, 0, 131))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0617_1208_780_uuid_0f4de36e-8803-41d2-bbe2-8d38eb5dff92_roi000_mask.png -> 0617_1208_780_uuid_0f4de36e-8803-41d2-bbe2-8d38eb5dff92_roi000_mask.png, 0617_1208_780_uuid_0f4de36e-8803-41d2-bbe2-8d38eb5dff92_roi000_mask.jpg (scale=13.3333, pad=(53, 0, 54, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0618_0838_780_uuid_a041a009-292c-455b-afc1-42aa1dad5e15_roi000_mask.png -> 0618_0838_780_uuid_a041a009-292c-455b-afc1-42aa1dad5e15_roi000_mask.png, 0618_0838_780_uuid_a041a009-292c-455b-afc1-42aa1dad5e15_roi000_mask.jpg (scale=11.4286, pad=(68, 0, 69, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0618_1008_780_uuid_0ebfdb29-6a63-4ed7-a03d-fa4bb851b616_roi000_mask.png -> 0618_1008_780_uuid_0ebfdb29-6a63-4ed7-a03d-fa4bb851b616_roi000_mask.png, 0618_1008_780_uuid_0ebfdb29-6a63-4ed7-a03d-fa4bb851b616_roi000_mask.jpg (scale=12.3077, pad=(49, 0, 49, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0709_0457_760_uuid_a66530e3-4460-4761-85fc-2548345385e9_roi000_mask.png -> 0709_0457_760_uuid_a66530e3-4460-4761-85fc-2548345385e9_roi000_mask.png, 0709_0457_760_uuid_a66530e3-4460-4761-85fc-2548345385e9_roi000_mask.jpg (scale=9.4118, pad=(0, 122, 0, 123))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0709_0527_760_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c_roi000_mask.png -> 0709_0527_760_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c_roi000_mask.png, 0709_0527_760_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c_roi000_mask.jpg (scale=20.0000, pad=(0, 20, 0, 20))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0709_1922_760_uuid_ac32b96a-93b9-4c9f-83c8-cb739da6fbdb_roi000_mask.png -> 0709_1922_760_uuid_ac32b96a-93b9-4c9f-83c8-cb739da6fbdb_roi000_mask.png, 0709_1922_760_uuid_ac32b96a-93b9-4c9f-83c8-cb739da6fbdb_roi000_mask.jpg (scale=11.6364, pad=(17, 0, 18, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0709_1952_760_uuid_afe891a5-c230-47c3-b326-128c8d4cf500_roi000_mask.png -> 0709_1952_760_uuid_afe891a5-c230-47c3-b326-128c8d4cf500_roi000_mask.png, 0709_1952_760_uuid_afe891a5-c230-47c3-b326-128c8d4cf500_roi000_mask.jpg (scale=10.6667, pad=(64, 0, 64, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0716_2006_640_uuid_66f4a0b4-6f9a-4b15-87b3-ec97f9e3ade9_roi000_mask.png -> 0716_2006_640_uuid_66f4a0b4-6f9a-4b15-87b3-ec97f9e3ade9_roi000_mask.png, 0716_2006_640_uuid_66f4a0b4-6f9a-4b15-87b3-ec97f9e3ade9_roi000_mask.jpg (scale=11.4286, pad=(0, 68, 0, 69))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0716_2008_680_uuid_acecd886-1bf2-456b-9c41-6de1edd8dde2_roi000_mask.png -> 0716_2008_680_uuid_acecd886-1bf2-456b-9c41-6de1edd8dde2_roi000_mask.png, 0716_2008_680_uuid_acecd886-1bf2-456b-9c41-6de1edd8dde2_roi000_mask.jpg (scale=12.8000, pad=(13, 0, 13, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0607_640_uuid_682f3e4e-5f14-4a32-ac14-f19d8e148f9b_roi000_mask.png -> 0717_0607_640_uuid_682f3e4e-5f14-4a32-ac14-f19d8e148f9b_roi000_mask.png, 0717_0607_640_uuid_682f3e4e-5f14-4a32-ac14-f19d8e148f9b_roi000_mask.jpg (scale=10.6667, pad=(0, 106, 0, 107))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0607_640_uuid_ecedf4cf-03ac-4a42-9e4c-f5ddeb63bb12_roi000_mask.png -> 0717_0607_640_uuid_ecedf4cf-03ac-4a42-9e4c-f5ddeb63bb12_roi000_mask.png, 0717_0607_640_uuid_ecedf4cf-03ac-4a42-9e4c-f5ddeb63bb12_roi000_mask.jpg (scale=9.0141, pad=(0, 176, 0, 176))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0607_640_uuid_fcd43230-bec7-49e5-9752-2c90a11ed7ac_roi000_mask.png -> 0717_0607_640_uuid_fcd43230-bec7-49e5-9752-2c90a11ed7ac_roi000_mask.png, 0717_0607_640_uuid_fcd43230-bec7-49e5-9752-2c90a11ed7ac_roi000_mask.jpg (scale=13.0612, pad=(0, 32, 0, 33))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0608_680_uuid_4234817c-4909-4d3f-bf6c-c71773600743_roi000_mask.png -> 0717_0608_680_uuid_4234817c-4909-4d3f-bf6c-c71773600743_roi000_mask.png, 0717_0608_680_uuid_4234817c-4909-4d3f-bf6c-c71773600743_roi000_mask.jpg (scale=11.0345, pad=(0, 77, 0, 77))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0635_640_uuid_1c52d7b9-ed3e-455d-a4a8-55045721bb11_roi000_mask.png -> 0717_0635_640_uuid_1c52d7b9-ed3e-455d-a4a8-55045721bb11_roi000_mask.png, 0717_0635_640_uuid_1c52d7b9-ed3e-455d-a4a8-55045721bb11_roi000_mask.jpg (scale=14.2222, pad=(7, 0, 7, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0635_640_uuid_fe19a80e-31bd-4641-a554-ee944b513278_roi000_mask.png -> 0717_0635_640_uuid_fe19a80e-31bd-4641-a554-ee944b513278_roi000_mask.png, 0717_0635_640_uuid_fe19a80e-31bd-4641-a554-ee944b513278_roi000_mask.jpg (scale=9.8462, pad=(182, 0, 182, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0705_640_uuid_bbff0fbe-4573-475d-9de0-c98a7857fff1_roi000_mask.png -> 0717_0705_640_uuid_bbff0fbe-4573-475d-9de0-c98a7857fff1_roi000_mask.png, 0717_0705_640_uuid_bbff0fbe-4573-475d-9de0-c98a7857fff1_roi000_mask.jpg (scale=16.8421, pad=(109, 0, 110, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0707_680_uuid_482cad8b-aea5-47d3-bf97-da1accb8064d_roi000_mask.png -> 0717_0707_680_uuid_482cad8b-aea5-47d3-bf97-da1accb8064d_roi000_mask.png, 0717_0707_680_uuid_482cad8b-aea5-47d3-bf97-da1accb8064d_roi000_mask.jpg (scale=10.6667, pad=(176, 0, 176, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0707_680_uuid_54f55b71-4a3a-4add-bf87-60d02dd195eb_roi000_mask.png -> 0717_0707_680_uuid_54f55b71-4a3a-4add-bf87-60d02dd195eb_roi000_mask.png, 0717_0707_680_uuid_54f55b71-4a3a-4add-bf87-60d02dd195eb_roi000_mask.jpg (scale=13.0612, pad=(6, 0, 7, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0734_600_uuid_3b23fde5-0e7b-4eb0-95de-51f31898ac47_roi000_mask.png -> 0717_0734_600_uuid_3b23fde5-0e7b-4eb0-95de-51f31898ac47_roi000_mask.png, 0717_0734_600_uuid_3b23fde5-0e7b-4eb0-95de-51f31898ac47_roi000_mask.jpg (scale=16.0000, pad=(80, 0, 80, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0705_640_uuid_55b08a45-f860-494a-be30-96753c43a17c_roi000_mask.png -> 0717_0705_640_uuid_55b08a45-f860-494a-be30-96753c43a17c_roi000_mask.png, 0717_0705_640_uuid_55b08a45-f860-494a-be30-96753c43a17c_roi000_mask.jpg (scale=27.8261, pad=(0, 97, 0, 98))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0805_640_uuid_e51dcbfc-29b2-4f76-858f-f8e1b8011641_roi000_mask.png -> 0717_0805_640_uuid_e51dcbfc-29b2-4f76-858f-f8e1b8011641_roi000_mask.png, 0717_0805_640_uuid_e51dcbfc-29b2-4f76-858f-f8e1b8011641_roi000_mask.jpg (scale=10.6667, pad=(192, 0, 192, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0603_540_uuid_2c925241-8f3c-41a7-a75f-40d80d3c00ba_roi000_mask.png -> 0718_0603_540_uuid_2c925241-8f3c-41a7-a75f-40d80d3c00ba_roi000_mask.png, 0718_0603_540_uuid_2c925241-8f3c-41a7-a75f-40d80d3c00ba_roi000_mask.jpg (scale=13.3333, pad=(66, 0, 67, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0603_540_uuid_5ff31570-85c2-4a6b-aeb8-ed714ec1eaaa_roi000_mask.png -> 0718_0603_540_uuid_5ff31570-85c2-4a6b-aeb8-ed714ec1eaaa_roi000_mask.png, 0718_0603_540_uuid_5ff31570-85c2-4a6b-aeb8-ed714ec1eaaa_roi000_mask.jpg (scale=13.3333, pad=(0, 26, 0, 27))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0603_540_uuid_b4371061-b3dd-4493-a992-9de3535f611c_roi000_mask.png -> 0718_0603_540_uuid_b4371061-b3dd-4493-a992-9de3535f611c_roi000_mask.png, 0718_0603_540_uuid_b4371061-b3dd-4493-a992-9de3535f611c_roi000_mask.jpg (scale=11.6364, pad=(0, 157, 0, 157))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0603_540_uuid_ccec919e-ae17-4c50-a34c-1930cd3ed7ce_roi000_mask.png -> 0718_0603_540_uuid_ccec919e-ae17-4c50-a34c-1930cd3ed7ce_roi000_mask.png, 0718_0603_540_uuid_ccec919e-ae17-4c50-a34c-1930cd3ed7ce_roi000_mask.jpg (scale=12.3077, pad=(0, 31, 0, 31))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0735_640_uuid_5be41150-30f2-4706-9316-0095e245d757_roi000_mask.png -> 0717_0735_640_uuid_5be41150-30f2-4706-9316-0095e245d757_roi000_mask.png, 0717_0735_640_uuid_5be41150-30f2-4706-9316-0095e245d757_roi000_mask.jpg (scale=16.0000, pad=(96, 0, 96, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0737_680_uuid_13e61627-eb37-4451-a7f5-a425be72ffb5_roi000_mask.png -> 0717_0737_680_uuid_13e61627-eb37-4451-a7f5-a425be72ffb5_roi000_mask.png, 0717_0737_680_uuid_13e61627-eb37-4451-a7f5-a425be72ffb5_roi000_mask.jpg (scale=14.2222, pad=(7, 0, 7, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0737_680_uuid_23c6a032-f1d3-4ad1-bf51-af6271d32bf0_roi000_mask.png -> 0717_0737_680_uuid_23c6a032-f1d3-4ad1-bf51-af6271d32bf0_roi000_mask.png, 0717_0737_680_uuid_23c6a032-f1d3-4ad1-bf51-af6271d32bf0_roi000_mask.jpg (scale=10.0000, pad=(165, 0, 165, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0804_600_uuid_032cbee1-dac0-4ce1-8dec-bc8dd756aafe_roi000_mask.png -> 0717_0804_600_uuid_032cbee1-dac0-4ce1-8dec-bc8dd756aafe_roi000_mask.png, 0717_0804_600_uuid_032cbee1-dac0-4ce1-8dec-bc8dd756aafe_roi000_mask.jpg (scale=10.6667, pad=(202, 0, 203, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0717_0807_680_uuid_b3e44a45-7e77-4666-860f-234364cbdd80_roi000_mask.png -> 0717_0807_680_uuid_b3e44a45-7e77-4666-860f-234364cbdd80_roi000_mask.png, 0717_0807_680_uuid_b3e44a45-7e77-4666-860f-234364cbdd80_roi000_mask.jpg (scale=13.6170, pad=(0, 7, 0, 7))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0603_540_uuid_0724bcb8-3cbf-4b26-967f-217cab143219_roi000_mask.png -> 0718_0603_540_uuid_0724bcb8-3cbf-4b26-967f-217cab143219_roi000_mask.png, 0718_0603_540_uuid_0724bcb8-3cbf-4b26-967f-217cab143219_roi000_mask.jpg (scale=10.3226, pad=(0, 139, 0, 140))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0603_540_uuid_16e1ceae-fc2c-4b24-983f-3c55b7a20384_roi000_mask.png -> 0718_0603_540_uuid_16e1ceae-fc2c-4b24-983f-3c55b7a20384_roi000_mask.png, 0718_0603_540_uuid_16e1ceae-fc2c-4b24-983f-3c55b7a20384_roi000_mask.jpg (scale=11.4286, pad=(0, 91, 0, 92))
# ...
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_873c06c2-278d-42f2-8a26-a85368cb04cd_roi000_mask.png -> 0718_0735_600_uuid_873c06c2-278d-42f2-8a26-a85368cb04cd_roi000_mask.png, 0718_0735_600_uuid_873c06c2-278d-42f2-8a26-a85368cb04cd_roi000_mask.jpg (scale=10.4918, pad=(126, 0, 126, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_adf1df17-52c8-49f6-a4fb-2719823ac89a_roi000_mask.png -> 0718_0735_600_uuid_adf1df17-52c8-49f6-a4fb-2719823ac89a_roi000_mask.png, 0718_0735_600_uuid_adf1df17-52c8-49f6-a4fb-2719823ac89a_roi000_mask.jpg (scale=10.6667, pad=(64, 0, 64, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_b19b6312-b723-469b-9862-781b0d3d2ec5_roi000_mask.png -> 0718_0735_600_uuid_b19b6312-b723-469b-9862-781b0d3d2ec5_roi000_mask.png, 0718_0735_600_uuid_b19b6312-b723-469b-9862-781b0d3d2ec5_roi000_mask.jpg (scale=11.4286, pad=(11, 0, 12, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_b1bf70af-6625-4b79-9b23-40d2f5fe44a7_roi000_mask.png -> 0718_0735_600_uuid_b1bf70af-6625-4b79-9b23-40d2f5fe44a7_roi000_mask.png, 0718_0735_600_uuid_b1bf70af-6625-4b79-9b23-40d2f5fe44a7_roi000_mask.jpg (scale=12.0755, pad=(0, 127, 0, 127))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_b27a5fff-b423-42df-8cf2-409903d7bbbb_roi000_mask.png -> 0718_0735_600_uuid_b27a5fff-b423-42df-8cf2-409903d7bbbb_roi000_mask.png, 0718_0735_600_uuid_b27a5fff-b423-42df-8cf2-409903d7bbbb_roi000_mask.jpg (scale=12.0755, pad=(0, 24, 0, 24))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_b29cedfd-4543-4113-82a3-c6a349d69970_roi000_mask.png -> 0718_0735_600_uuid_b29cedfd-4543-4113-82a3-c6a349d69970_roi000_mask.png, 0718_0735_600_uuid_b29cedfd-4543-4113-82a3-c6a349d69970_roi000_mask.jpg (scale=13.0612, pad=(6, 0, 7, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_f7def099-185c-4d6d-8fae-2e2a4783be77_roi000_mask.png -> 0718_0735_600_uuid_f7def099-185c-4d6d-8fae-2e2a4783be77_roi000_mask.png, 0718_0735_600_uuid_f7def099-185c-4d6d-8fae-2e2a4783be77_roi000_mask.jpg (scale=12.5490, pad=(0, 113, 0, 113))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_ff16bd9c-7301-4e8c-8f5f-37cc42f518af_roi000_mask.png -> 0718_0735_600_uuid_ff16bd9c-7301-4e8c-8f5f-37cc42f518af_roi000_mask.png, 0718_0735_600_uuid_ff16bd9c-7301-4e8c-8f5f-37cc42f518af_roi000_mask.jpg (scale=9.4118, pad=(155, 0, 156, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_1131ef1e-3b48-4b09-9bae-d012124727cd_roi000_mask.png -> 0718_0736_640_uuid_1131ef1e-3b48-4b09-9bae-d012124727cd_roi000_mask.png, 0718_0736_640_uuid_1131ef1e-3b48-4b09-9bae-d012124727cd_roi000_mask.jpg (scale=10.4918, pad=(115, 0, 116, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_2f6463b6-12dd-432d-8347-3b12d2efe118_roi000_mask.png -> 0718_0736_640_uuid_2f6463b6-12dd-432d-8347-3b12d2efe118_roi000_mask.png, 0718_0736_640_uuid_2f6463b6-12dd-432d-8347-3b12d2efe118_roi000_mask.jpg (scale=9.6970, pad=(87, 0, 88, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_38eddc00-9714-4b3b-b117-d669460c84ed_roi000_mask.png -> 0718_0736_640_uuid_38eddc00-9714-4b3b-b117-d669460c84ed_roi000_mask.png, 0718_0736_640_uuid_38eddc00-9714-4b3b-b117-d669460c84ed_roi000_mask.jpg (scale=11.8519, pad=(0, 130, 0, 131))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_398cb397-d909-4c35-9a3c-7420bd71c255_roi000_mask.png -> 0718_0736_640_uuid_398cb397-d909-4c35-9a3c-7420bd71c255_roi000_mask.png, 0718_0736_640_uuid_398cb397-d909-4c35-9a3c-7420bd71c255_roi000_mask.jpg (scale=13.3333, pad=(53, 0, 54, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_44def208-e09a-41d2-bd03-a4c5978ec4fe_roi000_mask.png -> 0718_0736_640_uuid_44def208-e09a-41d2-bd03-a4c5978ec4fe_roi000_mask.png, 0718_0736_640_uuid_44def208-e09a-41d2-bd03-a4c5978ec4fe_roi000_mask.jpg (scale=11.2281, pad=(62, 0, 62, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_480876f6-fe78-4407-bc34-9ac14c37be41_roi000_mask.png -> 0718_0736_640_uuid_480876f6-fe78-4407-bc34-9ac14c37be41_roi000_mask.png, 0718_0736_640_uuid_480876f6-fe78-4407-bc34-9ac14c37be41_roi000_mask.jpg (scale=9.5522, pad=(0, 95, 0, 96))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_5dce4b72-7d15-4970-b65d-4704cb1f2878_roi000_mask.png -> 0718_0736_640_uuid_5dce4b72-7d15-4970-b65d-4704cb1f2878_roi000_mask.png, 0718_0736_640_uuid_5dce4b72-7d15-4970-b65d-4704cb1f2878_roi000_mask.jpg (scale=11.2281, pad=(0, 163, 0, 163))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_60981552-3d01-4468-a88f-1ac4e0c8b06f_roi000_mask.png -> 0718_0736_640_uuid_60981552-3d01-4468-a88f-1ac4e0c8b06f_roi000_mask.png, 0718_0736_640_uuid_60981552-3d01-4468-a88f-1ac4e0c8b06f_roi000_mask.jpg (scale=11.2281, pad=(0, 95, 0, 96))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_6266ccd5-df4d-4107-94eb-7178e69752b5_roi000_mask.png -> 0718_0736_640_uuid_6266ccd5-df4d-4107-94eb-7178e69752b5_roi000_mask.png, 0718_0736_640_uuid_6266ccd5-df4d-4107-94eb-7178e69752b5_roi000_mask.jpg (scale=12.3077, pad=(0, 135, 0, 136))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_6c8bb8d6-db02-4767-b595-e03be0a4fcf2_roi000_mask.png -> 0718_0736_640_uuid_6c8bb8d6-db02-4767-b595-e03be0a4fcf2_roi000_mask.png, 0718_0736_640_uuid_6c8bb8d6-db02-4767-b595-e03be0a4fcf2_roi000_mask.jpg (scale=11.4286, pad=(103, 0, 103, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_6f8fbe81-8dc5-4335-9775-d8006060af99_roi000_mask.png -> 0718_0736_640_uuid_6f8fbe81-8dc5-4335-9775-d8006060af99_roi000_mask.png, 0718_0736_640_uuid_6f8fbe81-8dc5-4335-9775-d8006060af99_roi000_mask.jpg (scale=10.6667, pad=(0, 170, 0, 171))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_8319bf9d-c7b4-4d0f-b604-96eca354bf2f_roi000_mask.png -> 0718_0736_640_uuid_8319bf9d-c7b4-4d0f-b604-96eca354bf2f_roi000_mask.png, 0718_0736_640_uuid_8319bf9d-c7b4-4d0f-b604-96eca354bf2f_roi000_mask.jpg (scale=10.6667, pad=(133, 0, 134, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_8f0f809d-c8b7-42da-a909-19576d86339e_roi000_mask.png -> 0718_0736_640_uuid_8f0f809d-c8b7-42da-a909-19576d86339e_roi000_mask.png, 0718_0736_640_uuid_8f0f809d-c8b7-42da-a909-19576d86339e_roi000_mask.jpg (scale=16.4103, pad=(0, 156, 0, 156))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_9472886c-83c9-46ef-8666-b77970714784_roi000_mask.png -> 0718_0736_640_uuid_9472886c-83c9-46ef-8666-b77970714784_roi000_mask.png, 0718_0736_640_uuid_9472886c-83c9-46ef-8666-b77970714784_roi000_mask.jpg (scale=10.8475, pad=(0, 32, 0, 33))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_9fead23e-183b-4fac-981d-0bbb8107425b_roi000_mask.png -> 0718_0736_640_uuid_9fead23e-183b-4fac-981d-0bbb8107425b_roi000_mask.png, 0718_0736_640_uuid_9fead23e-183b-4fac-981d-0bbb8107425b_roi000_mask.jpg (scale=11.4286, pad=(0, 131, 0, 132))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_a727b24b-c059-42a4-8a5c-a9fb0bb255fe_roi000_mask.png -> 0718_0736_640_uuid_a727b24b-c059-42a4-8a5c-a9fb0bb255fe_roi000_mask.png, 0718_0736_640_uuid_a727b24b-c059-42a4-8a5c-a9fb0bb255fe_roi000_mask.jpg (scale=10.3226, pad=(155, 0, 155, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_aedf344e-d25e-4c67-bf39-ea363f6a7f17_roi000_mask.png -> 0718_0736_640_uuid_aedf344e-d25e-4c67-bf39-ea363f6a7f17_roi000_mask.png, 0718_0736_640_uuid_aedf344e-d25e-4c67-bf39-ea363f6a7f17_roi000_mask.jpg (scale=10.4918, pad=(68, 0, 68, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_bbf9071f-51f3-493a-b693-d0232e7546ee_roi000_mask.png -> 0718_0736_640_uuid_bbf9071f-51f3-493a-b693-d0232e7546ee_roi000_mask.png, 0718_0736_640_uuid_bbf9071f-51f3-493a-b693-d0232e7546ee_roi000_mask.jpg (scale=16.0000, pad=(0, 96, 0, 96))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_c9deec94-e0f4-45fb-b2c2-bfb6be55a3e3_roi000_mask.png -> 0718_0736_640_uuid_c9deec94-e0f4-45fb-b2c2-bfb6be55a3e3_roi000_mask.png, 0718_0736_640_uuid_c9deec94-e0f4-45fb-b2c2-bfb6be55a3e3_roi000_mask.jpg (scale=13.0612, pad=(85, 0, 85, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_cc126ebc-c616-485b-81ac-71c448e3bdcb_roi000_mask.png -> 0718_0736_640_uuid_cc126ebc-c616-485b-81ac-71c448e3bdcb_roi000_mask.png, 0718_0736_640_uuid_cc126ebc-c616-485b-81ac-71c448e3bdcb_roi000_mask.jpg (scale=11.0345, pad=(83, 0, 83, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_8787a3e9-00b2-4911-bf57-f9abc2ed0232_roi000_mask.png -> 0718_0735_600_uuid_8787a3e9-00b2-4911-bf57-f9abc2ed0232_roi000_mask.png, 0718_0735_600_uuid_8787a3e9-00b2-4911-bf57-f9abc2ed0232_roi000_mask.jpg (scale=10.6667, pad=(0, 192, 0, 192))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0735_600_uuid_e76c4994-eed7-4eb1-bfe6-df99ea76bd69_roi000_mask.png -> 0718_0735_600_uuid_e76c4994-eed7-4eb1-bfe6-df99ea76bd69_roi000_mask.png, 0718_0735_600_uuid_e76c4994-eed7-4eb1-bfe6-df99ea76bd69_roi000_mask.jpg (scale=14.5455, pad=(80, 0, 80, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_7978ffd1-5267-4870-87b7-5e85078c9028_roi000_mask.png -> 0718_0736_640_uuid_7978ffd1-5267-4870-87b7-5e85078c9028_roi000_mask.png, 0718_0736_640_uuid_7978ffd1-5267-4870-87b7-5e85078c9028_roi000_mask.jpg (scale=10.6667, pad=(0, 85, 0, 86))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0738_680_uuid_3a773f68-1f62-491e-8a42-8c4d50b17ff2_roi000_mask.png -> 0718_0738_680_uuid_3a773f68-1f62-491e-8a42-8c4d50b17ff2_roi000_mask.png, 0718_0738_680_uuid_3a773f68-1f62-491e-8a42-8c4d50b17ff2_roi000_mask.jpg (scale=10.4918, pad=(0, 105, 0, 105))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_d0d0f810-e2a8-4529-86fd-870e2a984a2f_roi000_mask.png -> 0718_0736_640_uuid_d0d0f810-e2a8-4529-86fd-870e2a984a2f_roi000_mask.png, 0718_0736_640_uuid_d0d0f810-e2a8-4529-86fd-870e2a984a2f_roi000_mask.jpg (scale=10.8475, pad=(190, 0, 190, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_e0e73c87-a51e-40de-a192-eb2e849f8de1_roi000_mask.png -> 0718_0736_640_uuid_e0e73c87-a51e-40de-a192-eb2e849f8de1_roi000_mask.png, 0718_0736_640_uuid_e0e73c87-a51e-40de-a192-eb2e849f8de1_roi000_mask.jpg (scale=11.0345, pad=(0, 94, 0, 94))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_ef57f090-bea2-46ec-a577-30a463367f7d_roi000_mask.png -> 0718_0736_640_uuid_ef57f090-bea2-46ec-a577-30a463367f7d_roi000_mask.png, 0718_0736_640_uuid_ef57f090-bea2-46ec-a577-30a463367f7d_roi000_mask.jpg (scale=10.0000, pad=(60, 0, 60, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0736_640_uuid_fa133fb5-13c6-4026-b7be-1336a279ba3a_roi000_mask.png -> 0718_0736_640_uuid_fa133fb5-13c6-4026-b7be-1336a279ba3a_roi000_mask.png, 0718_0736_640_uuid_fa133fb5-13c6-4026-b7be-1336a279ba3a_roi000_mask.jpg (scale=11.6364, pad=(0, 17, 0, 18))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0734_580_uuid_0734d8f1-4a28-43f4-b289-a992b839a01e_roi000_mask.png -> 0718_0734_580_uuid_0734d8f1-4a28-43f4-b289-a992b839a01e_roi000_mask.png, 0718_0734_580_uuid_0734d8f1-4a28-43f4-b289-a992b839a01e_roi000_mask.jpg (scale=12.8000, pad=(0, 141, 0, 141))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0734_580_uuid_0a44ce3e-045f-4e1a-aa47-af552d198c37_roi000_mask.png -> 0718_0734_580_uuid_0a44ce3e-045f-4e1a-aa47-af552d198c37_roi000_mask.png, 0718_0734_580_uuid_0a44ce3e-045f-4e1a-aa47-af552d198c37_roi000_mask.jpg (scale=11.4286, pad=(0, 171, 0, 172))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0734_580_uuid_1ba676e8-26e2-4d0a-b45b-901950f3d6e3_roi000_mask.png -> 0718_0734_580_uuid_1ba676e8-26e2-4d0a-b45b-901950f3d6e3_roi000_mask.png, 0718_0734_580_uuid_1ba676e8-26e2-4d0a-b45b-901950f3d6e3_roi000_mask.jpg (scale=10.0000, pad=(150, 0, 150, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0734_580_uuid_2a2808f2-d2a7-4c11-b5a5-a365f79e69dd_roi000_mask.png -> 0718_0734_580_uuid_2a2808f2-d2a7-4c11-b5a5-a365f79e69dd_roi000_mask.png, 0718_0734_580_uuid_2a2808f2-d2a7-4c11-b5a5-a365f79e69dd_roi000_mask.jpg (scale=10.0000, pad=(160, 0, 160, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0732_540_uuid_88a06b99-e201-4d14-86e1-db36a29d81c9_roi000_mask.png -> 0718_0732_540_uuid_88a06b99-e201-4d14-86e1-db36a29d81c9_roi000_mask.png, 0718_0732_540_uuid_88a06b99-e201-4d14-86e1-db36a29d81c9_roi000_mask.jpg (scale=11.4286, pad=(160, 0, 160, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0732_540_uuid_b6492f9a-b360-4400-a6a1-24d0bcdb6aef_roi000_mask.png -> 0718_0732_540_uuid_b6492f9a-b360-4400-a6a1-24d0bcdb6aef_roi000_mask.png, 0718_0732_540_uuid_b6492f9a-b360-4400-a6a1-24d0bcdb6aef_roi000_mask.jpg (scale=13.6170, pad=(75, 0, 75, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0732_540_uuid_c4fe292e-e8c9-4a2f-a8c6-87c1fe85adba_roi000_mask.png -> 0718_0732_540_uuid_c4fe292e-e8c9-4a2f-a8c6-87c1fe85adba_roi000_mask.png, 0718_0732_540_uuid_c4fe292e-e8c9-4a2f-a8c6-87c1fe85adba_roi000_mask.jpg (scale=10.8475, pad=(0, 124, 0, 125))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0732_540_uuid_d44196e3-7d88-4c9f-b5ea-0f5a25c59805_roi000_mask.png -> 0718_0732_540_uuid_d44196e3-7d88-4c9f-b5ea-0f5a25c59805_roi000_mask.png, 0718_0732_540_uuid_d44196e3-7d88-4c9f-b5ea-0f5a25c59805_roi000_mask.jpg (scale=11.4286, pad=(91, 0, 92, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0734_580_uuid_04c0b5cd-13af-466f-94d8-acdcc45aee76_roi000_mask.png -> 0718_0734_580_uuid_04c0b5cd-13af-466f-94d8-acdcc45aee76_roi000_mask.png, 0718_0734_580_uuid_04c0b5cd-13af-466f-94d8-acdcc45aee76_roi000_mask.jpg (scale=10.4918, pad=(0, 68, 0, 68))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0738_680_uuid_5bd9c360-828d-4a74-9e93-8777e7006074_roi000_mask.png -> 0718_0738_680_uuid_5bd9c360-828d-4a74-9e93-8777e7006074_roi000_mask.png, 0718_0738_680_uuid_5bd9c360-828d-4a74-9e93-8777e7006074_roi000_mask.jpg (scale=10.1587, pad=(0, 157, 0, 158))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0738_680_uuid_634c84bf-7e69-48cc-bcac-673b4e774a45_roi000_mask.png -> 0718_0738_680_uuid_634c84bf-7e69-48cc-bcac-673b4e774a45_roi000_mask.png, 0718_0738_680_uuid_634c84bf-7e69-48cc-bcac-673b4e774a45_roi000_mask.jpg (scale=11.4286, pad=(0, 160, 0, 160))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0738_680_uuid_6c034e6e-ae9e-45c9-9e75-07618d88c704_roi000_mask.png -> 0718_0738_680_uuid_6c034e6e-ae9e-45c9-9e75-07618d88c704_roi000_mask.png, 0718_0738_680_uuid_6c034e6e-ae9e-45c9-9e75-07618d88c704_roi000_mask.jpg (scale=11.8519, pad=(6, 0, 6, 0))
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/mask/0718_0738_680_uuid_7f98e248-5b02-4ac9-8c8d-ab9a1793812a_roi000_mask.png -> 0718_0738_680_uuid_7f98e248-5b02-4ac9-8c8d-ab9a1793812a_roi000_mask.png, 0718_0738_680_uuid_7f98e248-5b02-4ac9-8c8d-ab9a1793812a_roi000_mask.jpg (scale=10.4918, pad=(0, 152, 0, 152))
# [DONE] 共处理图片：849
# [OUT ] 放大图 & 更新 JSON：/workspace/models/runs_yolov11_det/crops_by_points/swd/mask/resized_640_lb
# [OUT ] 可视化图：/workspace/models/runs_yolov11_det/crops_by_points/swd/mask/resized_640_lb_vis

# %% [markdown]
# # 背景填充 -- 黑色

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import cv2
import glob
import numpy as np
from pathlib import Path

# ========== 配置 ==========
# IN_DIR  = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/mask/resized_640_lb")   # 输入目录
IN_DIR  = Path("/workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/")   # 输入目录
# OUT_DIR = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/mask/resized_640_lb_blackbg")  # 输出目录
OUT_DIR = Path("/workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg")  # 输出目录

IMG_EXTS = [".png", ".PNG"]

def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)

def process_one(img_path: Path, out_dir: Path):
    img = cv2.imread(str(img_path), cv2.IMREAD_UNCHANGED)
    if img is None:
        print(f"[WARN] 无法读取：{img_path}")
        return

    if img.shape[2] == 4:  # 带 alpha 通道
        b, g, r, a = cv2.split(img)
        # alpha==0 的区域 → 填充黑色
        mask = (a == 0)
        b[mask] = 0
        g[mask] = 0
        r[mask] = 0
        merged = cv2.merge([b, g, r])  # 输出为 BGR 三通道
    else:
        merged = img  # 没有透明通道就直接拷贝

    out_path = out_dir / img_path.relative_to(IN_DIR)
    ensure_dir(out_path.parent)
    cv2.imwrite(str(out_path.with_suffix(".jpg")), merged)  # 存 JPG（无透明）
    print(f"[OK] {img_path} -> {out_path.with_suffix('.jpg')}")

def main():
    ensure_dir(OUT_DIR)
    files = []
    for ext in IMG_EXTS:
        files.extend(glob.glob(str(IN_DIR / f"**/*{ext}"), recursive=True))

    if not files:
        print(f"[INFO] 没有找到 PNG：{IN_DIR}")
        return

    for f in files:
        process_one(Path(f), OUT_DIR)

    print(f"[DONE] 已处理 {len(files)} 张图片。输出目录：{OUT_DIR.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0604_580_uuid_d1d94c90-a467-47d0-b016-e6ebfa103e8d_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0604_580_uuid_d1d94c90-a467-47d0-b016-e6ebfa103e8d_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0607_640_uuid_966802cc-f544-4fae-a1d4-0db8ea6d2f51_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0607_640_uuid_966802cc-f544-4fae-a1d4-0db8ea6d2f51_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0634_580_uuid_05727c5d-7df8-45ae-a2be-e3e13d2c41c1_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0634_580_uuid_05727c5d-7df8-45ae-a2be-e3e13d2c41c1_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0634_580_uuid_840d5d0c-7ef4-423a-b118-27bb28cc9f62_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0634_580_uuid_840d5d0c-7ef4-423a-b118-27bb28cc9f62_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0720_0202_760_uuid_4393961d-f0b7-465a-bc96-eff712a13e93_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0720_0202_760_uuid_4393961d-f0b7-465a-bc96-eff712a13e93_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0720_0232_760_uuid_326dfcfc-1c80-4ccc-818a-d502feb80684_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0720_0232_760_uuid_326dfcfc-1c80-4ccc-818a-d502feb80684_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0720_0234_800_uuid_6a51d974-8ba2-461b-92d7-4e9ec44f01bf_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0720_0234_800_uuid_6a51d974-8ba2-461b-92d7-4e9ec44f01bf_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0801_2302_800_uuid_2da2eeff-8ad4-4107-9c16-cbc937b8678b_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0801_2302_800_uuid_2da2eeff-8ad4-4107-9c16-cbc937b8678b_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0801_2334_840_uuid_46b45cbc-b233-4d80-87d6-1c6a0ea6906b_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0801_2334_840_uuid_46b45cbc-b233-4d80-87d6-1c6a0ea6906b_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0635_600_uuid_e9b71ac3-0ec7-462c-a666-63d288f94000_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0635_600_uuid_e9b71ac3-0ec7-462c-a666-63d288f94000_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0635_600_uuid_f875d675-5b10-4e1f-bab8-09deff6a9b58_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0635_600_uuid_f875d675-5b10-4e1f-bab8-09deff6a9b58_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0636_640_uuid_39c532e9-ef18-4e55-9b77-1a36ad6eed60_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0636_640_uuid_39c532e9-ef18-4e55-9b77-1a36ad6eed60_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0636_640_uuid_5ba7f846-3801-47f5-b151-33a0999f5f77_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0636_640_uuid_5ba7f846-3801-47f5-b151-33a0999f5f77_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0636_640_uuid_adc1155a-6bfd-4c00-ba07-08fc35d47f69_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0636_640_uuid_adc1155a-6bfd-4c00-ba07-08fc35d47f69_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0704_580_uuid_484fa83e-0b1a-4c1a-887d-e4faf6ba60e1_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0704_580_uuid_484fa83e-0b1a-4c1a-887d-e4faf6ba60e1_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0704_580_uuid_c8e9ffa5-3932-4462-ab1b-3a6cf8e22647_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0704_580_uuid_c8e9ffa5-3932-4462-ab1b-3a6cf8e22647_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0704_580_uuid_fa3e1123-d08f-4c11-8f32-a4ba82fe921c_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0704_580_uuid_fa3e1123-d08f-4c11-8f32-a4ba82fe921c_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0705_600_uuid_0b4e8333-24a3-4423-ae64-ce12a981764a_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0705_600_uuid_0b4e8333-24a3-4423-ae64-ce12a981764a_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0719_0112_800_uuid_98e6a8ce-7aa4-4a82-bb3a-a72af1b20298_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0719_0112_800_uuid_98e6a8ce-7aa4-4a82-bb3a-a72af1b20298_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0720_0114_760_uuid_c347301d-e519-4b51-aa1e-1d1168338f2a_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0720_0114_760_uuid_c347301d-e519-4b51-aa1e-1d1168338f2a_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0720_0132_760_uuid_237591f0-55c5-450f-a692-37baefb61aa0_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0720_0132_760_uuid_237591f0-55c5-450f-a692-37baefb61aa0_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0720_0134_800_uuid_711c7b60-9d5a-4da3-82af-e271b5412ab2_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0720_0134_800_uuid_711c7b60-9d5a-4da3-82af-e271b5412ab2_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0635_600_uuid_498e3bbc-3444-4616-866c-d60da75819d6_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0635_600_uuid_498e3bbc-3444-4616-866c-d60da75819d6_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0704_580_uuid_30bc683b-1c23-480b-ad2e-596fdf9c383d_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0704_580_uuid_30bc683b-1c23-480b-ad2e-596fdf9c383d_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0706_640_uuid_715ef9a3-1fdb-43f0-9cf7-73c32a0885a5_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0706_640_uuid_715ef9a3-1fdb-43f0-9cf7-73c32a0885a5_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0719_0041_760_uuid_6813bcfe-e31d-49e0-b667-1af79efba905_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0719_0041_760_uuid_6813bcfe-e31d-49e0-b667-1af79efba905_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0705_600_uuid_4db8f15b-d5e9-4b54-a150-fac22d61294b_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0705_600_uuid_4db8f15b-d5e9-4b54-a150-fac22d61294b_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0705_600_uuid_ba8be6c4-cc71-4ba6-92e7-68c51b684408_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0705_600_uuid_ba8be6c4-cc71-4ba6-92e7-68c51b684408_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0705_600_uuid_edaed6d0-1374-40c7-a3c7-61c69e5f7633_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0705_600_uuid_edaed6d0-1374-40c7-a3c7-61c69e5f7633_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0705_600_uuid_fc96dbd6-f0e1-43c3-97ed-aa5a2fb3ad14_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0705_600_uuid_fc96dbd6-f0e1-43c3-97ed-aa5a2fb3ad14_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0706_640_uuid_e261e065-42e2-46b8-96ec-9b0def015daf_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0706_640_uuid_e261e065-42e2-46b8-96ec-9b0def015daf_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0735_600_uuid_855a19af-6fd2-47f6-a15e-48311be7779e_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0735_600_uuid_855a19af-6fd2-47f6-a15e-48311be7779e_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0735_600_uuid_ae4a7d67-d4bb-4795-bd60-baf055b888cc_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0735_600_uuid_ae4a7d67-d4bb-4795-bd60-baf055b888cc_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0736_640_uuid_585fa2d0-475c-4f55-baef-d479593d8fe6_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0736_640_uuid_585fa2d0-475c-4f55-baef-d479593d8fe6_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0736_640_uuid_74fd865e-53e4-403a-ac66-23c7a7d046ba_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0736_640_uuid_74fd865e-53e4-403a-ac66-23c7a7d046ba_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0736_640_uuid_7b5b3655-ce33-46c3-9643-d5ec6c756f33_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0736_640_uuid_7b5b3655-ce33-46c3-9643-d5ec6c756f33_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_0736_640_uuid_d433ba4a-a9f0-493c-9458-c4fc048f536a_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_0736_640_uuid_d433ba4a-a9f0-493c-9458-c4fc048f536a_roi000_mask.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb/0718_2006_800_uuid_6e952c4e-69c2-4ede-be48-fc1c2d397251_roi000_mask.png -> /workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg/0718_2006_800_uuid_6e952c4e-69c2-4ede-be48-fc1c2d397251_roi000_mask.jpg
# [DONE] 已处理 38 张图片。输出目录：/workspace/models/runs_yolov11_det/crops_by_points/mayswd/mask/resized_640_lb_blackbg

# %% [markdown]
# # 背景高斯模糊

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import cv2
import glob
import numpy as np
from pathlib import Path
from typing import List, Tuple, Any, Optional, Union

# ========== 配置（请按需修改） ==========
# IN_DIR      = Path("/workspace/models/runs_yolov11_det/crops_by_points/mayswd/rect/resized_640_lb")  # 输入：jpg + json
# OUT_BLUR    = Path("/workspace/models/runs_yolov11_det/crops_by_points/mayswd/rect/resized_640_lb_blur_outside")  # 新文件夹1
# OUT_VIS     = Path("/workspace/models/runs_yolov11_det/crops_by_points/mayswd/rect/resized_640_lb_blur_outside_vis")  # 新文件夹2

IN_DIR      = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb")  # 输入：jpg + json
OUT_BLUR    = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside")  # 新文件夹1
OUT_VIS     = Path("/workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis")  # 新文件夹2

# 模糊强度（内核需奇数）；sigmaX 留 0 让 OpenCV 自算
GAUSSIAN_KERNEL = (101, 101)
GAUSSIAN_SIGMA  = 0

# 画边颜色/厚度与填充透明度（BGR）
EDGE_COLOR   = (0, 0, 255)   # 红色边
EDGE_THICK   = 2
FILL_COLOR   = (255, 0, 0)   # 蓝色内部半透明
FILL_ALPHA   = 0.20          # 0~1；设 0 关闭填充效果

IMG_EXTS = [".jpg", ".jpeg", ".JPG", ".JPEG"]

# ========== 工具 ==========
def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)

def paired_json_for(img_path: Path) -> Path:
    return img_path.with_suffix(".json")

def _as_point_list(x: Any) -> Optional[List[List[float]]]:
    """
    把 [[x,y],...] 或 [{'x':..,'y':..},...] 的点集转成 [[x,y],...]
    若是“多个多边形”的结构（例如 [[[...],[...],...], [[...],...]]），则原样返回嵌套结构
    """
    if x is None:
        return None
    # 检测是否为多多边形（list 的第一层元素也是 list，并且其第一项仍是 list/dict）
    if isinstance(x, list) and len(x) > 0 and isinstance(x[0], list) and len(x[0]) > 0 and isinstance(x[0][0], (list, dict, float, int)):
        # 可能是单个多边形或多多边形
        # 判断：若 x[0][0] 还是标量，则是单多边形
        if isinstance(x[0][0], (int, float)) or (isinstance(x[0][0], list) and len(x[0][0]) == 2):
            # 单个多边形
            return _normalize_one_polygon(x)
        else:
            # 多个多边形：对每个子项递归归一化
            polys = []
            for poly in x:
                polys.append(_normalize_one_polygon(poly))
            return polys
    # dict/list 扁平点集
    return _normalize_one_polygon(x)

def _normalize_one_polygon(points: Any) -> Optional[List[List[float]]]:
    out = []
    if isinstance(points, list):
        for pt in points:
            if isinstance(pt, (list, tuple)) and len(pt) >= 2:
                out.append([float(pt[0]), float(pt[1])])
            elif isinstance(pt, dict) and ("x" in pt) and ("y" in pt):
                out.append([float(pt["x"]), float(pt["y"])])
    return out if out else None

def load_polygon_points_for_image(json_path: Path, img_shape: Tuple[int,int]) -> Optional[Union[List[List[float]], List[List[List[float]]]]]:
    """
    从 JSON 中得到“当前图坐标系”的多边形点：
      优先：points_rel_resized
      其次：points_rel + meta.scale/meta.pad（在 640 letterbox 下映射）
      再次：points（假定即当前坐标）
    支持“单多边形”或“多多边形”（返回同结构）。
    """
    if not json_path.exists():
        return None
    with json_path.open("r", encoding="utf-8") as f:
        data = json.load(f)

    # 1) 直接使用 points_rel_resized
    if "points_rel_resized" in data:
        pts = _as_point_list(data["points_rel_resized"])
        if pts: return pts

    # 2) 由 points_rel + meta.scale + meta.pad 推算（适用于 letterbox 到 640x640）
    if "points_rel" in data and "meta" in data and isinstance(data["meta"], dict):
        pts_rel = _as_point_list(data["points_rel"])
        scale = data["meta"].get("scale", None)
        pad   = data["meta"].get("pad", None)

        if pts_rel and scale is not None and pad is not None:
            # scale 既可能是 float，也可能是 {"sx":..,"sy":..}；letterbox 版本是 float
            if isinstance(scale, dict):
                sx = float(scale.get("sx", 1.0))
                sy = float(scale.get("sy", 1.0))
            else:
                sx = sy = float(scale)

            left = int(pad.get("left", 0)) if isinstance(pad, dict) else 0
            top  = int(pad.get("top", 0))  if isinstance(pad, dict) else 0

            def map_pts(one_poly):
                return [[x * sx + left, y * sy + top] for (x, y) in one_poly]

            if isinstance(pts_rel[0][0], list):  # 多多边形
                return [map_pts(poly) for poly in pts_rel]
            else:  # 单个多边形
                return map_pts(pts_rel)

    # 3) 兜底：points（假设它本来就是当前图坐标）
    if "points" in data:
        pts = _as_point_list(data["points"])
        if pts: return pts

    return None

def polygons_to_mask(polys: Union[List[List[float]], List[List[List[float]]]], h: int, w: int) -> np.ndarray:
    """
    根据单/多多边形生成 mask（uint8, 0/255）。点数<3时退化为外接矩形。
    """
    mask = np.zeros((h, w), dtype=np.uint8)

    def draw_one(poly):
        if poly is None or len(poly) == 0:
            return
        pts = np.array(poly, dtype=np.float32)
        pts = np.round(pts).astype(np.int32)
        if len(pts) >= 3:
            cv2.fillPoly(mask, [pts], 255)
        else:
            # 退化为外接矩形
            xs, ys = pts[:, 0], pts[:, 1]
            xmin, xmax = int(np.floor(xs.min())), int(np.ceil(xs.max()))
            ymin, ymax = int(np.floor(ys.min())), int(np.ceil(ys.max()))
            xmin = max(0, min(xmin, w-1)); xmax = max(0, min(xmax, w-1))
            ymin = max(0, min(ymin, h-1)); ymax = max(0, min(ymax, h-1))
            if xmax < xmin: xmax = xmin
            if ymax < ymin: ymax = ymin
            mask[ymin:ymax+1, xmin:xmax+1] = 255

    # 多多边形
    if isinstance(polys, list) and len(polys) > 0 and isinstance(polys[0], list) and len(polys[0]) > 0 and isinstance(polys[0][0], list):
        for poly in polys:
            draw_one(poly)
    else:
        draw_one(polys)

    return mask

def blur_outside_polygon(img: np.ndarray, mask: np.ndarray,
                         ksize=(31,31), sigmaX=0) -> np.ndarray:
    """
    多边形外高斯模糊：mask 内保持清晰，外部模糊。
    """
    # 统一到 BGR（jpeg 不会有 alpha）
    base = img.copy()
    if base.ndim == 3 and base.shape[2] == 4:
        base = cv2.cvtColor(base, cv2.COLOR_BGRA2BGR)

    blurred = cv2.GaussianBlur(base, ksize, sigmaX)
    m3 = cv2.merge([mask, mask, mask])
    inv = cv2.bitwise_not(mask)
    inv3 = cv2.merge([inv, inv, inv])

    keep = cv2.bitwise_and(base, m3)
    blur = cv2.bitwise_and(blurred, inv3)
    out  = cv2.add(keep, blur)
    return out

def draw_polygon_on_image(img: np.ndarray,
                          polys: Union[List[List[float]], List[List[List[float]]]],
                          edge_color=(0,0,255), edge_thick=2,
                          fill_color=(255,0,0), fill_alpha=0.2) -> np.ndarray:
    """
    在图上描边/可选半透明填充，支持单/多多边形。
    """
    canvas = img.copy()
    if canvas.ndim == 3 and canvas.shape[2] == 4:
        canvas = cv2.cvtColor(canvas, cv2.COLOR_BGRA2BGR)

    def draw_one(poly):
        pts = np.array(poly, dtype=np.float32)
        pts = np.round(pts).astype(np.int32)
        if len(pts) >= 3 and fill_alpha > 0:
            overlay = canvas.copy()
            cv2.fillPoly(overlay, [pts], fill_color)
            canvas[:] = cv2.addWeighted(overlay, fill_alpha, canvas, 1 - fill_alpha, 0)
        if len(pts) >= 2:
            cv2.polylines(canvas, [pts], isClosed=True, color=edge_color, thickness=edge_thick)

    if isinstance(polys, list) and len(polys) > 0 and isinstance(polys[0], list) and len(polys[0]) > 0 and isinstance(polys[0][0], list):
        for poly in polys:
            draw_one(poly)
    else:
        draw_one(polys)

    return canvas

def process_one(img_path: Path):
    img = cv2.imread(str(img_path), cv2.IMREAD_UNCHANGED)
    if img is None:
        print(f"[WARN] 无法读取：{img_path}")
        return

    h, w = img.shape[:2]
    json_path = paired_json_for(img_path)
    polys = load_polygon_points_for_image(json_path, (h, w))
    if polys is None:
        print(f"[WARN] 未找到可用的 points：{json_path}")
        return

    # 生成 mask 并在外部模糊
    mask = polygons_to_mask(polys, h, w)
    blur_img = blur_outside_polygon(img, mask, ksize=GAUSSIAN_KERNEL, sigmaX=GAUSSIAN_SIGMA)

    # 路径 & 保存 新文件夹1（仅模糊）
    rel = img_path.relative_to(IN_DIR)
    out1 = OUT_BLUR / rel
    ensure_dir(out1.parent)
    cv2.imwrite(str(out1), blur_img)

    # 新文件夹2（在模糊结果上描边/填充）
    vis = draw_polygon_on_image(blur_img, polys,
                                edge_color=EDGE_COLOR, edge_thick=EDGE_THICK,
                                fill_color=FILL_COLOR, fill_alpha=FILL_ALPHA)
    out2 = OUT_VIS / rel
    ensure_dir(out2.parent)
    cv2.imwrite(str(out2), vis)

    print(f"[OK] {img_path} -> {out1} & {out2}")

def main():
    ensure_dir(OUT_BLUR)
    ensure_dir(OUT_VIS)

    files = []
    for ext in IMG_EXTS:
        files.extend(glob.glob(str(IN_DIR / f"**/*{ext}"), recursive=True))
    img_files = [Path(p) for p in files]

    if not img_files:
        print(f"[INFO] 未找到图片：{IN_DIR}")
        return

    cnt = 0
    for p in img_files:
        try:
            process_one(p)
            cnt += 1
        except Exception as e:
            print(f"[ERR ] 处理失败：{p} -> {e}")

    print(f"[DONE] 共处理图片：{cnt}")
    print(f"[OUT ] 模糊外部：{OUT_BLUR.resolve()}")
    print(f"[OUT ] 模糊外部+描边：{OUT_VIS.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_0731_700_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_0731_700_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_0731_700_uuid_35af4292-800d-4e97-91e4-eca5e5229ec9_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_0731_700_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_0731_700_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_0731_700_uuid_ce655b7d-7c8b-4a1e-a863-32a000d82d0d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_0801_700_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_0801_700_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_0801_700_uuid_50a739e6-61d0-4b8b-aaeb-a692c56aa56e_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_0831_700_uuid_43850137-a234-44c7-8005-fc9f3ba5394d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_0831_700_uuid_43850137-a234-44c7-8005-fc9f3ba5394d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_0831_700_uuid_43850137-a234-44c7-8005-fc9f3ba5394d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1104_800_uuid_7c314724-2fc5-4b62-aee9-d8dba9f4bc10_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1104_800_uuid_7c314724-2fc5-4b62-aee9-d8dba9f4bc10_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1104_800_uuid_7c314724-2fc5-4b62-aee9-d8dba9f4bc10_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1133_760_uuid_21fcb8b5-2ae6-4637-af1d-b3089fd87be8_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1133_760_uuid_21fcb8b5-2ae6-4637-af1d-b3089fd87be8_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1133_760_uuid_21fcb8b5-2ae6-4637-af1d-b3089fd87be8_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1134_800_uuid_abccd58e-2358-485f-b45d-d62a0a0b4a7d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1134_800_uuid_abccd58e-2358-485f-b45d-d62a0a0b4a7d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1134_800_uuid_abccd58e-2358-485f-b45d-d62a0a0b4a7d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1203_760_uuid_6e949986-8b74-4b09-b49c-2733c95d7eb1_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1203_760_uuid_6e949986-8b74-4b09-b49c-2733c95d7eb1_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1203_760_uuid_6e949986-8b74-4b09-b49c-2733c95d7eb1_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1204_800_uuid_4ac0d4e4-0159-4fa4-ba97-6cff9f14beae_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1204_800_uuid_4ac0d4e4-0159-4fa4-ba97-6cff9f14beae_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1204_800_uuid_4ac0d4e4-0159-4fa4-ba97-6cff9f14beae_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1204_800_uuid_877e6907-0552-4475-9704-aa3697c0282d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1204_800_uuid_877e6907-0552-4475-9704-aa3697c0282d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1204_800_uuid_877e6907-0552-4475-9704-aa3697c0282d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1233_760_uuid_b52d3d9b-25eb-4438-8be4-ac4d301ed731_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1233_760_uuid_b52d3d9b-25eb-4438-8be4-ac4d301ed731_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1233_760_uuid_b52d3d9b-25eb-4438-8be4-ac4d301ed731_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2037_760_uuid_16913f05-f4b6-432e-995b-e0c540862fa4_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2037_760_uuid_16913f05-f4b6-432e-995b-e0c540862fa4_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2037_760_uuid_16913f05-f4b6-432e-995b-e0c540862fa4_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2111_760_uuid_c1a5a1f7-a887-4dd7-b09e-20f42449ba61_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2111_760_uuid_c1a5a1f7-a887-4dd7-b09e-20f42449ba61_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2111_760_uuid_c1a5a1f7-a887-4dd7-b09e-20f42449ba61_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2112_800_uuid_0f820073-800a-4293-a763-6ac14e4a1dac_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2112_800_uuid_0f820073-800a-4293-a763-6ac14e4a1dac_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2112_800_uuid_0f820073-800a-4293-a763-6ac14e4a1dac_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2112_800_uuid_3614c9d3-d3e7-4353-8cd4-554128320672_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2112_800_uuid_3614c9d3-d3e7-4353-8cd4-554128320672_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2112_800_uuid_3614c9d3-d3e7-4353-8cd4-554128320672_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2142_800_uuid_95875294-870a-4a2e-ade2-7a2db3ad5d8b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2142_800_uuid_95875294-870a-4a2e-ade2-7a2db3ad5d8b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2142_800_uuid_95875294-870a-4a2e-ade2-7a2db3ad5d8b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2037_760_uuid_433815b6-38a1-4426-92c1-fe95a98ce3c9_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2037_760_uuid_433815b6-38a1-4426-92c1-fe95a98ce3c9_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2037_760_uuid_433815b6-38a1-4426-92c1-fe95a98ce3c9_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2037_760_uuid_4c7e457d-8c85-4fb9-997d-c2d81377ad9f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2037_760_uuid_4c7e457d-8c85-4fb9-997d-c2d81377ad9f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2037_760_uuid_4c7e457d-8c85-4fb9-997d-c2d81377ad9f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2037_760_uuid_b242cdf6-6f80-477d-8e2f-91c4af478c6c_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2037_760_uuid_b242cdf6-6f80-477d-8e2f-91c4af478c6c_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2037_760_uuid_b242cdf6-6f80-477d-8e2f-91c4af478c6c_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2039_800_uuid_12f5c1fc-5211-4e99-bab0-0e5b8956de2e_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2039_800_uuid_12f5c1fc-5211-4e99-bab0-0e5b8956de2e_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2039_800_uuid_12f5c1fc-5211-4e99-bab0-0e5b8956de2e_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_0901_700_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_0901_700_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_0901_700_uuid_89efe46d-12bf-48a8-9e6e-aa57541b9df0_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0611_1401_700_uuid_e0a7482d-c38a-4278-9796-53af48e2400e_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0611_1401_700_uuid_e0a7482d-c38a-4278-9796-53af48e2400e_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0611_1401_700_uuid_e0a7482d-c38a-4278-9796-53af48e2400e_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0612_0831_700_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0612_0831_700_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0612_0831_700_uuid_03dbe0a2-6569-4f74-83ef-6e31f335de3b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0709_0527_760_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0709_0527_760_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0709_0527_760_uuid_0adcb25c-d24f-4378-ab50-d1942ffa561c_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2211_760_uuid_56da1137-9f54-48b7-8d72-814bb4519c98_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2211_760_uuid_56da1137-9f54-48b7-8d72-814bb4519c98_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2211_760_uuid_56da1137-9f54-48b7-8d72-814bb4519c98_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2211_760_uuid_d5f41b97-e608-48a1-b38c-95f590863a83_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2211_760_uuid_d5f41b97-e608-48a1-b38c-95f590863a83_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2211_760_uuid_d5f41b97-e608-48a1-b38c-95f590863a83_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2241_760_uuid_d5307554-f7be-434b-abac-d3177a577a62_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2241_760_uuid_d5307554-f7be-434b-abac-d3177a577a62_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2241_760_uuid_d5307554-f7be-434b-abac-d3177a577a62_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0801_0542_800_uuid_43096618-dea8-44f5-96c6-7607d2d99c8f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0801_0542_800_uuid_43096618-dea8-44f5-96c6-7607d2d99c8f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0801_0542_800_uuid_43096618-dea8-44f5-96c6-7607d2d99c8f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0802_0852_760_uuid_5b2f2f99-a093-42f6-a4d0-b0555d43a63d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0802_0852_760_uuid_5b2f2f99-a093-42f6-a4d0-b0555d43a63d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0802_0852_760_uuid_5b2f2f99-a093-42f6-a4d0-b0555d43a63d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0802_0854_800_uuid_6130bfaf-862f-4bb5-932a-7229c523d5b7_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0802_0854_800_uuid_6130bfaf-862f-4bb5-932a-7229c523d5b7_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0802_0854_800_uuid_6130bfaf-862f-4bb5-932a-7229c523d5b7_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_0913_760_uuid_66dede5e-915a-426f-82a9-2ae766970b71_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_0913_760_uuid_66dede5e-915a-426f-82a9-2ae766970b71_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_0913_760_uuid_66dede5e-915a-426f-82a9-2ae766970b71_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_0943_760_uuid_c3c60a70-c98c-4601-aaed-6345f92b8392_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_0943_760_uuid_c3c60a70-c98c-4601-aaed-6345f92b8392_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_0943_760_uuid_c3c60a70-c98c-4601-aaed-6345f92b8392_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1043_760_uuid_9a47261e-60f7-4028-a86f-12aac5eb6adc_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1043_760_uuid_9a47261e-60f7-4028-a86f-12aac5eb6adc_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1043_760_uuid_9a47261e-60f7-4028-a86f-12aac5eb6adc_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1143_760_uuid_781e0934-3f82-4baa-9f53-a87e3bbc959b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1143_760_uuid_781e0934-3f82-4baa-9f53-a87e3bbc959b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1143_760_uuid_781e0934-3f82-4baa-9f53-a87e3bbc959b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1243_760_uuid_0b507d48-389e-4394-bf7a-49657d18420a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1243_760_uuid_0b507d48-389e-4394-bf7a-49657d18420a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1243_760_uuid_0b507d48-389e-4394-bf7a-49657d18420a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1243_760_uuid_79603824-c256-489c-904a-65a6ce260d01_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1243_760_uuid_79603824-c256-489c-904a-65a6ce260d01_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1243_760_uuid_79603824-c256-489c-904a-65a6ce260d01_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1313_760_uuid_12768f06-0266-454b-8188-3f8c5391e7b3_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1313_760_uuid_12768f06-0266-454b-8188-3f8c5391e7b3_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1313_760_uuid_12768f06-0266-454b-8188-3f8c5391e7b3_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1343_760_uuid_69cbf2cb-b969-40a4-93df-4bc7ed1c8203_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1343_760_uuid_69cbf2cb-b969-40a4-93df-4bc7ed1c8203_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1343_760_uuid_69cbf2cb-b969-40a4-93df-4bc7ed1c8203_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_1031_700_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_1031_700_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_1031_700_uuid_4363ce35-f202-4d68-a674-1b6f0e941ef8_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0607_1031_700_uuid_68e56662-0412-4703-ab87-2b36a4cb2393_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0607_1031_700_uuid_68e56662-0412-4703-ab87-2b36a4cb2393_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0607_1031_700_uuid_68e56662-0412-4703-ab87-2b36a4cb2393_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0611_1131_700_uuid_d171f9a1-1d37-4230-893f-82049d74cb05_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0611_1131_700_uuid_d171f9a1-1d37-4230-893f-82049d74cb05_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0611_1131_700_uuid_d171f9a1-1d37-4230-893f-82049d74cb05_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0611_1131_700_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0611_1131_700_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0611_1131_700_uuid_e1a81e0f-ad96-45fc-be41-ceb9df04c3c7_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0132_760_uuid_6653f1f1-5c7f-4d99-b1ae-9542436f682a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0132_760_uuid_6653f1f1-5c7f-4d99-b1ae-9542436f682a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0132_760_uuid_6653f1f1-5c7f-4d99-b1ae-9542436f682a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0202_760_uuid_ab86d4ec-b636-46b7-8ee1-e1bd5cb08c58_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0202_760_uuid_ab86d4ec-b636-46b7-8ee1-e1bd5cb08c58_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0202_760_uuid_ab86d4ec-b636-46b7-8ee1-e1bd5cb08c58_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0232_760_uuid_53b680ae-585a-43f2-b7c9-459bc8a3477c_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0232_760_uuid_53b680ae-585a-43f2-b7c9-459bc8a3477c_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0232_760_uuid_53b680ae-585a-43f2-b7c9-459bc8a3477c_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0402_760_uuid_2ad00337-179e-4919-82d5-31472f725957_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0402_760_uuid_2ad00337-179e-4919-82d5-31472f725957_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0402_760_uuid_2ad00337-179e-4919-82d5-31472f725957_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0532_760_uuid_abfb9c2b-569f-4077-ad39-4f9439f6e72a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0532_760_uuid_abfb9c2b-569f-4077-ad39-4f9439f6e72a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0532_760_uuid_abfb9c2b-569f-4077-ad39-4f9439f6e72a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0602_760_uuid_9508e0b9-01ef-4954-99f3-f89b6dd5d5e0_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0602_760_uuid_9508e0b9-01ef-4954-99f3-f89b6dd5d5e0_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0602_760_uuid_9508e0b9-01ef-4954-99f3-f89b6dd5d5e0_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0730_2207_800_uuid_f95891d1-84e2-426d-93a7-a167c3feb63d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0730_2207_800_uuid_f95891d1-84e2-426d-93a7-a167c3feb63d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0730_2207_800_uuid_f95891d1-84e2-426d-93a7-a167c3feb63d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_0903_760_uuid_1fad8d0f-3463-4095-b94a-a7fe9ed68ef7_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_0903_760_uuid_1fad8d0f-3463-4095-b94a-a7fe9ed68ef7_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_0903_760_uuid_1fad8d0f-3463-4095-b94a-a7fe9ed68ef7_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1343_760_uuid_a7ef328e-d886-448a-8a4e-715c0373fc7f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1343_760_uuid_a7ef328e-d886-448a-8a4e-715c0373fc7f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1343_760_uuid_a7ef328e-d886-448a-8a4e-715c0373fc7f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1413_760_uuid_9fc92a55-ce93-4880-bb2f-799d62b92afc_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1413_760_uuid_9fc92a55-ce93-4880-bb2f-799d62b92afc_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1413_760_uuid_9fc92a55-ce93-4880-bb2f-799d62b92afc_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1443_760_uuid_9a48f1eb-bd0e-4fb3-ac24-ee75dddf7a91_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1443_760_uuid_9a48f1eb-bd0e-4fb3-ac24-ee75dddf7a91_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1443_760_uuid_9a48f1eb-bd0e-4fb3-ac24-ee75dddf7a91_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1513_760_uuid_10805ce0-086b-4775-9825-93141286e722_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1513_760_uuid_10805ce0-086b-4775-9825-93141286e722_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1513_760_uuid_10805ce0-086b-4775-9825-93141286e722_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1513_760_uuid_b0937a73-e2a6-4aab-a1b3-bea78d657f08_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1513_760_uuid_b0937a73-e2a6-4aab-a1b3-bea78d657f08_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1513_760_uuid_b0937a73-e2a6-4aab-a1b3-bea78d657f08_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1543_760_uuid_3ccb9eab-6ada-409c-91ab-b8c5f95d4e1f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1543_760_uuid_3ccb9eab-6ada-409c-91ab-b8c5f95d4e1f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1543_760_uuid_3ccb9eab-6ada-409c-91ab-b8c5f95d4e1f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1613_760_uuid_70ca6f13-2b22-4c21-8e6f-39b917b63ce2_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1613_760_uuid_70ca6f13-2b22-4c21-8e6f-39b917b63ce2_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1613_760_uuid_70ca6f13-2b22-4c21-8e6f-39b917b63ce2_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1643_760_uuid_9b6ce2df-3621-4cd8-8e5e-bea2e5b270a8_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1643_760_uuid_9b6ce2df-3621-4cd8-8e5e-bea2e5b270a8_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1643_760_uuid_9b6ce2df-3621-4cd8-8e5e-bea2e5b270a8_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1713_760_uuid_7c5a1898-93f8-4e07-9d2b-ecb819304a45_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1713_760_uuid_7c5a1898-93f8-4e07-9d2b-ecb819304a45_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1713_760_uuid_7c5a1898-93f8-4e07-9d2b-ecb819304a45_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1743_760_uuid_d305e724-a812-49a1-bb60-1f0980ea3b28_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1743_760_uuid_d305e724-a812-49a1-bb60-1f0980ea3b28_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1743_760_uuid_d305e724-a812-49a1-bb60-1f0980ea3b28_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0111_760_uuid_35715a06-28f0-453c-a25c-5ed5e94e4d79_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0111_760_uuid_35715a06-28f0-453c-a25c-5ed5e94e4d79_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0111_760_uuid_35715a06-28f0-453c-a25c-5ed5e94e4d79_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0111_760_uuid_83f1c984-8b53-4c7f-9ff4-6abb26fd10e2_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0111_760_uuid_83f1c984-8b53-4c7f-9ff4-6abb26fd10e2_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0111_760_uuid_83f1c984-8b53-4c7f-9ff4-6abb26fd10e2_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0111_760_uuid_c59d4a7a-6041-4d56-8504-356b95893e44_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0111_760_uuid_c59d4a7a-6041-4d56-8504-356b95893e44_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0111_760_uuid_c59d4a7a-6041-4d56-8504-356b95893e44_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0141_760_uuid_2aaa56ff-8108-45d2-9b62-e1a6b4451f24_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0141_760_uuid_2aaa56ff-8108-45d2-9b62-e1a6b4451f24_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0141_760_uuid_2aaa56ff-8108-45d2-9b62-e1a6b4451f24_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0141_760_uuid_aa83de1d-07eb-4abc-94a3-323a6575a8e3_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0141_760_uuid_aa83de1d-07eb-4abc-94a3-323a6575a8e3_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0141_760_uuid_aa83de1d-07eb-4abc-94a3-323a6575a8e3_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0141_760_uuid_d487c18b-c791-42b5-a4c8-e34cdac40e74_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0141_760_uuid_d487c18b-c791-42b5-a4c8-e34cdac40e74_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0141_760_uuid_d487c18b-c791-42b5-a4c8-e34cdac40e74_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0211_760_uuid_2712f95d-1fb6-43ec-a950-eee41b7783af_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0211_760_uuid_2712f95d-1fb6-43ec-a950-eee41b7783af_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0211_760_uuid_2712f95d-1fb6-43ec-a950-eee41b7783af_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0211_760_uuid_9e098409-e5d0-4416-9ad7-efdf3b6b888f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0211_760_uuid_9e098409-e5d0-4416-9ad7-efdf3b6b888f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0211_760_uuid_9e098409-e5d0-4416-9ad7-efdf3b6b888f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_0904_800_uuid_a0fb7c26-f3d4-4d36-9fff-b96ea526f47a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_0904_800_uuid_a0fb7c26-f3d4-4d36-9fff-b96ea526f47a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_0904_800_uuid_a0fb7c26-f3d4-4d36-9fff-b96ea526f47a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_0933_760_uuid_5c8b635d-db6e-4e3d-8213-78a9cd0be648_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_0933_760_uuid_5c8b635d-db6e-4e3d-8213-78a9cd0be648_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_0933_760_uuid_5c8b635d-db6e-4e3d-8213-78a9cd0be648_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_0934_800_uuid_5579357b-7b9c-40cc-b9f8-5c884e679710_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_0934_800_uuid_5579357b-7b9c-40cc-b9f8-5c884e679710_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_0934_800_uuid_5579357b-7b9c-40cc-b9f8-5c884e679710_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_0934_800_uuid_90f728c2-281c-4337-90ee-442519876201_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_0934_800_uuid_90f728c2-281c-4337-90ee-442519876201_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_0934_800_uuid_90f728c2-281c-4337-90ee-442519876201_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1003_760_uuid_1ace56e3-1024-4f6b-96b6-9472607c680b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1003_760_uuid_1ace56e3-1024-4f6b-96b6-9472607c680b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1003_760_uuid_1ace56e3-1024-4f6b-96b6-9472607c680b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1004_800_uuid_f57844a9-3fd7-4696-a557-95546555001b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1004_800_uuid_f57844a9-3fd7-4696-a557-95546555001b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1004_800_uuid_f57844a9-3fd7-4696-a557-95546555001b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_1034_800_uuid_1a4c6a2b-a5f1-4647-bb0b-157aa515f22f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_1034_800_uuid_1a4c6a2b-a5f1-4647-bb0b-157aa515f22f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_1034_800_uuid_1a4c6a2b-a5f1-4647-bb0b-157aa515f22f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0211_760_uuid_ff7a01f5-aee4-4430-bc25-8cc754d4e42e_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0211_760_uuid_ff7a01f5-aee4-4430-bc25-8cc754d4e42e_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0211_760_uuid_ff7a01f5-aee4-4430-bc25-8cc754d4e42e_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0212_800_uuid_6a5d5b92-151f-4f60-8f8f-1bf5df2d4b55_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0212_800_uuid_6a5d5b92-151f-4f60-8f8f-1bf5df2d4b55_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0212_800_uuid_6a5d5b92-151f-4f60-8f8f-1bf5df2d4b55_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0241_760_uuid_e95bdfc2-87dc-4982-9b0b-757a4e4162de_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0241_760_uuid_e95bdfc2-87dc-4982-9b0b-757a4e4162de_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0241_760_uuid_e95bdfc2-87dc-4982-9b0b-757a4e4162de_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0411_760_uuid_fcb2605f-6334-4235-9455-08801cf5f1a8_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0411_760_uuid_fcb2605f-6334-4235-9455-08801cf5f1a8_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0411_760_uuid_fcb2605f-6334-4235-9455-08801cf5f1a8_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0711_760_uuid_682f8042-887f-4c34-b573-6d6c216a182f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0711_760_uuid_682f8042-887f-4c34-b573-6d6c216a182f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0711_760_uuid_682f8042-887f-4c34-b573-6d6c216a182f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0720_0114_760_uuid_bb105020-21d5-4fc3-be9f-190e574b9469_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0720_0114_760_uuid_bb105020-21d5-4fc3-be9f-190e574b9469_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0720_0114_760_uuid_bb105020-21d5-4fc3-be9f-190e574b9469_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0041_760_uuid_b88ec47e-0c4d-46cb-a2ca-a7aead7d7ef5_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0041_760_uuid_b88ec47e-0c4d-46cb-a2ca-a7aead7d7ef5_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0041_760_uuid_b88ec47e-0c4d-46cb-a2ca-a7aead7d7ef5_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0041_760_uuid_fb3e7332-98d7-4435-9679-14cad38b854b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0041_760_uuid_fb3e7332-98d7-4435-9679-14cad38b854b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0041_760_uuid_fb3e7332-98d7-4435-9679-14cad38b854b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0041_760_uuid_fce907df-0744-4c41-b570-8b411f96c6db_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0041_760_uuid_fce907df-0744-4c41-b570-8b411f96c6db_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0041_760_uuid_fce907df-0744-4c41-b570-8b411f96c6db_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0111_760_uuid_0ec81b15-c165-4996-8e30-43fdb8530a44_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0111_760_uuid_0ec81b15-c165-4996-8e30-43fdb8530a44_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0111_760_uuid_0ec81b15-c165-4996-8e30-43fdb8530a44_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0719_0111_760_uuid_202ce91f-a3ac-4a72-bbde-b4a4b7165527_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0719_0111_760_uuid_202ce91f-a3ac-4a72-bbde-b4a4b7165527_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0719_0111_760_uuid_202ce91f-a3ac-4a72-bbde-b4a4b7165527_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0707_2027_760_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0707_2027_760_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0707_2027_760_uuid_0f34efe4-eea4-4a51-a09b-5dea0e1e73b2_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0707_2106_760_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0707_2106_760_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0707_2106_760_uuid_54e19a2f-662f-4042-a0b1-bb69993b0487_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0709_0357_760_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0709_0357_760_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0709_0357_760_uuid_ac8cb828-9b42-4867-83bc-16de0e98591c_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0709_0457_760_uuid_a66530e3-4460-4761-85fc-2548345385e9_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0709_0457_760_uuid_a66530e3-4460-4761-85fc-2548345385e9_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0709_0457_760_uuid_a66530e3-4460-4761-85fc-2548345385e9_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2037_760_uuid_26eff48e-d7e0-4d35-89dd-00e0165bd124_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2037_760_uuid_26eff48e-d7e0-4d35-89dd-00e0165bd124_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2037_760_uuid_26eff48e-d7e0-4d35-89dd-00e0165bd124_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2142_800_uuid_b1ef0a02-01f1-451d-bcef-bbd684bb5929_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2142_800_uuid_b1ef0a02-01f1-451d-bcef-bbd684bb5929_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2142_800_uuid_b1ef0a02-01f1-451d-bcef-bbd684bb5929_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1113_760_uuid_7705b98b-12c2-49ea-b1e8-fa9acdd9b0dc_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1113_760_uuid_7705b98b-12c2-49ea-b1e8-fa9acdd9b0dc_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1113_760_uuid_7705b98b-12c2-49ea-b1e8-fa9acdd9b0dc_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0803_1543_760_uuid_118450bc-5173-42d6-8d97-5b1e4f93b5eb_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0803_1543_760_uuid_118450bc-5173-42d6-8d97-5b1e4f93b5eb_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0803_1543_760_uuid_118450bc-5173-42d6-8d97-5b1e4f93b5eb_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2039_800_uuid_5bdac058-9a1f-423e-afe1-f281b481cbcc_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2039_800_uuid_5bdac058-9a1f-423e-afe1-f281b481cbcc_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2039_800_uuid_5bdac058-9a1f-423e-afe1-f281b481cbcc_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2039_800_uuid_c898453c-d284-429d-8b39-3d179f3331f3_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2039_800_uuid_c898453c-d284-429d-8b39-3d179f3331f3_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2039_800_uuid_c898453c-d284-429d-8b39-3d179f3331f3_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2039_800_uuid_caf53adc-3d5c-41f7-9b2b-86127808119d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2039_800_uuid_caf53adc-3d5c-41f7-9b2b-86127808119d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2039_800_uuid_caf53adc-3d5c-41f7-9b2b-86127808119d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2039_800_uuid_e8bd32e1-a920-4324-864d-23f189d7e634_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2039_800_uuid_e8bd32e1-a920-4324-864d-23f189d7e634_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2039_800_uuid_e8bd32e1-a920-4324-864d-23f189d7e634_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0731_2040_840_uuid_b517b888-4cb9-4100-b859-9f906cecfd5b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0731_2040_840_uuid_b517b888-4cb9-4100-b859-9f906cecfd5b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0731_2040_840_uuid_b517b888-4cb9-4100-b859-9f906cecfd5b_roi000_bbox.jpg
# ...
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_6c8bb8d6-db02-4767-b595-e03be0a4fcf2_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_6c8bb8d6-db02-4767-b595-e03be0a4fcf2_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_6c8bb8d6-db02-4767-b595-e03be0a4fcf2_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_6f8fbe81-8dc5-4335-9775-d8006060af99_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_6f8fbe81-8dc5-4335-9775-d8006060af99_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_6f8fbe81-8dc5-4335-9775-d8006060af99_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_7978ffd1-5267-4870-87b7-5e85078c9028_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_7978ffd1-5267-4870-87b7-5e85078c9028_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_7978ffd1-5267-4870-87b7-5e85078c9028_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_8319bf9d-c7b4-4d0f-b604-96eca354bf2f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_8319bf9d-c7b4-4d0f-b604-96eca354bf2f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_8319bf9d-c7b4-4d0f-b604-96eca354bf2f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_9472886c-83c9-46ef-8666-b77970714784_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_9472886c-83c9-46ef-8666-b77970714784_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_9472886c-83c9-46ef-8666-b77970714784_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_9fead23e-183b-4fac-981d-0bbb8107425b_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_9fead23e-183b-4fac-981d-0bbb8107425b_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_9fead23e-183b-4fac-981d-0bbb8107425b_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_a727b24b-c059-42a4-8a5c-a9fb0bb255fe_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_a727b24b-c059-42a4-8a5c-a9fb0bb255fe_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_a727b24b-c059-42a4-8a5c-a9fb0bb255fe_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_aedf344e-d25e-4c67-bf39-ea363f6a7f17_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_aedf344e-d25e-4c67-bf39-ea363f6a7f17_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_aedf344e-d25e-4c67-bf39-ea363f6a7f17_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_bbf9071f-51f3-493a-b693-d0232e7546ee_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_bbf9071f-51f3-493a-b693-d0232e7546ee_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_bbf9071f-51f3-493a-b693-d0232e7546ee_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_c9deec94-e0f4-45fb-b2c2-bfb6be55a3e3_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_c9deec94-e0f4-45fb-b2c2-bfb6be55a3e3_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_c9deec94-e0f4-45fb-b2c2-bfb6be55a3e3_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_cc126ebc-c616-485b-81ac-71c448e3bdcb_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_cc126ebc-c616-485b-81ac-71c448e3bdcb_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_cc126ebc-c616-485b-81ac-71c448e3bdcb_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_d0d0f810-e2a8-4529-86fd-870e2a984a2f_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_d0d0f810-e2a8-4529-86fd-870e2a984a2f_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_d0d0f810-e2a8-4529-86fd-870e2a984a2f_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0708_680_uuid_f7353091-1b58-457a-84b4-37586a09f36c_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0708_680_uuid_f7353091-1b58-457a-84b4-37586a09f36c_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0708_680_uuid_f7353091-1b58-457a-84b4-37586a09f36c_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0732_540_uuid_08a6f32a-51cb-4ddf-b878-feed8f00c02a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0732_540_uuid_08a6f32a-51cb-4ddf-b878-feed8f00c02a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0732_540_uuid_08a6f32a-51cb-4ddf-b878-feed8f00c02a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0732_540_uuid_3c095ad5-cf4e-485a-b117-dcfdb46316f2_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0732_540_uuid_3c095ad5-cf4e-485a-b117-dcfdb46316f2_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0732_540_uuid_3c095ad5-cf4e-485a-b117-dcfdb46316f2_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0732_540_uuid_88a06b99-e201-4d14-86e1-db36a29d81c9_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0732_540_uuid_88a06b99-e201-4d14-86e1-db36a29d81c9_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0732_540_uuid_88a06b99-e201-4d14-86e1-db36a29d81c9_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0732_540_uuid_b6492f9a-b360-4400-a6a1-24d0bcdb6aef_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0732_540_uuid_b6492f9a-b360-4400-a6a1-24d0bcdb6aef_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0732_540_uuid_b6492f9a-b360-4400-a6a1-24d0bcdb6aef_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0732_540_uuid_c4fe292e-e8c9-4a2f-a8c6-87c1fe85adba_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0732_540_uuid_c4fe292e-e8c9-4a2f-a8c6-87c1fe85adba_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0732_540_uuid_c4fe292e-e8c9-4a2f-a8c6-87c1fe85adba_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0732_540_uuid_d44196e3-7d88-4c9f-b5ea-0f5a25c59805_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0732_540_uuid_d44196e3-7d88-4c9f-b5ea-0f5a25c59805_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0732_540_uuid_d44196e3-7d88-4c9f-b5ea-0f5a25c59805_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0734_580_uuid_04c0b5cd-13af-466f-94d8-acdcc45aee76_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0734_580_uuid_04c0b5cd-13af-466f-94d8-acdcc45aee76_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0734_580_uuid_04c0b5cd-13af-466f-94d8-acdcc45aee76_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0734_580_uuid_0734d8f1-4a28-43f4-b289-a992b839a01e_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0734_580_uuid_0734d8f1-4a28-43f4-b289-a992b839a01e_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0734_580_uuid_0734d8f1-4a28-43f4-b289-a992b839a01e_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0734_580_uuid_0a44ce3e-045f-4e1a-aa47-af552d198c37_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0734_580_uuid_0a44ce3e-045f-4e1a-aa47-af552d198c37_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0734_580_uuid_0a44ce3e-045f-4e1a-aa47-af552d198c37_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0734_580_uuid_1ba676e8-26e2-4d0a-b45b-901950f3d6e3_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0734_580_uuid_1ba676e8-26e2-4d0a-b45b-901950f3d6e3_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0734_580_uuid_1ba676e8-26e2-4d0a-b45b-901950f3d6e3_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0734_580_uuid_2a2808f2-d2a7-4c11-b5a5-a365f79e69dd_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0734_580_uuid_2a2808f2-d2a7-4c11-b5a5-a365f79e69dd_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0734_580_uuid_2a2808f2-d2a7-4c11-b5a5-a365f79e69dd_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_ef57f090-bea2-46ec-a577-30a463367f7d_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_ef57f090-bea2-46ec-a577-30a463367f7d_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_ef57f090-bea2-46ec-a577-30a463367f7d_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0736_640_uuid_fa133fb5-13c6-4026-b7be-1336a279ba3a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0736_640_uuid_fa133fb5-13c6-4026-b7be-1336a279ba3a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0736_640_uuid_fa133fb5-13c6-4026-b7be-1336a279ba3a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0738_680_uuid_3a773f68-1f62-491e-8a42-8c4d50b17ff2_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0738_680_uuid_3a773f68-1f62-491e-8a42-8c4d50b17ff2_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0738_680_uuid_3a773f68-1f62-491e-8a42-8c4d50b17ff2_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0738_680_uuid_5bd9c360-828d-4a74-9e93-8777e7006074_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0738_680_uuid_5bd9c360-828d-4a74-9e93-8777e7006074_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0738_680_uuid_5bd9c360-828d-4a74-9e93-8777e7006074_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0738_680_uuid_634c84bf-7e69-48cc-bcac-673b4e774a45_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0738_680_uuid_634c84bf-7e69-48cc-bcac-673b4e774a45_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0738_680_uuid_634c84bf-7e69-48cc-bcac-673b4e774a45_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0738_680_uuid_6c034e6e-ae9e-45c9-9e75-07618d88c704_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0738_680_uuid_6c034e6e-ae9e-45c9-9e75-07618d88c704_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0738_680_uuid_6c034e6e-ae9e-45c9-9e75-07618d88c704_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_0738_680_uuid_7f98e248-5b02-4ac9-8c8d-ab9a1793812a_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_0738_680_uuid_7f98e248-5b02-4ac9-8c8d-ab9a1793812a_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_0738_680_uuid_7f98e248-5b02-4ac9-8c8d-ab9a1793812a_roi000_bbox.jpg
# [OK] /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb/0718_2005_760_uuid_69eac9f3-e306-42b1-b162-9d87fba5b7f6_roi000_bbox.jpg -> /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside/0718_2005_760_uuid_69eac9f3-e306-42b1-b162-9d87fba5b7f6_roi000_bbox.jpg & /workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis/0718_2005_760_uuid_69eac9f3-e306-42b1-b162-9d87fba5b7f6_roi000_bbox.jpg
# [DONE] 共处理图片：849
# [OUT ] 模糊外部：/workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside
# [OUT ] 模糊外部+描边：/workspace/models/runs_yolov11_det/crops_by_points/swd/rect/resized_640_lb_blur_outside_vis
