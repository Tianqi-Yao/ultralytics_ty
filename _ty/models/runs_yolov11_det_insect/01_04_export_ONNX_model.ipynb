# %% [markdown]
# # 导出ONNX模型

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/workspace/models/best_model/yolo11n-det-best_v1.pt")  # load a custom trained model

# Export the model
model.export(format="onnx")
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Core(TM) Ultra 7 265KF)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/workspace/models/best_model/yolo11n-det-best_v1.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 1.1s, saved as '/workspace/models/best_model/yolo11n-det-best_v1.onnx' (10.1 MB)
#
# Export complete (1.3s)
# Results saved to /workspace/models/best_model
# Predict:         yolo predict task=detect model=/workspace/models/best_model/yolo11n-det-best_v1.onnx imgsz=640
# Validate:        yolo val task=detect model=/workspace/models/best_model/yolo11n-det-best_v1.onnx imgsz=640 data=/workspace/models/runs_yolov11_det/datasets/swd_pose_split_0.5_0.2_0.3/swd_detection.yaml
# Visualize:       https://netron.app
# ...
