# %% [markdown]
# # 导出ONNX模型

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/workspace/models/runs_yolov11_cls/runs_yolo11n-cls_batch8/cropped_objects_v3_5-2-3/weights/best.pt")  # load a custom trained model

# Export the model
model.export(format="onnx")
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Core(TM) Ultra 7 265KF)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
#
# PyTorch: starting from '/workspace/models/runs_yolov11_cls/runs_yolo11n-cls_batch8/cropped_objects_v3_5-2-3/weights/best.pt' with input shape (1, 3, 64, 64) BCHW and output shape(s) (1, 2) (3.1 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 0.6s, saved as '/workspace/models/runs_yolov11_cls/runs_yolo11n-cls_batch8/cropped_objects_v3_5-2-3/weights/best.onnx' (5.9 MB)
#
# Export complete (0.7s)
# Results saved to /workspace/models/runs_yolov11_cls/runs_yolo11n-cls_batch8/cropped_objects_v3_5-2-3/weights
# Predict:         yolo predict task=classify model=/workspace/models/runs_yolov11_cls/runs_yolo11n-cls_batch8/cropped_objects_v3_5-2-3/weights/best.onnx imgsz=64
# ...
