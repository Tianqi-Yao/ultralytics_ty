# %% [markdown]
# # det

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov8/segment/train6_yolov8x/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov11/segment/train3/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov11/segment/train5/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train5/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train6/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %% [markdown]
# # Seg

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov11/segment/train3/weights/best.pt")

results = model.val(data="data/data.yaml", project="/home/tianqi/wslProjects/SWD")

# results = model.val(data="data/data_test.yaml")
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f9afa15fd90>>
# Traceback (most recent call last):
#   File "/home/tianqi/miniconda3/envs/cuda124/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Ultralytics 8.3.78 🚀 Python-3.10.16 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,067,203 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning /home/tianqi/wslProjects/01_swd/02_code/ultralytics_ty/data/valid/labels.cache... 58 images, 22 backgrounds, 0 corrupt: 100%|██████████| 80/80 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:03<00:00,  1.64it/s]
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train3/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train4/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train5/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train6/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")
