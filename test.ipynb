# %% [markdown]
# # det

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov8/segment/train6_yolov8x/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov11/segment/train3/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov11/segment/train5/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train5/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train6/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %% [markdown]
# # Seg

# %%
from ultralytics import YOLO

model = YOLO("models/runs_yolov11/segment/train3/weights/best.pt")

results = model.val(data="data/data.yaml")

# results = model.val(data="data/data_test.yaml")
# Out:
# Ultralytics 8.3.75 🚀 Python-3.10.16 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,203 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning /home/tianqi/wslProjects/SWD/ultralytics_ty/data/valid/labels.cache... 58 images, 22 backgrounds, 0 corrupt: 100%|██████████| 80/80 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:05<00:00,  1.17s/it]
#                    all         80         67      0.899      0.666      0.814      0.583      0.899      0.666      0.814      0.568
# Speed: 4.0ms preprocess, 34.0ms inference, 0.1ms loss, 19.8ms postprocess per image
# Results saved to /home/tianqi/wslProjects/SWD/ultralytics_ty/runs/segment/val17

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train3/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train4/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train5/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train6/weights/best.pt")

results = model.val(data="data/data.yaml")

results = model.val(data="data/data_test.yaml")
