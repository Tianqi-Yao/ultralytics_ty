# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11n-seg.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")

# # Perform object detection on an image using the model
# results = model("https://ultralytics.com/images/bus.jpg")

# # Export the model to ONNX format
# success = model.export(format="onnx")
# Out:
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11s-seg.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# ...
# 100%|██████████| 19.7M/19.7M [00:00<00:00, 38.0MB/s]
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11m-seg.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# ...
# 100%|██████████| 43.3M/43.3M [00:01<00:00, 39.9MB/s]
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11l-seg.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# ...
# 100%|██████████| 53.5M/53.5M [00:01<00:00, 38.7MB/s]
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11x-seg.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# ...
# 100%|██████████| 119M/119M [00:02<00:00, 46.0MB/s]
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11n.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# New https://pypi.org/project/ultralytics/8.3.67 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11s.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11m.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# ...
# 100%|██████████| 38.8M/38.8M [00:01<00:00, 39.6MB/s]
# New https://pypi.org/project/ultralytics/8.3.67 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11l.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11x.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="data/data.yaml", epochs=500, device=0,
                        single_cls=True,
                        cos_lr=True,
                        degrees= 45.0,  # Image rotation (+/- deg)
                        scale=0,  # Image scale (+/- fraction))
)

# # Evaluate the model's performance on the validation set
results = model.val(data="data/data_test.yaml")
# Out:
# ...
# 100%|██████████| 109M/109M [00:02<00:00, 39.7MB/s]
# New https://pypi.org/project/ultralytics/8.3.67 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.66  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# ...
